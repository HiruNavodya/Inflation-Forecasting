# %% [markdown]
# ## 1

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown
# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 1  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 1), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 25.9MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 18.1 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 13.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 07:34:15,330] A new study created in memory with name: no-name-ede555df-824c-48df-b0ad-4f4e5b35167b
# [I 2025-05-29 07:34:25,535] Trial 0 finished with value: 0.0022891865422328315 and parameters: {'filters': 90, 'kernel_size': 1, 'lr': 0.00030158910215038565, 'epochs': 26, 'batch_size': 8}. Best is trial 0 with value: 0.0022891865422328315.
# [I 2025-05-29 07:34:36,121] Trial 1 finished with value: 0.00035409060850118596 and parameters: {'filters': 93, 'kernel_size': 1, 'lr': 0.005982907103441468, 'epochs': 35, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:34:47,788] Trial 2 finished with value: 0.0034541303369527063 and parameters: {'filters': 68, 'kernel_size': 1, 'lr': 0.0001307101750849335, 'epochs': 49, 'batch_size': 32}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:34:54,130] Trial 3 finished with value: 0.0008589363084562743 and parameters: {'filters': 126, 'kernel_size': 1, 'lr': 0.004234334891689538, 'epochs': 10, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:02,399] Trial 4 finished with value: 0.004267955945882325 and parameters: {'filters': 59, 'kernel_size': 1, 'lr': 0.0001416543938587573, 'epochs': 34, 'batch_size': 32}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:08,863] Trial 5 finished with value: 0.039451481153567634 and parameters: {'filters': 37, 'kernel_size': 1, 'lr': 0.00013645475822740327, 'epochs': 13, 'batch_size': 32}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:22,457] Trial 6 finished with value: 0.0018596084943662088 and parameters: {'filters': 117, 'kernel_size': 1, 'lr': 0.0001901212424723311, 'epochs': 40, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:32,302] Trial 7 finished with value: 0.0011836991034215316 and parameters: {'filters': 91, 'kernel_size': 1, 'lr': 0.009647535332933317, 'epochs': 36, 'batch_size': 32}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:37,875] Trial 8 finished with value: 0.007279990066308528 and parameters: {'filters': 46, 'kernel_size': 1, 'lr': 0.0003130618967733603, 'epochs': 11, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:44,253] Trial 9 finished with value: 0.002618201697866122 and parameters: {'filters': 38, 'kernel_size': 1, 'lr': 0.0006656819416351696, 'epochs': 13, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:35:52,307] Trial 10 finished with value: 0.0010442759570044775 and parameters: {'filters': 103, 'kernel_size': 1, 'lr': 0.0024142363047860906, 'epochs': 23, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:02,423] Trial 11 finished with value: 0.00042675519944168627 and parameters: {'filters': 124, 'kernel_size': 1, 'lr': 0.005244614813069395, 'epochs': 22, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:11,622] Trial 12 finished with value: 0.0004980698722647503 and parameters: {'filters': 112, 'kernel_size': 1, 'lr': 0.008409399679877345, 'epochs': 21, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:23,296] Trial 13 finished with value: 0.0011305508911997701 and parameters: {'filters': 78, 'kernel_size': 1, 'lr': 0.0018352797315021375, 'epochs': 43, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:32,698] Trial 14 finished with value: 0.0009286223891346405 and parameters: {'filters': 100, 'kernel_size': 1, 'lr': 0.004385494234845987, 'epochs': 30, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:40,082] Trial 15 finished with value: 0.0012503629113780335 and parameters: {'filters': 127, 'kernel_size': 1, 'lr': 0.0010664783890647616, 'epochs': 19, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:36:53,430] Trial 16 finished with value: 0.00043682560984355706 and parameters: {'filters': 78, 'kernel_size': 1, 'lr': 0.004555237610613545, 'epochs': 30, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:01,224] Trial 17 finished with value: 0.0012390127667458728 and parameters: {'filters': 113, 'kernel_size': 1, 'lr': 0.0026364478757741534, 'epochs': 17, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:10,165] Trial 18 finished with value: 0.0009603554499335587 and parameters: {'filters': 100, 'kernel_size': 1, 'lr': 0.0012314720231382326, 'epochs': 26, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:22,514] Trial 19 finished with value: 0.0005668778612744063 and parameters: {'filters': 89, 'kernel_size': 1, 'lr': 0.006196731617765927, 'epochs': 35, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:34,585] Trial 20 finished with value: 0.0017486320381673675 and parameters: {'filters': 63, 'kernel_size': 1, 'lr': 0.0006168473369697431, 'epochs': 43, 'batch_size': 16}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:46,022] Trial 21 finished with value: 0.00047001604495259625 and parameters: {'filters': 78, 'kernel_size': 1, 'lr': 0.004419719176976298, 'epochs': 29, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:37:57,681] Trial 22 finished with value: 0.00037526225787587464 and parameters: {'filters': 72, 'kernel_size': 1, 'lr': 0.006244187673197798, 'epochs': 32, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:38:11,563] Trial 23 finished with value: 0.00043620922951959074 and parameters: {'filters': 54, 'kernel_size': 1, 'lr': 0.006769095234473105, 'epochs': 37, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:38:21,371] Trial 24 finished with value: 0.00048772144752244156 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.002972137209750348, 'epochs': 25, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:38:32,596] Trial 25 finished with value: 0.0008266296742173532 and parameters: {'filters': 120, 'kernel_size': 1, 'lr': 0.00163256745505211, 'epochs': 32, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:38:46,085] Trial 26 finished with value: 0.00038823767196542275 and parameters: {'filters': 106, 'kernel_size': 1, 'lr': 0.005943223933953636, 'epochs': 39, 'batch_size': 8}. Best is trial 1 with value: 0.00035409060850118596.
# [I 2025-05-29 07:38:59,093] Trial 27 finished with value: 0.0003451702408104514 and parameters: {'filters': 106, 'kernel_size': 1, 'lr': 0.0033350746393023913, 'epochs': 39, 'batch_size': 8}. Best is trial 27 with value: 0.0003451702408104514.
# [I 2025-05-29 07:39:09,716] Trial 28 finished with value: 0.0011781804156877722 and parameters: {'filters': 86, 'kernel_size': 1, 'lr': 0.0034411520146549785, 'epochs': 46, 'batch_size': 32}. Best is trial 27 with value: 0.0003451702408104514.
# [I 2025-05-29 07:39:20,491] Trial 29 finished with value: 0.0006448649413262805 and parameters: {'filters': 93, 'kernel_size': 1, 'lr': 0.001984557711417848, 'epochs': 40, 'batch_size': 16}. Best is trial 27 with value: 0.0003451702408104514.
# Best trial: {'filters': 106, 'kernel_size': 1, 'lr': 0.0033350746393023913, 'epochs': 39, 'batch_size': 8}
# Epoch 1/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0073
# Epoch 2/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 3/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2517e-04
# Epoch 4/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3690e-04
# Epoch 5/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7106e-04
# Epoch 6/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0363e-04
# Epoch 7/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5405e-04
# Epoch 8/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0522e-04
# Epoch 9/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7981e-04
# Epoch 10/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0536e-04
# Epoch 11/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8366e-04
# Epoch 12/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4503e-04
# Epoch 13/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1068e-04
# Epoch 14/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5105e-04
# Epoch 15/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4606e-04
# Epoch 16/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2087e-04
# Epoch 17/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7267e-04
# Epoch 18/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4472e-04
# Epoch 19/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5678e-04
# Epoch 20/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4641e-04
# Epoch 21/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9386e-04
# Epoch 22/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3220e-04
# Epoch 23/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7374e-04
# Epoch 24/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8771e-04
# Epoch 25/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5662e-04
# Epoch 26/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2973e-04
# Epoch 27/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3207e-04
# Epoch 28/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2173e-04
# Epoch 29/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3452e-04
# Epoch 30/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8218e-04
# Epoch 31/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1198e-04
# Epoch 32/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9448e-04
# Epoch 33/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8865e-04
# Epoch 34/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3353e-04
# Epoch 35/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8063e-04
# Epoch 36/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4660e-04
# Epoch 37/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8202e-04
# Epoch 38/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8524e-04
# Epoch 39/39
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7557e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  Test MSE  : 20.8256
#  Test RMSE : 4.5635
#  Test MAE  : 2.7006
#  Test MAPE : 55.25%
#  Test R²   : 0.9533

# %% [markdown]
# ## 2

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 29.2MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)

# %%
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 2  # Monthly data (1 year of past data to predict next month)

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

# %%
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 2),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)
# Out:
# [I 2025-05-29 07:42:55,337] A new study created in memory with name: no-name-f24bbfc6-9922-4f85-a81f-1103ff03dc2a
# [I 2025-05-29 07:43:07,326] Trial 0 finished with value: 0.00203865945028762 and parameters: {'filters': 63, 'kernel_size': 1, 'lr': 0.0006762225122970608, 'epochs': 15, 'batch_size': 16}. Best is trial 0 with value: 0.00203865945028762.
# [I 2025-05-29 07:43:32,876] Trial 1 finished with value: 0.0007317230968813723 and parameters: {'filters': 105, 'kernel_size': 2, 'lr': 0.0010611346419233767, 'epochs': 36, 'batch_size': 8}. Best is trial 1 with value: 0.0007317230968813723.
# [I 2025-05-29 07:43:46,306] Trial 2 finished with value: 0.0014997309966323276 and parameters: {'filters': 49, 'kernel_size': 1, 'lr': 0.000581188056532699, 'epochs': 37, 'batch_size': 16}. Best is trial 1 with value: 0.0007317230968813723.
# [I 2025-05-29 07:43:59,948] Trial 3 finished with value: 0.002767225378192961 and parameters: {'filters': 41, 'kernel_size': 1, 'lr': 0.0003054671900522137, 'epochs': 38, 'batch_size': 16}. Best is trial 1 with value: 0.0007317230968813723.
# [I 2025-05-29 07:44:11,076] Trial 4 finished with value: 0.013361917769846817 and parameters: {'filters': 66, 'kernel_size': 1, 'lr': 0.0001262255749601517, 'epochs': 26, 'batch_size': 16}. Best is trial 1 with value: 0.0007317230968813723.
# [I 2025-05-29 07:44:24,654] Trial 5 finished with value: 0.0006363717208538825 and parameters: {'filters': 88, 'kernel_size': 1, 'lr': 0.007028901670820748, 'epochs': 49, 'batch_size': 32}. Best is trial 5 with value: 0.0006363717208538825.
# [I 2025-05-29 07:44:31,798] Trial 6 finished with value: 0.0005912064079893753 and parameters: {'filters': 90, 'kernel_size': 2, 'lr': 0.008837392648415756, 'epochs': 17, 'batch_size': 16}. Best is trial 6 with value: 0.0005912064079893753.
# [I 2025-05-29 07:44:38,763] Trial 7 finished with value: 0.0007807946725127598 and parameters: {'filters': 66, 'kernel_size': 1, 'lr': 0.007995541485425618, 'epochs': 23, 'batch_size': 16}. Best is trial 6 with value: 0.0005912064079893753.
# [I 2025-05-29 07:44:47,656] Trial 8 finished with value: 0.0005307341149697701 and parameters: {'filters': 97, 'kernel_size': 1, 'lr': 0.005434802770455547, 'epochs': 24, 'batch_size': 16}. Best is trial 8 with value: 0.0005307341149697701.
# [I 2025-05-29 07:44:57,097] Trial 9 finished with value: 0.0016725508515567828 and parameters: {'filters': 74, 'kernel_size': 2, 'lr': 0.001951234636896147, 'epochs': 22, 'batch_size': 32}. Best is trial 8 with value: 0.0005307341149697701.
# [I 2025-05-29 07:45:03,076] Trial 10 finished with value: 0.0006802229327149689 and parameters: {'filters': 127, 'kernel_size': 2, 'lr': 0.0026889346599081646, 'epochs': 12, 'batch_size': 8}. Best is trial 8 with value: 0.0005307341149697701.
# [I 2025-05-29 07:45:10,167] Trial 11 finished with value: 0.001125676402201255 and parameters: {'filters': 96, 'kernel_size': 2, 'lr': 0.0039819726889552655, 'epochs': 17, 'batch_size': 16}. Best is trial 8 with value: 0.0005307341149697701.
# [I 2025-05-29 07:45:19,956] Trial 12 finished with value: 0.0005247853987384588 and parameters: {'filters': 119, 'kernel_size': 2, 'lr': 0.008670584175559347, 'epochs': 31, 'batch_size': 16}. Best is trial 12 with value: 0.0005247853987384588.
# [I 2025-05-29 07:45:28,118] Trial 13 finished with value: 0.0007377964599678913 and parameters: {'filters': 117, 'kernel_size': 2, 'lr': 0.004048652205291402, 'epochs': 29, 'batch_size': 16}. Best is trial 12 with value: 0.0005247853987384588.
# [I 2025-05-29 07:45:39,293] Trial 14 finished with value: 0.0011811807538227488 and parameters: {'filters': 107, 'kernel_size': 1, 'lr': 0.0016394283473140947, 'epochs': 45, 'batch_size': 32}. Best is trial 12 with value: 0.0005247853987384588.
# [I 2025-05-29 07:45:50,644] Trial 15 finished with value: 0.0005101696054528778 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.0047114575876238, 'epochs': 32, 'batch_size': 8}. Best is trial 15 with value: 0.0005101696054528778.
# [I 2025-05-29 07:46:06,218] Trial 16 finished with value: 0.0005042111685421938 and parameters: {'filters': 127, 'kernel_size': 2, 'lr': 0.0030658469697561136, 'epochs': 33, 'batch_size': 8}. Best is trial 16 with value: 0.0005042111685421938.
# [I 2025-05-29 07:46:22,050] Trial 17 finished with value: 0.0004982675018254668 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.0029175072443860628, 'epochs': 32, 'batch_size': 8}. Best is trial 17 with value: 0.0004982675018254668.
# [I 2025-05-29 07:46:39,236] Trial 18 finished with value: 0.00045120044766614836 and parameters: {'filters': 115, 'kernel_size': 2, 'lr': 0.002726631428543246, 'epochs': 44, 'batch_size': 8}. Best is trial 18 with value: 0.00045120044766614836.
# [I 2025-05-29 07:46:57,361] Trial 19 finished with value: 0.00047348366448810947 and parameters: {'filters': 113, 'kernel_size': 2, 'lr': 0.0014099090079308894, 'epochs': 43, 'batch_size': 8}. Best is trial 18 with value: 0.00045120044766614836.
# [I 2025-05-29 07:47:14,285] Trial 20 finished with value: 0.0007180142468617609 and parameters: {'filters': 110, 'kernel_size': 2, 'lr': 0.0013876268029207994, 'epochs': 42, 'batch_size': 8}. Best is trial 18 with value: 0.00045120044766614836.
# [I 2025-05-29 07:47:28,269] Trial 21 finished with value: 0.00040831374644767493 and parameters: {'filters': 116, 'kernel_size': 2, 'lr': 0.002435347815568997, 'epochs': 43, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:47:44,953] Trial 22 finished with value: 0.0010710376567052056 and parameters: {'filters': 115, 'kernel_size': 2, 'lr': 0.0006905142120063253, 'epochs': 50, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:47:58,762] Trial 23 finished with value: 0.00042869891816129285 and parameters: {'filters': 102, 'kernel_size': 2, 'lr': 0.0021525829048760717, 'epochs': 44, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:48:13,950] Trial 24 finished with value: 0.00041225864940012497 and parameters: {'filters': 101, 'kernel_size': 2, 'lr': 0.0021847859876370627, 'epochs': 46, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:48:28,073] Trial 25 finished with value: 0.0004741111382221182 and parameters: {'filters': 100, 'kernel_size': 2, 'lr': 0.0020491864131600927, 'epochs': 47, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:48:41,462] Trial 26 finished with value: 0.0010431568565157552 and parameters: {'filters': 83, 'kernel_size': 2, 'lr': 0.0009165890090967935, 'epochs': 40, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:48:56,063] Trial 27 finished with value: 0.001020341951516457 and parameters: {'filters': 102, 'kernel_size': 2, 'lr': 0.00042189855266530396, 'epochs': 46, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:49:09,049] Trial 28 finished with value: 0.0005985669025297587 and parameters: {'filters': 93, 'kernel_size': 2, 'lr': 0.0010537166800403562, 'epochs': 40, 'batch_size': 8}. Best is trial 21 with value: 0.00040831374644767493.
# [I 2025-05-29 07:49:20,151] Trial 29 finished with value: 0.0005954199878033251 and parameters: {'filters': 79, 'kernel_size': 2, 'lr': 0.0021263343152454193, 'epochs': 49, 'batch_size': 32}. Best is trial 21 with value: 0.00040831374644767493.
# Best trial: {'filters': 116, 'kernel_size': 2, 'lr': 0.002435347815568997, 'epochs': 43, 'batch_size': 8}

# %%
# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)
# Out:
# Epoch 1/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0069
# Epoch 2/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9941e-04
# Epoch 3/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7788e-04
# Epoch 4/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0280e-04
# Epoch 5/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0180e-04
# Epoch 6/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0913e-04
# Epoch 7/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8882e-04
# Epoch 8/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2229e-04
# Epoch 9/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9288e-04
# Epoch 10/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2271e-04
# Epoch 11/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6761e-04
# Epoch 12/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9135e-04
# Epoch 13/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1928e-04
# Epoch 14/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0003e-04
# Epoch 15/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2663e-04
# Epoch 16/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5303e-04
# Epoch 17/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4884e-04
# Epoch 18/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5659e-04
# Epoch 19/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1763e-04
# Epoch 20/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1037e-04
# Epoch 21/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8947e-04
# Epoch 22/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4451e-04
# Epoch 23/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6210e-04
# Epoch 24/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1680e-04
# Epoch 25/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0893e-04
# Epoch 26/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4474e-04
# Epoch 27/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.7044e-04
# Epoch 28/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8882e-04
# Epoch 29/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.8024e-04
# Epoch 30/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8829e-04
# Epoch 31/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3492e-04
# Epoch 32/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1572e-04
# Epoch 33/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6043e-04
# Epoch 34/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6372e-04
# Epoch 35/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0661e-04
# Epoch 36/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2527e-04
# Epoch 37/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2335e-04
# Epoch 38/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3298e-04
# Epoch 39/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9628e-04
# Epoch 40/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0821e-04
# Epoch 41/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9424e-04
# Epoch 42/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1947e-04
# Epoch 43/43
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5461e-04

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R2: {r2:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Test MSE: 17.6329
# Test MAE: 2.5270
# Test R2: 0.9605

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  Test MSE  : 17.6329
#  Test RMSE : 4.1992
#  Test MAE  : 2.5270
#  Test MAPE : 54.95%
#  Test R²   : 0.9605

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()

# %% [markdown]
# ## 3

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 3  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 3), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 31.3MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 07:49:48,082] A new study created in memory with name: no-name-7742e977-dfac-46a7-8839-06db50fc3708
# [I 2025-05-29 07:50:01,538] Trial 0 finished with value: 0.0010633736771220963 and parameters: {'filters': 75, 'kernel_size': 1, 'lr': 0.00041980052525042043, 'epochs': 33, 'batch_size': 8}. Best is trial 0 with value: 0.0010633736771220963.
# [I 2025-05-29 07:50:09,403] Trial 1 finished with value: 0.0008538818365195766 and parameters: {'filters': 49, 'kernel_size': 3, 'lr': 0.003401479200106907, 'epochs': 16, 'batch_size': 8}. Best is trial 1 with value: 0.0008538818365195766.
# [I 2025-05-29 07:50:20,475] Trial 2 finished with value: 0.0007359805313171819 and parameters: {'filters': 124, 'kernel_size': 1, 'lr': 0.0010695849608628274, 'epochs': 31, 'batch_size': 8}. Best is trial 2 with value: 0.0007359805313171819.
# [I 2025-05-29 07:50:25,841] Trial 3 finished with value: 0.001000167185945126 and parameters: {'filters': 83, 'kernel_size': 2, 'lr': 0.008343061819799318, 'epochs': 12, 'batch_size': 16}. Best is trial 2 with value: 0.0007359805313171819.
# [I 2025-05-29 07:50:36,535] Trial 4 finished with value: 0.0018481234437786043 and parameters: {'filters': 116, 'kernel_size': 2, 'lr': 0.0002271406599165448, 'epochs': 39, 'batch_size': 16}. Best is trial 2 with value: 0.0007359805313171819.
# [I 2025-05-29 07:50:48,613] Trial 5 finished with value: 0.0024945260859870664 and parameters: {'filters': 33, 'kernel_size': 2, 'lr': 0.0005001317389473364, 'epochs': 35, 'batch_size': 8}. Best is trial 2 with value: 0.0007359805313171819.
# [I 2025-05-29 07:50:55,507] Trial 6 finished with value: 0.0006576772041929265 and parameters: {'filters': 32, 'kernel_size': 2, 'lr': 0.007026944029779209, 'epochs': 13, 'batch_size': 8}. Best is trial 6 with value: 0.0006576772041929265.
# [I 2025-05-29 07:51:03,241] Trial 7 finished with value: 0.0007455781402920062 and parameters: {'filters': 33, 'kernel_size': 3, 'lr': 0.008160866103824348, 'epochs': 21, 'batch_size': 8}. Best is trial 6 with value: 0.0006576772041929265.
# [I 2025-05-29 07:51:12,757] Trial 8 finished with value: 0.002391723624896258 and parameters: {'filters': 126, 'kernel_size': 1, 'lr': 0.00023035893440316943, 'epochs': 31, 'batch_size': 16}. Best is trial 6 with value: 0.0006576772041929265.
# [I 2025-05-29 07:51:25,743] Trial 9 finished with value: 0.0018714108931211133 and parameters: {'filters': 101, 'kernel_size': 2, 'lr': 0.00044726926739477297, 'epochs': 49, 'batch_size': 16}. Best is trial 6 with value: 0.0006576772041929265.
# [I 2025-05-29 07:51:33,246] Trial 10 finished with value: 0.0012632118887268007 and parameters: {'filters': 61, 'kernel_size': 3, 'lr': 0.0015978160294086584, 'epochs': 22, 'batch_size': 32}. Best is trial 6 with value: 0.0006576772041929265.
# [I 2025-05-29 07:51:42,075] Trial 11 finished with value: 0.0006264863671579709 and parameters: {'filters': 97, 'kernel_size': 1, 'lr': 0.0018645193445496323, 'epochs': 23, 'batch_size': 8}. Best is trial 11 with value: 0.0006264863671579709.
# [I 2025-05-29 07:51:47,529] Trial 12 finished with value: 0.0024753298591046282 and parameters: {'filters': 99, 'kernel_size': 1, 'lr': 0.00311380130701922, 'epochs': 10, 'batch_size': 32}. Best is trial 11 with value: 0.0006264863671579709.
# [I 2025-05-29 07:51:55,868] Trial 13 finished with value: 0.0005066737115460759 and parameters: {'filters': 87, 'kernel_size': 1, 'lr': 0.003653251162379919, 'epochs': 23, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:06,754] Trial 14 finished with value: 0.0006349494457632924 and parameters: {'filters': 91, 'kernel_size': 1, 'lr': 0.002526234006943596, 'epochs': 22, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:16,822] Trial 15 finished with value: 0.0009000039475116258 and parameters: {'filters': 73, 'kernel_size': 1, 'lr': 0.001416083486959464, 'epochs': 25, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:25,170] Trial 16 finished with value: 0.007676339882891625 and parameters: {'filters': 108, 'kernel_size': 1, 'lr': 0.00010971164534358567, 'epochs': 26, 'batch_size': 32}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:32,435] Trial 17 finished with value: 0.000580890637744839 and parameters: {'filters': 84, 'kernel_size': 1, 'lr': 0.004404633800199996, 'epochs': 18, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:40,421] Trial 18 finished with value: 0.0005225619776562477 and parameters: {'filters': 64, 'kernel_size': 1, 'lr': 0.004665710283772722, 'epochs': 17, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:47,227] Trial 19 finished with value: 0.0010975309075244393 and parameters: {'filters': 64, 'kernel_size': 2, 'lr': 0.005112872218151289, 'epochs': 17, 'batch_size': 32}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:52:59,520] Trial 20 finished with value: 0.0015307709836633876 and parameters: {'filters': 52, 'kernel_size': 2, 'lr': 0.0007346723286047863, 'epochs': 39, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:53:06,800] Trial 21 finished with value: 0.0005390099831856787 and parameters: {'filters': 85, 'kernel_size': 1, 'lr': 0.004143334825613226, 'epochs': 18, 'batch_size': 8}. Best is trial 13 with value: 0.0005066737115460759.
# [I 2025-05-29 07:53:17,148] Trial 22 finished with value: 0.0004410852367679278 and parameters: {'filters': 66, 'kernel_size': 1, 'lr': 0.0053487267575535805, 'epochs': 28, 'batch_size': 8}. Best is trial 22 with value: 0.0004410852367679278.
# [I 2025-05-29 07:53:27,339] Trial 23 finished with value: 0.0005083826351134727 and parameters: {'filters': 68, 'kernel_size': 1, 'lr': 0.005666551917726735, 'epochs': 27, 'batch_size': 8}. Best is trial 22 with value: 0.0004410852367679278.
# [I 2025-05-29 07:53:36,822] Trial 24 finished with value: 0.0007702678897961354 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.002366774294320876, 'epochs': 27, 'batch_size': 8}. Best is trial 22 with value: 0.0004410852367679278.
# [I 2025-05-29 07:53:46,532] Trial 25 finished with value: 0.0006194442394189537 and parameters: {'filters': 50, 'kernel_size': 1, 'lr': 0.006290536886892052, 'epochs': 28, 'batch_size': 8}. Best is trial 22 with value: 0.0004410852367679278.
# [I 2025-05-29 07:53:58,614] Trial 26 finished with value: 0.00040153942245524377 and parameters: {'filters': 58, 'kernel_size': 1, 'lr': 0.0059521361034140996, 'epochs': 37, 'batch_size': 8}. Best is trial 26 with value: 0.00040153942245524377.
# [I 2025-05-29 07:54:13,313] Trial 27 finished with value: 0.0004566482772740225 and parameters: {'filters': 41, 'kernel_size': 2, 'lr': 0.009861520445963686, 'epochs': 46, 'batch_size': 8}. Best is trial 26 with value: 0.00040153942245524377.
# [I 2025-05-29 07:54:25,468] Trial 28 finished with value: 0.0004700889791517208 and parameters: {'filters': 42, 'kernel_size': 2, 'lr': 0.007719111709747743, 'epochs': 48, 'batch_size': 16}. Best is trial 26 with value: 0.00040153942245524377.
# [I 2025-05-29 07:54:38,726] Trial 29 finished with value: 0.0005979363049846143 and parameters: {'filters': 55, 'kernel_size': 3, 'lr': 0.00828061646163164, 'epochs': 46, 'batch_size': 32}. Best is trial 26 with value: 0.00040153942245524377.
# Best trial: {'filters': 58, 'kernel_size': 1, 'lr': 0.0059521361034140996, 'epochs': 37, 'batch_size': 8}
# Epoch 1/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0055
# Epoch 2/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0167e-04
# Epoch 3/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9544e-04
# Epoch 4/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6103e-04
# Epoch 5/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2693e-04
# Epoch 6/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7911e-04
# Epoch 7/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8474e-04
# Epoch 8/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2761e-04
# Epoch 9/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4074e-04
# Epoch 10/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0172e-04
# Epoch 11/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6304e-04
# Epoch 12/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1286e-04
# Epoch 13/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1192e-04
# Epoch 14/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6415e-04
# Epoch 15/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2336e-04
# Epoch 16/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9281e-04
# Epoch 17/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3655e-04
# Epoch 18/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0234e-04
# Epoch 19/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0840e-04
# Epoch 20/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9280e-04
# Epoch 21/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3376e-04
# Epoch 22/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5986e-04
# Epoch 23/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6787e-04
# Epoch 24/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0879e-04
# Epoch 25/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5941e-04
# Epoch 26/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6627e-04
# Epoch 27/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9842e-04
# Epoch 28/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7058e-04
# Epoch 29/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6136e-04
# Epoch 30/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5620e-04
# Epoch 31/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8248e-04
# Epoch 32/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6782e-04
# Epoch 33/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2009e-04
# Epoch 34/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0636e-04
# Epoch 35/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4034e-04
# Epoch 36/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9889e-04
# Epoch 37/37
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1960e-04
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7df8ed402c00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7df8ed402c00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  Test MSE  : 19.2178
#  Test RMSE : 4.3838
#  Test MAE  : 2.7766
#  Test MAPE : 63.39%
#  Test R²   : 0.9575

# %% [markdown]
# ## 4

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 4  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 4), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 8.90MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 07:59:21,325] A new study created in memory with name: no-name-d751b7c5-bee1-4676-b0d9-97f431cc5df1
# [I 2025-05-29 07:59:35,269] Trial 0 finished with value: 0.0009163244200559953 and parameters: {'filters': 57, 'kernel_size': 4, 'lr': 0.0017490216498243325, 'epochs': 49, 'batch_size': 16}. Best is trial 0 with value: 0.0009163244200559953.
# [I 2025-05-29 07:59:43,654] Trial 1 finished with value: 0.001205930932580183 and parameters: {'filters': 108, 'kernel_size': 2, 'lr': 0.0015105653009775456, 'epochs': 29, 'batch_size': 32}. Best is trial 0 with value: 0.0009163244200559953.
# [I 2025-05-29 07:59:52,378] Trial 2 finished with value: 0.0009392094895398865 and parameters: {'filters': 82, 'kernel_size': 2, 'lr': 0.002438500206620576, 'epochs': 28, 'batch_size': 16}. Best is trial 0 with value: 0.0009163244200559953.
# [I 2025-05-29 08:00:03,408] Trial 3 finished with value: 0.007449328899383545 and parameters: {'filters': 80, 'kernel_size': 2, 'lr': 0.00011355211111982924, 'epochs': 43, 'batch_size': 32}. Best is trial 0 with value: 0.0009163244200559953.
# [I 2025-05-29 08:00:11,567] Trial 4 finished with value: 0.0014156243026567001 and parameters: {'filters': 86, 'kernel_size': 1, 'lr': 0.0011318651882508328, 'epochs': 21, 'batch_size': 16}. Best is trial 0 with value: 0.0009163244200559953.
# [I 2025-05-29 08:00:18,432] Trial 5 finished with value: 0.0008916983254797136 and parameters: {'filters': 87, 'kernel_size': 1, 'lr': 0.0021222046915874804, 'epochs': 21, 'batch_size': 16}. Best is trial 5 with value: 0.0008916983254797136.
# [I 2025-05-29 08:00:29,974] Trial 6 finished with value: 0.002432449022307992 and parameters: {'filters': 104, 'kernel_size': 3, 'lr': 0.00012032705709054147, 'epochs': 43, 'batch_size': 16}. Best is trial 5 with value: 0.0008916983254797136.
# [I 2025-05-29 08:00:39,907] Trial 7 finished with value: 0.0023756800510454923 and parameters: {'filters': 46, 'kernel_size': 2, 'lr': 0.0012223008457072917, 'epochs': 35, 'batch_size': 32}. Best is trial 5 with value: 0.0008916983254797136.
# [I 2025-05-29 08:00:50,795] Trial 8 finished with value: 0.0008824813946072633 and parameters: {'filters': 101, 'kernel_size': 1, 'lr': 0.00224586798409291, 'epochs': 38, 'batch_size': 16}. Best is trial 8 with value: 0.0008824813946072633.
# [I 2025-05-29 08:00:56,889] Trial 9 finished with value: 0.0015422760916408151 and parameters: {'filters': 58, 'kernel_size': 3, 'lr': 0.0017584503176045212, 'epochs': 10, 'batch_size': 8}. Best is trial 8 with value: 0.0008824813946072633.
# [I 2025-05-29 08:01:10,402] Trial 10 finished with value: 0.0008650011053153624 and parameters: {'filters': 128, 'kernel_size': 1, 'lr': 0.008839587772906651, 'epochs': 37, 'batch_size': 8}. Best is trial 10 with value: 0.0008650011053153624.
# [I 2025-05-29 08:01:23,806] Trial 11 finished with value: 0.0003558006768192475 and parameters: {'filters': 126, 'kernel_size': 1, 'lr': 0.009799118995472509, 'epochs': 35, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:01:35,966] Trial 12 finished with value: 0.0011338727150966104 and parameters: {'filters': 124, 'kernel_size': 1, 'lr': 0.008839669974979914, 'epochs': 35, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:01:44,699] Trial 13 finished with value: 0.0005546509491978213 and parameters: {'filters': 127, 'kernel_size': 1, 'lr': 0.00959565272045645, 'epochs': 23, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:01:53,774] Trial 14 finished with value: 0.000722592065964515 and parameters: {'filters': 115, 'kernel_size': 4, 'lr': 0.004698024547956867, 'epochs': 21, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:03,254] Trial 15 finished with value: 0.0019379132815326254 and parameters: {'filters': 118, 'kernel_size': 1, 'lr': 0.000267993784346764, 'epochs': 25, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:11,756] Trial 16 finished with value: 0.0009716105269035324 and parameters: {'filters': 95, 'kernel_size': 3, 'lr': 0.004156423755916965, 'epochs': 13, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:20,243] Trial 17 finished with value: 0.0008272470440715551 and parameters: {'filters': 114, 'kernel_size': 2, 'lr': 0.004528386069160158, 'epochs': 15, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:31,893] Trial 18 finished with value: 0.001668873941525817 and parameters: {'filters': 34, 'kernel_size': 1, 'lr': 0.0005455836459958154, 'epochs': 31, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:42,457] Trial 19 finished with value: 0.0005495956914577013 and parameters: {'filters': 67, 'kernel_size': 2, 'lr': 0.00978137554442936, 'epochs': 25, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:02:54,880] Trial 20 finished with value: 0.0005897588901765024 and parameters: {'filters': 68, 'kernel_size': 2, 'lr': 0.005847844487499959, 'epochs': 32, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:04,521] Trial 21 finished with value: 0.0006400034277855108 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.008700299961651777, 'epochs': 25, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:11,883] Trial 22 finished with value: 0.0008847176601799825 and parameters: {'filters': 70, 'kernel_size': 2, 'lr': 0.003332523067704839, 'epochs': 17, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:22,032] Trial 23 finished with value: 0.0007720312763315936 and parameters: {'filters': 122, 'kernel_size': 1, 'lr': 0.006251210953786795, 'epochs': 25, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:30,401] Trial 24 finished with value: 0.000762907632937034 and parameters: {'filters': 96, 'kernel_size': 3, 'lr': 0.009702974337528168, 'epochs': 18, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:41,056] Trial 25 finished with value: 0.0010385896603111178 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.0032887420635778365, 'epochs': 42, 'batch_size': 32}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:03:50,707] Trial 26 finished with value: 0.001297654482186772 and parameters: {'filters': 109, 'kernel_size': 1, 'lr': 0.0005927777672418225, 'epochs': 27, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:04:01,676] Trial 27 finished with value: 0.0005156223924132064 and parameters: {'filters': 59, 'kernel_size': 1, 'lr': 0.007124391101076771, 'epochs': 33, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:04:13,395] Trial 28 finished with value: 0.0006425946048693731 and parameters: {'filters': 56, 'kernel_size': 2, 'lr': 0.006281965599640196, 'epochs': 33, 'batch_size': 8}. Best is trial 11 with value: 0.0003558006768192475.
# [I 2025-05-29 08:04:24,517] Trial 29 finished with value: 0.001437670987797901 and parameters: {'filters': 60, 'kernel_size': 4, 'lr': 0.0006824996412587023, 'epochs': 48, 'batch_size': 32}. Best is trial 11 with value: 0.0003558006768192475.
# Best trial: {'filters': 126, 'kernel_size': 1, 'lr': 0.009799118995472509, 'epochs': 35, 'batch_size': 8}
# Epoch 1/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0117
# Epoch 2/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 3/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5590e-04
# Epoch 4/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4570e-04
# Epoch 5/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5853e-04
# Epoch 6/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6915e-04
# Epoch 7/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3345e-04
# Epoch 8/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9838e-04
# Epoch 9/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1828e-04
# Epoch 10/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5021e-04
# Epoch 11/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9596e-04
# Epoch 12/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8949e-04
# Epoch 13/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1578e-04
# Epoch 14/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7830e-04
# Epoch 15/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8879e-04
# Epoch 16/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4237e-04
# Epoch 17/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1869e-04
# Epoch 18/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0413e-04
# Epoch 19/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1539e-04
# Epoch 20/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3803e-04
# Epoch 21/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9186e-04
# Epoch 22/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5608e-04
# Epoch 23/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8751e-04
# Epoch 24/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0911e-04
# Epoch 25/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1099e-04
# Epoch 26/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0792e-04
# Epoch 27/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2234e-04
# Epoch 28/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2817e-04
# Epoch 29/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8603e-04
# Epoch 30/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7289e-04
# Epoch 31/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4789e-04
# Epoch 32/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5123e-04
# Epoch 33/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0248e-04
# Epoch 34/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9793e-04
# Epoch 35/35
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4342e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  Test MSE  : 19.5825
#  Test RMSE : 4.4252
#  Test MAE  : 2.9984
#  Test MAPE : 75.83%
#  Test R²   : 0.9567

# %% [markdown]
# ## 5

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations
# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 5  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 5), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 8.47MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 08:04:51,532] A new study created in memory with name: no-name-f796b23f-7c52-4527-b392-faac61771a66
# [I 2025-05-29 08:04:59,152] Trial 0 finished with value: 0.007847430766560137 and parameters: {'filters': 128, 'kernel_size': 3, 'lr': 0.00010986162414648352, 'epochs': 23, 'batch_size': 32}. Best is trial 0 with value: 0.007847430766560137.
# [I 2025-05-29 08:05:09,534] Trial 1 finished with value: 0.0009141289629042149 and parameters: {'filters': 36, 'kernel_size': 4, 'lr': 0.008466841898117248, 'epochs': 44, 'batch_size': 32}. Best is trial 1 with value: 0.0009141289629042149.
# [I 2025-05-29 08:05:17,576] Trial 2 finished with value: 0.0012987014197278768 and parameters: {'filters': 45, 'kernel_size': 4, 'lr': 0.001647524912297091, 'epochs': 21, 'batch_size': 8}. Best is trial 1 with value: 0.0009141289629042149.
# [I 2025-05-29 08:05:27,344] Trial 3 finished with value: 0.0010581064561847597 and parameters: {'filters': 101, 'kernel_size': 2, 'lr': 0.0027082803026696766, 'epochs': 41, 'batch_size': 32}. Best is trial 1 with value: 0.0009141289629042149.
# [I 2025-05-29 08:05:38,990] Trial 4 finished with value: 0.0008532088395440951 and parameters: {'filters': 42, 'kernel_size': 4, 'lr': 0.007733951837347722, 'epochs': 44, 'batch_size': 32}. Best is trial 4 with value: 0.0008532088395440951.
# [I 2025-05-29 08:05:46,858] Trial 5 finished with value: 0.0023680076119489968 and parameters: {'filters': 50, 'kernel_size': 5, 'lr': 0.0002777718257145222, 'epochs': 22, 'batch_size': 16}. Best is trial 4 with value: 0.0008532088395440951.
# [I 2025-05-29 08:05:54,706] Trial 6 finished with value: 0.0014353171670033287 and parameters: {'filters': 112, 'kernel_size': 4, 'lr': 0.005167708271311386, 'epochs': 12, 'batch_size': 32}. Best is trial 4 with value: 0.0008532088395440951.
# [I 2025-05-29 08:06:02,580] Trial 7 finished with value: 0.002867802861146629 and parameters: {'filters': 126, 'kernel_size': 2, 'lr': 0.0002166274761732164, 'epochs': 24, 'batch_size': 32}. Best is trial 4 with value: 0.0008532088395440951.
# [I 2025-05-29 08:06:12,340] Trial 8 finished with value: 0.0010528151275745283 and parameters: {'filters': 102, 'kernel_size': 5, 'lr': 0.0074634925146749975, 'epochs': 34, 'batch_size': 32}. Best is trial 4 with value: 0.0008532088395440951.
# [I 2025-05-29 08:06:23,647] Trial 9 finished with value: 0.0006268489523790777 and parameters: {'filters': 88, 'kernel_size': 5, 'lr': 0.0030803476405565394, 'epochs': 34, 'batch_size': 8}. Best is trial 9 with value: 0.0006268489523790777.
# [I 2025-05-29 08:06:36,326] Trial 10 finished with value: 0.0010930835608936225 and parameters: {'filters': 69, 'kernel_size': 3, 'lr': 0.0007723244919088214, 'epochs': 35, 'batch_size': 8}. Best is trial 9 with value: 0.0006268489523790777.
# [I 2025-05-29 08:06:52,426] Trial 11 finished with value: 0.0005656455226320153 and parameters: {'filters': 76, 'kernel_size': 5, 'lr': 0.0031401836678081664, 'epochs': 50, 'batch_size': 8}. Best is trial 11 with value: 0.0005656455226320153.
# [I 2025-05-29 08:07:08,762] Trial 12 finished with value: 0.0005481437547132373 and parameters: {'filters': 78, 'kernel_size': 5, 'lr': 0.002636498724721784, 'epochs': 50, 'batch_size': 8}. Best is trial 12 with value: 0.0005481437547132373.
# [I 2025-05-29 08:07:24,254] Trial 13 finished with value: 0.0008842767274472862 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.00074832001017218, 'epochs': 50, 'batch_size': 8}. Best is trial 12 with value: 0.0005481437547132373.
# [I 2025-05-29 08:07:38,821] Trial 14 finished with value: 0.0005477194499690086 and parameters: {'filters': 80, 'kernel_size': 5, 'lr': 0.001643658218025086, 'epochs': 50, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:07:49,916] Trial 15 finished with value: 0.0012413150495073448 and parameters: {'filters': 61, 'kernel_size': 5, 'lr': 0.001431818456146379, 'epochs': 40, 'batch_size': 16}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:08:04,927] Trial 16 finished with value: 0.0011414589340953778 and parameters: {'filters': 87, 'kernel_size': 4, 'lr': 0.0004936815753907211, 'epochs': 47, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:08:18,979] Trial 17 finished with value: 0.0008577008557040244 and parameters: {'filters': 59, 'kernel_size': 3, 'lr': 0.0016177945308350448, 'epochs': 39, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:08:29,441] Trial 18 finished with value: 0.0005902577928888301 and parameters: {'filters': 86, 'kernel_size': 2, 'lr': 0.004212005512816018, 'epochs': 30, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:08:41,763] Trial 19 finished with value: 0.0010437062980296712 and parameters: {'filters': 97, 'kernel_size': 5, 'lr': 0.0011787240492989286, 'epochs': 46, 'batch_size': 16}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:08:47,823] Trial 20 finished with value: 0.001204630360007286 and parameters: {'filters': 77, 'kernel_size': 3, 'lr': 0.002312083079651576, 'epochs': 10, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:09:02,723] Trial 21 finished with value: 0.0005533603883426016 and parameters: {'filters': 76, 'kernel_size': 5, 'lr': 0.0037227278491381095, 'epochs': 50, 'batch_size': 8}. Best is trial 14 with value: 0.0005477194499690086.
# [I 2025-05-29 08:09:17,443] Trial 22 finished with value: 0.0004791013343492523 and parameters: {'filters': 66, 'kernel_size': 5, 'lr': 0.004921509758521926, 'epochs': 50, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:09:32,405] Trial 23 finished with value: 0.000734145394138371 and parameters: {'filters': 58, 'kernel_size': 4, 'lr': 0.005333752848818287, 'epochs': 46, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:09:46,673] Trial 24 finished with value: 0.0007953534368425608 and parameters: {'filters': 66, 'kernel_size': 5, 'lr': 0.0022645643146642245, 'epochs': 43, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:10:03,360] Trial 25 finished with value: 0.0007649770413991064 and parameters: {'filters': 93, 'kernel_size': 4, 'lr': 0.0008634216667810996, 'epochs': 48, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:10:15,323] Trial 26 finished with value: 0.0010885106457863003 and parameters: {'filters': 83, 'kernel_size': 5, 'lr': 0.0019732673476274515, 'epochs': 38, 'batch_size': 16}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:10:24,600] Trial 27 finished with value: 0.0007375517937665185 and parameters: {'filters': 51, 'kernel_size': 1, 'lr': 0.005305285967411459, 'epochs': 29, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:10:40,009] Trial 28 finished with value: 0.0009745089046191424 and parameters: {'filters': 108, 'kernel_size': 4, 'lr': 0.0005369535242996706, 'epochs': 47, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# [I 2025-05-29 08:10:46,854] Trial 29 finished with value: 0.00409167492762208 and parameters: {'filters': 71, 'kernel_size': 5, 'lr': 0.0001227626174424666, 'epochs': 17, 'batch_size': 8}. Best is trial 22 with value: 0.0004791013343492523.
# Best trial: {'filters': 66, 'kernel_size': 5, 'lr': 0.004921509758521926, 'epochs': 50, 'batch_size': 8}
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0058
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3496e-04
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1286e-04
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0658e-04
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5342e-04
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1999e-04
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4054e-04
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3270e-04
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7423e-04
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2889e-04
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6412e-04
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3923e-04
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0423e-04
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2890e-04
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3167e-04
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2473e-04
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2737e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8651e-04
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1326e-04
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3570e-04
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9076e-04
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6051e-04
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3766e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2767e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8743e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2014e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4063e-04
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7079e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7676e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3201e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8035e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9784e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5710e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7322e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4559e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2211e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8857e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2568e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0221e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1778e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4088e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1348e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0301e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7811e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6148e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6350e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2760e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4709e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  Test MSE  : 15.3173
#  Test RMSE : 3.9137
#  Test MAE  : 2.5415
#  Test MAPE : 59.06%
#  Test R²   : 0.9661

# %% [markdown]
# ## 6

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations
# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()
# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 6  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 6), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 27.6MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 08:11:18,031] A new study created in memory with name: no-name-665ee135-a555-4a80-b059-c80865898b76
# [I 2025-05-29 08:11:31,958] Trial 0 finished with value: 0.0013485512123831238 and parameters: {'filters': 115, 'kernel_size': 2, 'lr': 0.0006016650168691709, 'epochs': 21, 'batch_size': 8}. Best is trial 0 with value: 0.0013485512123831238.
# [I 2025-05-29 08:11:47,095] Trial 1 finished with value: 0.0012404508985734235 and parameters: {'filters': 104, 'kernel_size': 1, 'lr': 0.000489345475551935, 'epochs': 44, 'batch_size': 8}. Best is trial 1 with value: 0.0012404508985734235.
# [I 2025-05-29 08:11:56,795] Trial 2 finished with value: 0.0014744908839929849 and parameters: {'filters': 56, 'kernel_size': 5, 'lr': 0.0018958146807826234, 'epochs': 34, 'batch_size': 32}. Best is trial 1 with value: 0.0012404508985734235.
# [I 2025-05-29 08:12:03,660] Trial 3 finished with value: 0.0016739767500742648 and parameters: {'filters': 108, 'kernel_size': 3, 'lr': 0.0018188279153330887, 'epochs': 23, 'batch_size': 32}. Best is trial 1 with value: 0.0012404508985734235.
# [I 2025-05-29 08:12:10,393] Trial 4 finished with value: 0.001995069173669132 and parameters: {'filters': 39, 'kernel_size': 4, 'lr': 0.005872184535564546, 'epochs': 12, 'batch_size': 16}. Best is trial 1 with value: 0.0012404508985734235.
# [I 2025-05-29 08:12:21,911] Trial 5 finished with value: 0.001309874724635544 and parameters: {'filters': 53, 'kernel_size': 3, 'lr': 0.001439145596844561, 'epochs': 41, 'batch_size': 16}. Best is trial 1 with value: 0.0012404508985734235.
# [I 2025-05-29 08:12:36,737] Trial 6 finished with value: 0.0010212523920927197 and parameters: {'filters': 61, 'kernel_size': 1, 'lr': 0.000867834134198446, 'epochs': 44, 'batch_size': 8}. Best is trial 6 with value: 0.0010212523920927197.
# [I 2025-05-29 08:12:47,326] Trial 7 finished with value: 0.0009630263181558499 and parameters: {'filters': 40, 'kernel_size': 3, 'lr': 0.009214686097375552, 'epochs': 35, 'batch_size': 16}. Best is trial 7 with value: 0.0009630263181558499.
# [I 2025-05-29 08:12:58,703] Trial 8 finished with value: 0.0012796431886575494 and parameters: {'filters': 107, 'kernel_size': 5, 'lr': 0.0008584154728085605, 'epochs': 31, 'batch_size': 8}. Best is trial 7 with value: 0.0009630263181558499.
# [I 2025-05-29 08:13:08,903] Trial 9 finished with value: 0.001461330287080879 and parameters: {'filters': 92, 'kernel_size': 2, 'lr': 0.002065310957684172, 'epochs': 39, 'batch_size': 32}. Best is trial 7 with value: 0.0009630263181558499.
# [I 2025-05-29 08:13:21,895] Trial 10 finished with value: 0.0026997195673175156 and parameters: {'filters': 74, 'kernel_size': 6, 'lr': 0.00012509867319116964, 'epochs': 49, 'batch_size': 16}. Best is trial 7 with value: 0.0009630263181558499.
# [I 2025-05-29 08:13:37,710] Trial 11 finished with value: 0.0003674574933635692 and parameters: {'filters': 33, 'kernel_size': 1, 'lr': 0.00908320250051151, 'epochs': 50, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:13:51,067] Trial 12 finished with value: 0.0008675509355574226 and parameters: {'filters': 35, 'kernel_size': 2, 'lr': 0.008834076973414984, 'epochs': 49, 'batch_size': 16}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:14:03,906] Trial 13 finished with value: 0.0004875271357983972 and parameters: {'filters': 36, 'kernel_size': 1, 'lr': 0.004332253832719632, 'epochs': 49, 'batch_size': 16}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:14:20,306] Trial 14 finished with value: 0.0004708566896927853 and parameters: {'filters': 127, 'kernel_size': 1, 'lr': 0.004223312565514602, 'epochs': 50, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:14:30,383] Trial 15 finished with value: 0.0005949460367749756 and parameters: {'filters': 123, 'kernel_size': 1, 'lr': 0.0040427261161123, 'epochs': 24, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:14:46,568] Trial 16 finished with value: 0.000569008732175765 and parameters: {'filters': 84, 'kernel_size': 2, 'lr': 0.004079341331669439, 'epochs': 44, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:14:52,573] Trial 17 finished with value: 0.0017998067196458578 and parameters: {'filters': 127, 'kernel_size': 4, 'lr': 0.0002457754941561481, 'epochs': 10, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:15:06,561] Trial 18 finished with value: 0.0004867338187371691 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.0033284567840901657, 'epochs': 40, 'batch_size': 8}. Best is trial 11 with value: 0.0003674574933635692.
# [I 2025-05-29 08:15:21,989] Trial 19 finished with value: 0.00035788527263017994 and parameters: {'filters': 93, 'kernel_size': 2, 'lr': 0.006550930483049446, 'epochs': 50, 'batch_size': 8}. Best is trial 19 with value: 0.00035788527263017994.
# [I 2025-05-29 08:15:32,911] Trial 20 finished with value: 0.0010865035486252357 and parameters: {'filters': 88, 'kernel_size': 2, 'lr': 0.006440640533517742, 'epochs': 28, 'batch_size': 8}. Best is trial 19 with value: 0.00035788527263017994.
# [I 2025-05-29 08:15:49,885] Trial 21 finished with value: 0.000402480562722 and parameters: {'filters': 96, 'kernel_size': 1, 'lr': 0.003038135881710317, 'epochs': 50, 'batch_size': 8}. Best is trial 19 with value: 0.00035788527263017994.
# [I 2025-05-29 08:16:04,584] Trial 22 finished with value: 0.0005650338668298597 and parameters: {'filters': 101, 'kernel_size': 2, 'lr': 0.002923058787755986, 'epochs': 46, 'batch_size': 8}. Best is trial 19 with value: 0.00035788527263017994.
# [I 2025-05-29 08:16:19,765] Trial 23 finished with value: 0.0005440788518171757 and parameters: {'filters': 96, 'kernel_size': 1, 'lr': 0.006302053984920015, 'epochs': 45, 'batch_size': 8}. Best is trial 19 with value: 0.00035788527263017994.
# [I 2025-05-29 08:16:33,347] Trial 24 finished with value: 0.0003384015678117673 and parameters: {'filters': 78, 'kernel_size': 2, 'lr': 0.009624242511055571, 'epochs': 39, 'batch_size': 8}. Best is trial 24 with value: 0.0003384015678117673.
# [I 2025-05-29 08:16:43,445] Trial 25 finished with value: 0.0014125352026894689 and parameters: {'filters': 76, 'kernel_size': 3, 'lr': 0.008348698416068006, 'epochs': 38, 'batch_size': 32}. Best is trial 24 with value: 0.0003384015678117673.
# [I 2025-05-29 08:16:55,959] Trial 26 finished with value: 0.00045542343771861243 and parameters: {'filters': 47, 'kernel_size': 2, 'lr': 0.009361434981822342, 'epochs': 36, 'batch_size': 8}. Best is trial 24 with value: 0.0003384015678117673.
# [I 2025-05-29 08:17:16,702] Trial 27 finished with value: 0.0004987950766614327 and parameters: {'filters': 71, 'kernel_size': 3, 'lr': 0.005631207254623579, 'epochs': 42, 'batch_size': 8}. Best is trial 24 with value: 0.0003384015678117673.
# [I 2025-05-29 08:17:33,366] Trial 28 finished with value: 0.00046470230154227465 and parameters: {'filters': 62, 'kernel_size': 4, 'lr': 0.006165059068447278, 'epochs': 46, 'batch_size': 8}. Best is trial 24 with value: 0.0003384015678117673.
# [I 2025-05-29 08:17:46,186] Trial 29 finished with value: 0.0014071211238236476 and parameters: {'filters': 114, 'kernel_size': 2, 'lr': 0.00041811542429917434, 'epochs': 32, 'batch_size': 8}. Best is trial 24 with value: 0.0003384015678117673.
# Best trial: {'filters': 78, 'kernel_size': 2, 'lr': 0.009624242511055571, 'epochs': 39, 'batch_size': 8}
# Epoch 1/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0087
# Epoch 2/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 3/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 4/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6295e-04
# Epoch 5/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9366e-04
# Epoch 6/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2688e-04
# Epoch 7/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9554e-04
# Epoch 8/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7497e-04
# Epoch 9/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2654e-04
# Epoch 10/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0599e-04
# Epoch 11/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5746e-04
# Epoch 12/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3213e-04
# Epoch 13/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8238e-04
# Epoch 14/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0354e-04
# Epoch 15/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4251e-04
# Epoch 16/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4242e-04
# Epoch 17/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3413e-04
# Epoch 18/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2936e-04
# Epoch 19/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7871e-04
# Epoch 20/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0899e-04
# Epoch 21/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2183e-04
# Epoch 22/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9969e-04
# Epoch 23/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7548e-04
# Epoch 24/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2218e-04
# Epoch 25/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5322e-04
# Epoch 26/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0609e-04
# Epoch 27/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8478e-04
# Epoch 28/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3555e-04
# Epoch 29/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8486e-04
# Epoch 30/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8182e-04
# Epoch 31/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3234e-04
# Epoch 32/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2064e-04
# Epoch 33/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5576e-04
# Epoch 34/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9547e-04
# Epoch 35/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6293e-04
# Epoch 36/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1332e-04
# Epoch 37/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6818e-04
# Epoch 38/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6551e-04
# Epoch 39/39
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4573e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  Test MSE  : 22.0311
#  Test RMSE : 4.6937
#  Test MAE  : 3.3730
#  Test MAPE : 83.52%
#  Test R²   : 0.9513

# %% [markdown]
# ## 7

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations
# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 7  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 7), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 8.90MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 08:18:14,543] A new study created in memory with name: no-name-895ceb85-6f16-403b-a07f-495ab1f51354
# [I 2025-05-29 08:18:29,474] Trial 0 finished with value: 0.0018656942605351408 and parameters: {'filters': 79, 'kernel_size': 3, 'lr': 0.00019245884631540993, 'epochs': 40, 'batch_size': 8}. Best is trial 0 with value: 0.0018656942605351408.
# [I 2025-05-29 08:18:45,142] Trial 1 finished with value: 0.0004907565889880061 and parameters: {'filters': 115, 'kernel_size': 2, 'lr': 0.002075649388428045, 'epochs': 43, 'batch_size': 8}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:18:54,735] Trial 2 finished with value: 0.0007807811198290437 and parameters: {'filters': 54, 'kernel_size': 2, 'lr': 0.003802367498378151, 'epochs': 24, 'batch_size': 8}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:03,696] Trial 3 finished with value: 0.0026118255142743387 and parameters: {'filters': 38, 'kernel_size': 1, 'lr': 0.00041219891974401957, 'epochs': 36, 'batch_size': 32}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:14,271] Trial 4 finished with value: 0.0015969511296134442 and parameters: {'filters': 73, 'kernel_size': 4, 'lr': 0.000169738437577963, 'epochs': 25, 'batch_size': 8}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:28,197] Trial 5 finished with value: 0.0009206365163360412 and parameters: {'filters': 49, 'kernel_size': 6, 'lr': 0.002294743173431412, 'epochs': 36, 'batch_size': 8}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:37,654] Trial 6 finished with value: 0.0017561339094148327 and parameters: {'filters': 85, 'kernel_size': 2, 'lr': 0.0002585402698491414, 'epochs': 22, 'batch_size': 8}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:46,061] Trial 7 finished with value: 0.009005912715413919 and parameters: {'filters': 105, 'kernel_size': 5, 'lr': 0.00011042794061310272, 'epochs': 27, 'batch_size': 32}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:19:53,056] Trial 8 finished with value: 0.0012994248633428167 and parameters: {'filters': 38, 'kernel_size': 1, 'lr': 0.004591177631967259, 'epochs': 23, 'batch_size': 32}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:20:00,700] Trial 9 finished with value: 0.0035338096786290407 and parameters: {'filters': 54, 'kernel_size': 6, 'lr': 0.0001721191917374431, 'epochs': 21, 'batch_size': 16}. Best is trial 1 with value: 0.0004907565889880061.
# [I 2025-05-29 08:20:13,170] Trial 10 finished with value: 0.00043368085850185406 and parameters: {'filters': 127, 'kernel_size': 4, 'lr': 0.009808807398458966, 'epochs': 50, 'batch_size': 16}. Best is trial 10 with value: 0.00043368085850185406.
# [I 2025-05-29 08:20:25,245] Trial 11 finished with value: 0.00038575599319301546 and parameters: {'filters': 125, 'kernel_size': 4, 'lr': 0.007757947563287251, 'epochs': 47, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:20:38,017] Trial 12 finished with value: 0.0007993261291024586 and parameters: {'filters': 127, 'kernel_size': 4, 'lr': 0.008369042118651887, 'epochs': 49, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:20:50,579] Trial 13 finished with value: 0.0004411080735735595 and parameters: {'filters': 101, 'kernel_size': 7, 'lr': 0.008522957246413002, 'epochs': 50, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:02,829] Trial 14 finished with value: 0.0016441429518939306 and parameters: {'filters': 126, 'kernel_size': 5, 'lr': 0.0010090850584285012, 'epochs': 45, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:09,886] Trial 15 finished with value: 0.001269709939757983 and parameters: {'filters': 111, 'kernel_size': 3, 'lr': 0.0048942654308563585, 'epochs': 16, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:19,573] Trial 16 finished with value: 0.000505382296978496 and parameters: {'filters': 118, 'kernel_size': 4, 'lr': 0.00968465035521838, 'epochs': 33, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:25,374] Trial 17 finished with value: 0.002306525236538922 and parameters: {'filters': 94, 'kernel_size': 5, 'lr': 0.0008607715708240956, 'epochs': 10, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:38,317] Trial 18 finished with value: 0.0007922444153033817 and parameters: {'filters': 68, 'kernel_size': 3, 'lr': 0.0022614671339183977, 'epochs': 45, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:21:50,070] Trial 19 finished with value: 0.0012239188169284414 and parameters: {'filters': 95, 'kernel_size': 4, 'lr': 0.0009539356568550039, 'epochs': 40, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:22:03,532] Trial 20 finished with value: 0.0005324650313317155 and parameters: {'filters': 120, 'kernel_size': 6, 'lr': 0.00587612868609031, 'epochs': 50, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:22:16,704] Trial 21 finished with value: 0.00043825040726612013 and parameters: {'filters': 105, 'kernel_size': 7, 'lr': 0.007518074330568396, 'epochs': 50, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:22:28,800] Trial 22 finished with value: 0.0005336618875541413 and parameters: {'filters': 128, 'kernel_size': 7, 'lr': 0.0031222321937985366, 'epochs': 46, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:22:40,131] Trial 23 finished with value: 0.0006941733784818401 and parameters: {'filters': 108, 'kernel_size': 5, 'lr': 0.006432927219279259, 'epochs': 40, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:22:52,521] Trial 24 finished with value: 0.0012423868077651907 and parameters: {'filters': 119, 'kernel_size': 3, 'lr': 0.001537671997968749, 'epochs': 47, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:23:03,451] Trial 25 finished with value: 0.001227297378742757 and parameters: {'filters': 99, 'kernel_size': 5, 'lr': 0.006546543641634416, 'epochs': 42, 'batch_size': 32}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:23:15,990] Trial 26 finished with value: 0.0006957497195495913 and parameters: {'filters': 112, 'kernel_size': 6, 'lr': 0.0031730695328234483, 'epochs': 48, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:23:33,040] Trial 27 finished with value: 0.0007836037742284437 and parameters: {'filters': 88, 'kernel_size': 4, 'lr': 0.007936441091478685, 'epochs': 36, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:23:43,821] Trial 28 finished with value: 0.0006589921104023233 and parameters: {'filters': 124, 'kernel_size': 7, 'lr': 0.009951167556252687, 'epochs': 31, 'batch_size': 16}. Best is trial 11 with value: 0.00038575599319301546.
# [I 2025-05-29 08:23:56,012] Trial 29 finished with value: 0.001376919496882086 and parameters: {'filters': 104, 'kernel_size': 3, 'lr': 0.004603039266527561, 'epochs': 42, 'batch_size': 32}. Best is trial 11 with value: 0.00038575599319301546.
# Best trial: {'filters': 125, 'kernel_size': 4, 'lr': 0.007757947563287251, 'epochs': 47, 'batch_size': 16}
# Epoch 1/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0089
# Epoch 2/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 3/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 4/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010
# Epoch 5/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 6/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8536e-04
# Epoch 7/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7840e-04
# Epoch 8/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4763e-04
# Epoch 9/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5442e-04
# Epoch 10/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3549e-04
# Epoch 11/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6842e-04
# Epoch 12/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5076e-04
# Epoch 13/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4104e-04
# Epoch 14/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1124e-04
# Epoch 15/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1571e-04
# Epoch 16/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3406e-04
# Epoch 17/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1530e-04
# Epoch 18/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6063e-04
# Epoch 19/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5335e-04
# Epoch 20/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4792e-04
# Epoch 21/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8289e-04
# Epoch 22/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0845e-04
# Epoch 23/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5838e-04
# Epoch 24/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5475e-04
# Epoch 25/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7449e-04
# Epoch 26/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3427e-04
# Epoch 27/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6665e-04
# Epoch 28/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4478e-04
# Epoch 29/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1161e-04
# Epoch 30/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9276e-04
# Epoch 31/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1543e-04
# Epoch 32/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0696e-04
# Epoch 33/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8407e-04
# Epoch 34/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6830e-04
# Epoch 35/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4978e-04
# Epoch 36/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8288e-04
# Epoch 37/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0854e-04
# Epoch 38/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7193e-04
# Epoch 39/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0836e-04
# Epoch 40/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2135e-04
# Epoch 41/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6811e-04
# Epoch 42/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6993e-04
# Epoch 43/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6691e-04
# Epoch 44/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3339e-04
# Epoch 45/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2741e-04
# Epoch 46/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5815e-04
# Epoch 47/47
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9125e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  Test MSE  : 16.6611
#  Test RMSE : 4.0818
#  Test MAE  : 2.7029
#  Test MAPE : 68.69%
#  Test R²   : 0.9632

# %% [markdown]
# ## 8

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations
# LOADING THE DATASET
import gdown
# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 8  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 8), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 27.5MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 08:24:23,895] A new study created in memory with name: no-name-9e03d9e8-a468-44ff-9de6-2f2ee24ab1f2
# [I 2025-05-29 08:24:35,989] Trial 0 finished with value: 0.0065198973946583765 and parameters: {'filters': 45, 'kernel_size': 7, 'lr': 0.00013898519992263793, 'epochs': 44, 'batch_size': 32}. Best is trial 0 with value: 0.0065198973946583765.
# [I 2025-05-29 08:24:49,083] Trial 1 finished with value: 0.001691690490891536 and parameters: {'filters': 118, 'kernel_size': 4, 'lr': 0.0002958186894017614, 'epochs': 31, 'batch_size': 8}. Best is trial 1 with value: 0.001691690490891536.
# [I 2025-05-29 08:25:00,633] Trial 2 finished with value: 0.0010476845442705478 and parameters: {'filters': 85, 'kernel_size': 5, 'lr': 0.008042934891757595, 'epochs': 47, 'batch_size': 32}. Best is trial 2 with value: 0.0010476845442705478.
# [I 2025-05-29 08:25:14,347] Trial 3 finished with value: 0.0008931061796223124 and parameters: {'filters': 100, 'kernel_size': 7, 'lr': 0.0009180484066450309, 'epochs': 33, 'batch_size': 8}. Best is trial 3 with value: 0.0008931061796223124.
# [I 2025-05-29 08:25:27,878] Trial 4 finished with value: 0.0022156037448439747 and parameters: {'filters': 66, 'kernel_size': 7, 'lr': 0.00020253525344988266, 'epochs': 48, 'batch_size': 16}. Best is trial 3 with value: 0.0008931061796223124.
# [I 2025-05-29 08:25:36,048] Trial 5 finished with value: 0.001359440366892765 and parameters: {'filters': 121, 'kernel_size': 8, 'lr': 0.00027086025158641825, 'epochs': 21, 'batch_size': 8}. Best is trial 3 with value: 0.0008931061796223124.
# [I 2025-05-29 08:25:45,492] Trial 6 finished with value: 0.0013766651973128319 and parameters: {'filters': 88, 'kernel_size': 8, 'lr': 0.0032556338046020434, 'epochs': 36, 'batch_size': 32}. Best is trial 3 with value: 0.0008931061796223124.
# [I 2025-05-29 08:25:56,784] Trial 7 finished with value: 0.0015127384976949543 and parameters: {'filters': 126, 'kernel_size': 6, 'lr': 0.0005376276448219625, 'epochs': 28, 'batch_size': 8}. Best is trial 3 with value: 0.0008931061796223124.
# [I 2025-05-29 08:26:11,232] Trial 8 finished with value: 0.0007189085299614817 and parameters: {'filters': 117, 'kernel_size': 3, 'lr': 0.003755667463269116, 'epochs': 40, 'batch_size': 8}. Best is trial 8 with value: 0.0007189085299614817.
# [I 2025-05-29 08:26:23,038] Trial 9 finished with value: 0.0022795880407405398 and parameters: {'filters': 57, 'kernel_size': 2, 'lr': 0.0003457337398361738, 'epochs': 50, 'batch_size': 32}. Best is trial 8 with value: 0.0007189085299614817.
# [I 2025-05-29 08:26:29,399] Trial 10 finished with value: 0.0024503232028412945 and parameters: {'filters': 34, 'kernel_size': 1, 'lr': 0.002493833402304607, 'epochs': 11, 'batch_size': 16}. Best is trial 8 with value: 0.0007189085299614817.
# [I 2025-05-29 08:26:42,528] Trial 11 finished with value: 0.0008023077874289205 and parameters: {'filters': 102, 'kernel_size': 3, 'lr': 0.0012241137811628783, 'epochs': 39, 'batch_size': 8}. Best is trial 8 with value: 0.0007189085299614817.
# [I 2025-05-29 08:26:55,271] Trial 12 finished with value: 0.0005463148409035057 and parameters: {'filters': 105, 'kernel_size': 3, 'lr': 0.002966864585128, 'epochs': 40, 'batch_size': 8}. Best is trial 12 with value: 0.0005463148409035057.
# [I 2025-05-29 08:27:08,259] Trial 13 finished with value: 0.0006136605225037783 and parameters: {'filters': 107, 'kernel_size': 3, 'lr': 0.009175921837162376, 'epochs': 41, 'batch_size': 8}. Best is trial 12 with value: 0.0005463148409035057.
# [I 2025-05-29 08:27:18,587] Trial 14 finished with value: 0.0006847150070825592 and parameters: {'filters': 105, 'kernel_size': 4, 'lr': 0.009687017024779069, 'epochs': 27, 'batch_size': 8}. Best is trial 12 with value: 0.0005463148409035057.
# [I 2025-05-29 08:27:31,806] Trial 15 finished with value: 0.0003844945701227213 and parameters: {'filters': 76, 'kernel_size': 1, 'lr': 0.005627437329038227, 'epochs': 41, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:27:38,675] Trial 16 finished with value: 0.0010804634366650134 and parameters: {'filters': 71, 'kernel_size': 1, 'lr': 0.0019110539986247955, 'epochs': 22, 'batch_size': 16}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:27:51,736] Trial 17 finished with value: 0.0006541825277963653 and parameters: {'filters': 92, 'kernel_size': 2, 'lr': 0.00514413445373, 'epochs': 36, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:28:06,830] Trial 18 finished with value: 0.0006554069307943186 and parameters: {'filters': 75, 'kernel_size': 2, 'lr': 0.0013776557720575385, 'epochs': 44, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:28:12,133] Trial 19 finished with value: 0.0012201109687642504 and parameters: {'filters': 58, 'kernel_size': 1, 'lr': 0.0054707007613835875, 'epochs': 10, 'batch_size': 16}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:28:25,637] Trial 20 finished with value: 0.0013288785606467475 and parameters: {'filters': 77, 'kernel_size': 5, 'lr': 0.0006456049420253686, 'epochs': 35, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:28:39,161] Trial 21 finished with value: 0.0004403329367050901 and parameters: {'filters': 105, 'kernel_size': 3, 'lr': 0.005992729477424075, 'epochs': 41, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:28:54,079] Trial 22 finished with value: 0.0005364861184110244 and parameters: {'filters': 94, 'kernel_size': 3, 'lr': 0.005414752644481932, 'epochs': 44, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:29:09,513] Trial 23 finished with value: 0.0004598038940457627 and parameters: {'filters': 94, 'kernel_size': 2, 'lr': 0.005262672126860535, 'epochs': 44, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:29:24,425] Trial 24 finished with value: 0.0005160745931789279 and parameters: {'filters': 82, 'kernel_size': 2, 'lr': 0.0019714031452351846, 'epochs': 46, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:29:38,735] Trial 25 finished with value: 0.0008996317240719994 and parameters: {'filters': 95, 'kernel_size': 1, 'lr': 0.006585212892505718, 'epochs': 42, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:29:54,700] Trial 26 finished with value: 0.0004350455419626087 and parameters: {'filters': 113, 'kernel_size': 2, 'lr': 0.00395562759403148, 'epochs': 50, 'batch_size': 8}. Best is trial 15 with value: 0.0003844945701227213.
# [I 2025-05-29 08:30:11,100] Trial 27 finished with value: 0.00036150884989183396 and parameters: {'filters': 112, 'kernel_size': 4, 'lr': 0.004061216334591779, 'epochs': 50, 'batch_size': 8}. Best is trial 27 with value: 0.00036150884989183396.
# [I 2025-05-29 08:30:24,170] Trial 28 finished with value: 0.0006354299063483874 and parameters: {'filters': 115, 'kernel_size': 4, 'lr': 0.003712495968751363, 'epochs': 50, 'batch_size': 16}. Best is trial 27 with value: 0.00036150884989183396.
# [I 2025-05-29 08:30:35,587] Trial 29 finished with value: 0.001439777445436145 and parameters: {'filters': 112, 'kernel_size': 6, 'lr': 0.002051140598227947, 'epochs': 50, 'batch_size': 32}. Best is trial 27 with value: 0.00036150884989183396.
# Best trial: {'filters': 112, 'kernel_size': 4, 'lr': 0.004061216334591779, 'epochs': 50, 'batch_size': 8}
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0097
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4030e-04
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5709e-04
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8912e-04
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0647e-04
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4132e-04
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6507e-04
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3716e-04
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8922e-04
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6034e-04
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1871e-04
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8598e-04
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2128e-04
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9577e-04
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1896e-04
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4578e-04
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8381e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9099e-04
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2119e-04
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7541e-04
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6426e-04
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2320e-04
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6560e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1517e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5394e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4146e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7327e-04
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7788e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7442e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6405e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7930e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1382e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1905e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4543e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4586e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6395e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7882e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2876e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3367e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5920e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2928e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1569e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0447e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8375e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6871e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9272e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1284e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6989e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  Test MSE  : 31.4307
#  Test RMSE : 5.6063
#  Test MAE  : 3.6525
#  Test MAPE : 89.52%
#  Test R²   : 0.9314

# %% [markdown]
# ## *

# %% [markdown]
# ## 9

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown
# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()
# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 9  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 9), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 24.2MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.16.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-05-29 08:31:06,656] A new study created in memory with name: no-name-fc5d1311-ac52-49d7-a02e-bb02e1cf5b7e
# [I 2025-05-29 08:31:21,531] Trial 0 finished with value: 0.0019364089530427009 and parameters: {'filters': 63, 'kernel_size': 7, 'lr': 0.0001610099607754105, 'epochs': 44, 'batch_size': 8}. Best is trial 0 with value: 0.0019364089530427009.
# [I 2025-05-29 08:31:30,186] Trial 1 finished with value: 0.005229901134346922 and parameters: {'filters': 92, 'kernel_size': 7, 'lr': 0.00013926284778411363, 'epochs': 29, 'batch_size': 32}. Best is trial 0 with value: 0.0019364089530427009.
# [I 2025-05-29 08:31:48,883] Trial 2 finished with value: 0.0012670033029280603 and parameters: {'filters': 72, 'kernel_size': 8, 'lr': 0.0007639640788791418, 'epochs': 32, 'batch_size': 8}. Best is trial 2 with value: 0.0012670033029280603.
# [I 2025-05-29 08:32:00,584] Trial 3 finished with value: 0.0006766043564615151 and parameters: {'filters': 111, 'kernel_size': 9, 'lr': 0.0055417193407777555, 'epochs': 34, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:32:14,070] Trial 4 finished with value: 0.0013025162334088236 and parameters: {'filters': 89, 'kernel_size': 3, 'lr': 0.0014545302457038827, 'epochs': 47, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:32:24,614] Trial 5 finished with value: 0.0008067731056750441 and parameters: {'filters': 46, 'kernel_size': 2, 'lr': 0.00492402615390682, 'epochs': 24, 'batch_size': 8}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:32:34,051] Trial 6 finished with value: 0.000709968104880924 and parameters: {'filters': 36, 'kernel_size': 9, 'lr': 0.003352726489080972, 'epochs': 27, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:32:45,378] Trial 7 finished with value: 0.0017087227703693013 and parameters: {'filters': 37, 'kernel_size': 3, 'lr': 0.002401515246716828, 'epochs': 34, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:32:53,118] Trial 8 finished with value: 0.0017039491212926805 and parameters: {'filters': 66, 'kernel_size': 3, 'lr': 0.0022191947104061483, 'epochs': 11, 'batch_size': 8}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:07,169] Trial 9 finished with value: 0.0019528888127145667 and parameters: {'filters': 71, 'kernel_size': 1, 'lr': 0.00018138216610509924, 'epochs': 39, 'batch_size': 8}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:13,494] Trial 10 finished with value: 0.0018106299976352602 and parameters: {'filters': 123, 'kernel_size': 5, 'lr': 0.009369209921430926, 'epochs': 17, 'batch_size': 32}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:22,093] Trial 11 finished with value: 0.0008444634683352584 and parameters: {'filters': 116, 'kernel_size': 9, 'lr': 0.005056168828325922, 'epochs': 23, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:32,885] Trial 12 finished with value: 0.0007259648118633777 and parameters: {'filters': 107, 'kernel_size': 9, 'lr': 0.009973149126853601, 'epochs': 38, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:40,928] Trial 13 finished with value: 0.0021926526872751615 and parameters: {'filters': 50, 'kernel_size': 6, 'lr': 0.0004934545172962639, 'epochs': 26, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:48,235] Trial 14 finished with value: 0.0010387189007208992 and parameters: {'filters': 104, 'kernel_size': 9, 'lr': 0.003602078276974853, 'epochs': 18, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:33:59,064] Trial 15 finished with value: 0.0025872926538189254 and parameters: {'filters': 32, 'kernel_size': 5, 'lr': 0.0011557624116653531, 'epochs': 37, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:10,210] Trial 16 finished with value: 0.0012656634644372389 and parameters: {'filters': 85, 'kernel_size': 7, 'lr': 0.0058564472777000755, 'epochs': 43, 'batch_size': 32}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:18,914] Trial 17 finished with value: 0.0012739752419292927 and parameters: {'filters': 100, 'kernel_size': 8, 'lr': 0.0026127213688169107, 'epochs': 29, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:25,634] Trial 18 finished with value: 0.001959860606196647 and parameters: {'filters': 127, 'kernel_size': 8, 'lr': 0.00041224373265727623, 'epochs': 19, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:38,865] Trial 19 finished with value: 0.0012150612213493635 and parameters: {'filters': 56, 'kernel_size': 6, 'lr': 0.001704734429370484, 'epochs': 50, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:48,513] Trial 20 finished with value: 0.0016361947928089648 and parameters: {'filters': 77, 'kernel_size': 4, 'lr': 0.00380295042368594, 'epochs': 34, 'batch_size': 32}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:34:59,239] Trial 21 finished with value: 0.0006829536772177865 and parameters: {'filters': 110, 'kernel_size': 9, 'lr': 0.009570928430145417, 'epochs': 40, 'batch_size': 16}. Best is trial 3 with value: 0.0006766043564615151.
# [I 2025-05-29 08:35:10,678] Trial 22 finished with value: 0.0006056280253687873 and parameters: {'filters': 114, 'kernel_size': 9, 'lr': 0.007529569007963902, 'epochs': 41, 'batch_size': 16}. Best is trial 22 with value: 0.0006056280253687873.
# [I 2025-05-29 08:35:22,566] Trial 23 finished with value: 0.0005352681037038565 and parameters: {'filters': 116, 'kernel_size': 8, 'lr': 0.006769645314301538, 'epochs': 42, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:35:34,303] Trial 24 finished with value: 0.0006192665168782696 and parameters: {'filters': 118, 'kernel_size': 8, 'lr': 0.0057176639026736975, 'epochs': 43, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:35:46,492] Trial 25 finished with value: 0.0005589753369955967 and parameters: {'filters': 121, 'kernel_size': 8, 'lr': 0.007121139124936153, 'epochs': 44, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:35:59,703] Trial 26 finished with value: 0.0005778600898338482 and parameters: {'filters': 97, 'kernel_size': 6, 'lr': 0.0073787658581903675, 'epochs': 50, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:36:12,286] Trial 27 finished with value: 0.000615108700003475 and parameters: {'filters': 97, 'kernel_size': 6, 'lr': 0.006698728961103271, 'epochs': 49, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:36:24,023] Trial 28 finished with value: 0.0013517710322048515 and parameters: {'filters': 121, 'kernel_size': 7, 'lr': 0.0039864239971541685, 'epochs': 46, 'batch_size': 32}. Best is trial 23 with value: 0.0005352681037038565.
# [I 2025-05-29 08:36:36,311] Trial 29 finished with value: 0.0006106788884305084 and parameters: {'filters': 98, 'kernel_size': 6, 'lr': 0.007693416078986607, 'epochs': 46, 'batch_size': 16}. Best is trial 23 with value: 0.0005352681037038565.
# Best trial: {'filters': 116, 'kernel_size': 8, 'lr': 0.006769645314301538, 'epochs': 42, 'batch_size': 16}
# Epoch 1/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0099
# Epoch 2/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 3/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013
# Epoch 4/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6282e-04
# Epoch 5/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 6/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4547e-04
# Epoch 7/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0147e-04
# Epoch 8/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3765e-04
# Epoch 9/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1852e-04
# Epoch 10/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0527e-04
# Epoch 11/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5822e-04
# Epoch 12/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7834e-04
# Epoch 13/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4843e-04
# Epoch 14/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8672e-04
# Epoch 15/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0075e-04
# Epoch 16/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5904e-04
# Epoch 17/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0249e-04
# Epoch 18/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4591e-04
# Epoch 19/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1398e-04
# Epoch 20/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6733e-04
# Epoch 21/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3757e-04
# Epoch 22/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4356e-04
# Epoch 23/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2039e-04
# Epoch 24/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9526e-04
# Epoch 25/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1521e-04
# Epoch 26/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6197e-04
# Epoch 27/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5147e-04
# Epoch 28/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3443e-04
# Epoch 29/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7918e-04
# Epoch 30/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6165e-04
# Epoch 31/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1326e-04
# Epoch 32/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7704e-04
# Epoch 33/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4212e-04
# Epoch 34/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3444e-04
# Epoch 35/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8098e-04
# Epoch 36/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3807e-04
# Epoch 37/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5069e-04
# Epoch 38/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3738e-04
# Epoch 39/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9983e-04
# Epoch 40/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7304e-04
# Epoch 41/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3795e-04
# Epoch 42/42
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7542e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  Test MSE  : 21.8162
#  Test RMSE : 4.6708
#  Test MAE  : 3.2568
#  Test MAPE : 77.98%
#  Test R²   : 0.9524
