# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.15.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.4.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 21.9 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
# !pip install --upgrade numpy pmdarima
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting numpy
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 849.8 kB/s eta 0:00:00
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.11/dist-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.15.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.4.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 37.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# Successfully installed numpy-2.2.6

# %%
# !pip install numpy==1.26.4 --no-cache-dir
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 74.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 152.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# !pip uninstall -y numpy pmdarima
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: pmdarima 2.0.4
# Uninstalling pmdarima-2.0.4:
#   Successfully uninstalled pmdarima-2.0.4

# %%
# !pip install numpy==1.24.2
# !pip install pmdarima
# Out:
# Collecting numpy==1.24.2
#   Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Downloading numpy-1.24.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 37.2 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.13.0 requires numpy<3,>=1.24.3, but you have numpy 1.24.2 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# pymc 5.22.0 requires numpy>=1.25.0, but you have numpy 1.24.2 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.24.2 which is incompatible.
# blosc2 3.3.3 requires numpy>=1.26, but you have numpy 1.24.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.2 which is incompatible.
# albumentations 2.0.7 requires numpy>=1.24.4, but you have numpy 1.24.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.2 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.2 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.2 which is incompatible.
# Successfully installed numpy-1.24.2
# Collecting pmdarima
#   Using cached pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.24.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (1.15.3)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (2.4.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.11/dist-packages (from pmdarima) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Using cached pmdarima-2.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.2 MB)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
import numpy as np
from pmdarima import auto_arima

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations


# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()



# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Assuming your time series data is in 'df' and it's in a column called 'value'
# Splitting the data into 70% for training and 30% for testing
train_size = int(len(df) * 0.9)
train, test = df[:train_size], df[train_size:]

# Inspect the first few rows of training and testing sets
print(train.head(), test.head())

import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA



# Plotting the train and test sets
plt.figure(figsize=(10, 6))
plt.plot(train, label='Training Set', color='blue')
plt.plot(test, label='Testing Set', color='orange')
plt.title('Train and Test Data')
plt.xlabel('Time')
plt.ylabel('Y-o-Y Inflation Value')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 26.7MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412             Inflation
# Date
# 2022-09-30  69.812630
# 2022-10-31  65.963240
# 2022-11-30  60.982084
# 2022-12-31  57.207498
# 2023-01-31  51.729686

# %% [markdown]
# # Auto ARIMA

# %%
train["Inflation"]
# Out:
# Date
# 2000-01-31     0.329139
# 2000-02-28     1.940367
# 2000-03-31     4.469678
# 2000-04-30     3.672022
# 2000-05-31     2.382412
#                 ...
# 2022-04-30    29.827089
# 2022-05-31    39.130435
# 2022-06-30    54.634831
# 2022-07-31    60.796646
# 2022-08-31    64.320557
# Name: Inflation, Length: 272, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Use AutoARIMA to find the best ARIMA model
auto_model = auto_arima(
    train["Inflation"],
    seasonal=False,
    trace=True,
    error_action="ignore",
    suppress_warnings=True,
    stepwise=True,
    information_criterion='aic'
)
test["Inflation"]
# Print the best model summary
print(auto_model.summary())
# Forecast using the best model
forecast = auto_model.predict(n_periods=len(test))
# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train.index, train["Inflation"], label='Train', color='#203147')
plt.plot(test.index, test["Inflation"], label='Test', color='#01ef63')
plt.plot(test.index, forecast, label='Forecast', color='orange')
plt.title('Inflation Forecast')
plt.xlabel('Date')
plt.ylabel('Inflation')
plt.legend()
plt.show()
# Calculate metrics



mse = mean_squared_error(test["Inflation"], forecast)
mae = mean_absolute_error(test["Inflation"], forecast)
mape = np.mean(np.abs((test["Inflation"] - forecast) / test["Inflation"])) * 100
rmse = np.sqrt(mse)
from sklearn.metrics import r2_score

# Calculate R-squared
r2 = r2_score(test["Inflation"], forecast)

# Print metrics including R-squared
print(f"AIC: {auto_model.aic():.4f}")
print(f"BIC: {auto_model.bic():.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
print(f"RMSE: {rmse:.4f}")
print(f"R²: {r2:.4f}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1043.320, Time=2.61 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2108.971, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1787.509, Time=0.21 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1053.638, Time=0.53 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1043.338, Time=0.87 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=2.53 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1057.440, Time=3.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1076.094, Time=0.85 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1052.668, Time=1.26 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1043.190, Time=2.64 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=1044.180, Time=1.36 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=3.45 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.16 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=1045.765, Time=0.30 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=inf, Time=0.65 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1041.002, Time=2.60 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1042.386, Time=0.64 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1043.883, Time=0.41 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=1042.894, Time=0.58 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1046.118, Time=0.25 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1041.266, Time=0.30 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=1045.210, Time=0.22 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.83 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0] intercept
# Total fit time: 27.544 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  272
# Model:               SARIMAX(3, 0, 1)   Log Likelihood                -514.501
# Date:                Thu, 29 May 2025   AIC                           1041.002
# Time:                        08:06:15   BIC                           1062.637
# Sample:                             0   HQIC                          1049.687
#                                 - 272
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0887      0.074      1.203      0.229      -0.056       0.233
# ar.L1          2.1880      0.160     13.680      0.000       1.874       2.501
# ar.L2         -1.4440      0.263     -5.482      0.000      -1.960      -0.928
# ar.L3          0.2475      0.109      2.274      0.023       0.034       0.461
# ma.L1         -0.7337      0.149     -4.918      0.000      -1.026      -0.441
# sigma2         2.5230      0.133     18.917      0.000       2.262       2.784
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1086.50
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.05   Skew:                             1.56
# Prob(H) (two-sided):                  0.83   Kurtosis:                        12.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AIC: 1041.0019
# BIC: 1062.6367
# MSE: 728.5325
# MAE: 20.8955
# MAPE: nan%
# RMSE: 26.9913
# R²: -0.2515

# %% [markdown]
# The Ljung-Box test indicates no significant autocorrelation in the residuals.
#
# The Jarque-Bera test shows that the residuals are not normally distributed.
#
# The heteroskedasticity test indicates that the residuals have non-constant variance.

# %% [markdown]
# Statistic (Q) = 0.01, and Prob(Q) = 0.93.
#
# The Ljung-Box test is used to check for autocorrelation in the residuals. A high p-value (greater than 0.05) suggests that the residuals are not autocorrelated, which is a good sign of model fit. Since the p-value is 0.93, we fail to reject the null hypothesis that there is no autocorrelation in the residuals, indicating no significant autocorrelation.
#
# Jarque-Bera (JB) Test:
#
# Statistic (JB) = 13.78, and Prob(JB) = 0.00.
#
# The Jarque-Bera test checks for normality of the residuals. A low p-value (below 0.05) indicates that the residuals are not normally distributed. In your case, with a p-value of 0.00, the residuals appear to significantly deviate from a normal distribution.
#
# Heteroskedasticity (H) Test:
#
# Statistic (H) = 0.32, and Prob(H) = 0.00.
#
# This test checks for heteroskedasticity, or non-constant variance of residuals. A low p-value (less than 0.05) suggests the presence of heteroskedasticity. Here, with a p-value of 0.00, it indicates that heteroskedasticity is present in the residuals.

# %% [markdown]
# ## Checking The Assumption

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Split the data into training and test sets
train_size = int(len(data['Inflation']) * 0.9)
train, test = data['Inflation'][:train_size], data['Inflation'][train_size:]

# Fit ARIMA(1,1,0) model
model_110 = ARIMA(train, order=(1,1,0))
model_110_fit = model_110.fit()

# Residual Analysis
residuals = model_110_fit.resid

# %%
# 1. Check for White Noise
plt.figure(figsize=(12,5))
plt.plot(residuals)
plt.axhline(y=0, linestyle='dashed', color='black')
plt.title('Residuals Over Time (White Noise Check)')
plt.show()

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# Assuming 'residuals' is a numpy array or pandas series containing your residual values.

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# ACF plot
sm.graphics.tsa.plot_acf(residuals, lags=40, ax=ax[0])
ax[0].set_title('Autocorrelation Function (ACF)')

# PACF plot
sm.graphics.tsa.plot_pacf(residuals, lags=40, ax=ax[1])
ax[1].set_title('Partial Autocorrelation Function (PACF)')

plt.tight_layout()  # Ensures the plots do not overlap
plt.show()

# %%
# Ljung-Box Test
ljung_box_results = acorr_ljungbox(residuals, lags=[10], return_df=True)
print("Ljung-Box test p-value:", ljung_box_results['lb_pvalue'].values[0])
# Out:
# Ljung-Box test p-value: 0.3130355972211257

# %% [markdown]
# The null hypothesis (H₀) of the Ljung-Box test states that the residuals are white noise (i.e., no significant autocorrelation).
# The alternative hypothesis (H₁) suggests that the residuals are autocorrelated (indicating a poor model fit).
# A p-value > 0.05 means we fail to reject the null hypothesis, implying that the residuals behave like white noise.
# This suggests that the ARIMA(1,1,0) model captures most of the autocorrelated structure in the data well.

# %%
# 3. Normality of Residuals (Histogram and Q-Q Plot)
fig, ax = plt.subplots(1, 2, figsize=(14,5))
sns.histplot(residuals, bins=30, kde=True, ax=ax[0])
ax[0].set_title("Histogram of Residuals")
sm.qqplot(residuals, line='s', ax=ax[1])
ax[1].set_title("Q-Q Plot of Residuals")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(model_110_fit.fittedvalues, residuals, alpha=0.5)
plt.axhline(y=0, color="red", linestyle="--")
plt.title("Residuals vs. Fitted Values")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# The Ljung-Box test indicates no significant autocorrelation in the residuals.
#
# The Jarque-Bera test shows that the residuals are not normally distributed.
#
# The heteroskedasticity test indicates that the residuals have non-constant variance.

# %% [markdown]
# ## SARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations


# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()



# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Assuming your time series data is in 'df' and it's in a column called 'value'
# Splitting the data into 70% for training and 30% for testing
train_size = int(len(df) * 0.9)
train, test = df[:train_size], df[train_size:]

# Inspect the first few rows of training and testing sets
print(train.head(), test.head())

import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA



# Plotting the train and test sets
plt.figure(figsize=(10, 6))
plt.plot(train, label='Training Set', color='blue')
plt.plot(test, label='Testing Set', color='orange')
plt.title('Train and Test Data')
plt.xlabel('Time')
plt.ylabel('Y-o-Y Inflation Value')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 8.76MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412             Inflation
# Date
# 2022-09-30  69.812630
# 2022-10-31  65.963240
# 2022-11-30  60.982084
# 2022-12-31  57.207498
# 2023-01-31  51.729686

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Use AutoARIMA to find the best ARIMA model
SARIMA_auto_model = auto_arima(
    train["Inflation"],
    seasonal=True,           # Enable seasonal components
    m=12,                    # Periodicity of the seasonality (e.g., 12 for monthly data with yearly seasonality)
    trace=True,
    error_action="ignore",
    suppress_warnings=True,
    stepwise=True,
    information_criterion='aic'
)

# Print the best SARIMA model summary
print(SARIMA_auto_model.summary())

test["Inflation"]
# Print the best model summary
print(SARIMA_auto_model.summary())
# Forecast using the best model
forecast = SARIMA_auto_model.predict(n_periods=len(test))
# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(train.index, train["Inflation"], label='Train', color='#203147')
plt.plot(test.index, test["Inflation"], label='Test', color='#01ef63')
plt.plot(test.index, forecast, label='Forecast', color='orange')
plt.title('Inflation Forecast')
plt.xlabel('Date')
plt.ylabel('Inflation')
plt.legend()
plt.show()
# Calculate metrics



mse = mean_squared_error(test["Inflation"], forecast)
mae = mean_absolute_error(test["Inflation"], forecast)
mape = np.mean(np.abs((test["Inflation"] - forecast) / test["Inflation"])) * 100
rmse = np.sqrt(mse)
from sklearn.metrics import r2_score

# Calculate R-squared
r2 = r2_score(test["Inflation"], forecast)

# Print metrics including R-squared
print(f"AIC: {auto_model.aic():.4f}")
print(f"BIC: {auto_model.bic():.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.4f}%")
print(f"RMSE: {rmse:.4f}")
print(f"R²: {r2:.4f}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=975.447, Time=2.03 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1893.373, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1602.444, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2108.971, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=972.808, Time=3.40 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=1041.266, Time=0.65 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=974.714, Time=3.27 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=995.379, Time=1.28 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=975.992, Time=4.38 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=979.723, Time=0.82 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=971.332, Time=2.57 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=1042.386, Time=0.74 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=973.212, Time=1.42 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=973.220, Time=2.21 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=994.257, Time=0.93 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=974.456, Time=3.31 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=1028.919, Time=0.87 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=978.013, Time=0.76 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=963.454, Time=3.18 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1041.002, Time=1.27 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=965.075, Time=1.67 sec
#  ARIMA(3,0,1)(0,0,2)[12] intercept   : AIC=964.116, Time=3.54 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=991.596, Time=2.00 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=966.689, Time=5.77 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=970.995, Time=0.89 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : AIC=962.977, Time=1.59 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1042.894, Time=0.62 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : AIC=963.639, Time=1.91 sec
#  ARIMA(4,0,1)(0,0,2)[12] intercept   : AIC=963.459, Time=3.64 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : AIC=993.139, Time=3.68 sec
#  ARIMA(4,0,1)(1,0,2)[12] intercept   : AIC=967.119, Time=4.36 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=972.265, Time=0.72 sec
#  ARIMA(5,0,1)(0,0,1)[12] intercept   : AIC=963.008, Time=1.73 sec
#  ARIMA(4,0,2)(0,0,1)[12] intercept   : AIC=974.889, Time=1.86 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=962.959, Time=1.67 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(3,0,2)(1,0,1)[12] intercept   : AIC=963.405, Time=2.57 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=963.457, Time=3.49 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : AIC=992.860, Time=1.67 sec
#  ARIMA(3,0,2)(1,0,2)[12] intercept   : AIC=964.917, Time=5.99 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=962.498, Time=2.37 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=1043.378, Time=0.80 sec
#  ARIMA(3,0,3)(1,0,1)[12] intercept   : AIC=962.636, Time=1.96 sec
#  ARIMA(3,0,3)(0,0,2)[12] intercept   : AIC=962.783, Time=5.41 sec
#  ARIMA(3,0,3)(1,0,0)[12] intercept   : AIC=990.288, Time=4.27 sec
#  ARIMA(3,0,3)(1,0,2)[12] intercept   : AIC=964.350, Time=4.62 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=977.384, Time=1.77 sec
#  ARIMA(4,0,3)(0,0,1)[12] intercept   : AIC=963.925, Time=6.19 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=964.220, Time=2.33 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=972.135, Time=2.03 sec
#  ARIMA(4,0,4)(0,0,1)[12] intercept   : AIC=964.806, Time=2.45 sec
#  ARIMA(3,0,3)(0,0,1)[12]             : AIC=966.722, Time=1.39 sec
#
# Best model:  ARIMA(3,0,3)(0,0,1)[12] intercept
# Total fit time: 121.437 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  272
# Model:             SARIMAX(3, 0, 3)x(0, 0, [1], 12)   Log Likelihood                -472.249
# Date:                              Thu, 29 May 2025   AIC                            962.498
# Time:                                      08:08:20   BIC                            994.950
# Sample:                                           0   HQIC                           975.527
#                                               - 272
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1201      0.112      1.072      0.284      -0.099       0.339
# ar.L1          0.8589      0.106      8.129      0.000       0.652       1.066
# ar.L2          0.9695      0.051     19.008      0.000       0.870       1.069
# ar.L3         -0.8413      0.097     -8.684      0.000      -1.031      -0.651
# ma.L1          0.6766      0.132      5.118      0.000       0.417       0.936
# ma.L2         -0.3573      0.186     -1.921      0.055      -0.722       0.007
# ma.L3         -0.1735      0.083     -2.080      0.038      -0.337      -0.010
# ma.S.L12      -0.8253      0.096     -8.558      0.000      -1.014      -0.636
# sigma2         1.7735      0.093     18.976      0.000       1.590       1.957
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2169.33
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.47   Skew:                             2.20
# Prob(H) (two-sided):                  0.07   Kurtosis:                        16.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  272
# Model:             SARIMAX(3, 0, 3)x(0, 0, [1], 12)   Log Likelihood                -472.249
# Date:                              Thu, 29 May 2025   AIC                            962.498
# Time:                                      08:08:20   BIC                            994.950
# Sample:                                           0   HQIC                           975.527
#                                               - 272
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1201      0.112      1.072      0.284      -0.099       0.339
# ar.L1          0.8589      0.106      8.129      0.000       0.652       1.066
# ar.L2          0.9695      0.051     19.008      0.000       0.870       1.069
# ar.L3         -0.8413      0.097     -8.684      0.000      -1.031      -0.651
# ma.L1          0.6766      0.132      5.118      0.000       0.417       0.936
# ma.L2         -0.3573      0.186     -1.921      0.055      -0.722       0.007
# ma.L3         -0.1735      0.083     -2.080      0.038      -0.337      -0.010
# ma.S.L12      -0.8253      0.096     -8.558      0.000      -1.014      -0.636
# sigma2         1.7735      0.093     18.976      0.000       1.590       1.957
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2169.33
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.47   Skew:                             2.20
# Prob(H) (two-sided):                  0.07   Kurtosis:                        16.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AIC: 1041.0019
# BIC: 1062.6367
# MSE: 132.6634
# MAE: 8.2103
# MAPE: nan%
# RMSE: 11.5180
# R²: 0.7721

# %% [markdown]
# Ljung-Box (Q) Test:
# Statistic (Q) = 0.01, and Prob(Q) = 0.94.
#
# Interpretation: The Ljung-Box test checks for autocorrelation in the residuals. A high p-value (greater than 0.05) indicates no significant autocorrelation. With a p-value of 0.94, you fail to reject the null hypothesis of no autocorrelation, suggesting that there is no significant autocorrelation in the residuals. This is a good result for your model.
#
# 2. Jarque-Bera (JB) Test:
# Statistic (JB) = 29.08, and Prob(JB) = 0.00.
#
# Interpretation: The Jarque-Bera test assesses whether the residuals are normally distributed by examining skewness and kurtosis. A low p-value (less than 0.05) indicates that the residuals are significantly non-normal. With a p-value of 0.00, you can conclude that the residuals are not normally distributed, which is a concern for model assumptions. This suggests that while the model fits the data well in terms of autocorrelation, the residuals deviate from normality.
#
# 3. Heteroskedasticity (H) Test:
# Statistic (H) = 0.34, and Prob(H) = 0.00.
#
# Interpretation: The Heteroskedasticity test checks whether the residuals have constant variance (homoscedasticity). A low p-value (less than 0.05) indicates the presence of heteroskedasticity, meaning that the residuals' variance is not constant across time. With a p-value of 0.00, this suggests that your residuals exhibit heteroskedasticity, which could be problematic as it violates the assumption of constant variance in regression models.

# %% [markdown]
# ## Checking The Assumption

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Split the data into training and test sets
train_size = int(len(data['Inflation']) * 0.9)
train, test = data['Inflation'][:train_size], data['Inflation'][train_size:]

# Fit ARIMA(4,1,2)(0,0,1)[12] model
model_412_001_12 = ARIMA(train, order=(4, 1, 2), seasonal_order=(0, 0, 1, 12))
model_412_001_12_fit = model_412_001_12.fit()

# Residual Analysis
residuals = model_412_001_12_fit.resid

# 1. Check for White Noise
plt.figure(figsize=(12,5))
plt.plot(residuals)
plt.axhline(y=0, linestyle='dashed', color='black')
plt.title('Residuals Over Time (White Noise Check)')
plt.show()

# ACF and PACF plots
fig, ax = plt.subplots(1, 2, figsize=(14, 5))

# ACF plot
sm.graphics.tsa.plot_acf(residuals, lags=40, ax=ax[0])
ax[0].set_title('Autocorrelation Function (ACF)')

# PACF plot
sm.graphics.tsa.plot_pacf(residuals, lags=40, ax=ax[1])
ax[1].set_title('Partial Autocorrelation Function (PACF)')

plt.tight_layout()  # Ensures the plots do not overlap
plt.show()

# Ljung-Box Test
ljung_box_results = acorr_ljungbox(residuals, lags=[10], return_df=True)
print("Ljung-Box test p-value:", ljung_box_results['lb_pvalue'].values[0])

# 3. Normality of Residuals (Histogram and Q-Q Plot)
fig, ax = plt.subplots(1, 2, figsize=(14,5))
sns.histplot(residuals, bins=30, kde=True, ax=ax[0])
ax[0].set_title("Histogram of Residuals")
sm.qqplot(residuals, line='s', ax=ax[1])
ax[1].set_title("Q-Q Plot of Residuals")
plt.show()

from scipy.stats import shapiro

# Perform Shapiro-Wilk test
shapiro_test_stat, shapiro_p_value = shapiro(residuals)

# Print results
print("Shapiro-Wilk test statistic:", shapiro_test_stat)
print("Shapiro-Wilk test p-value:", shapiro_p_value)

# Interpretation
if shapiro_p_value > 0.05:
    print("Residuals appear to be normally distributed (fail to reject H0).")
else:
    print("Residuals do not appear to be normally distributed (reject H0).")

# Plot residuals vs. fitted values
plt.figure(figsize=(10, 6))
plt.scatter(model_412_001_12_fit.fittedvalues, residuals, alpha=0.5)
plt.axhline(y=0, color="red", linestyle="--")
plt.title("Residuals vs. Fitted Values")
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.show()

# Compute evaluation metrics
pred_412_001_12 = model_412_001_12_fit.predict(start=len(train), end=len(train)+len(test)-1)
mse_412_001_12 = mean_squared_error(test, pred_412_001_12)
rmse_412_001_12 = np.sqrt(mse_412_001_12)
mae_412_001_12 = mean_absolute_error(test, pred_412_001_12)
mape_412_001_12 = np.mean(np.abs((test - pred_412_001_12) / test)) * 100
aic_412_001_12 = model_412_001_12_fit.aic
bic_412_001_12 = model_412_001_12_fit.bic

# Print evaluation metrics
print("ARIMA(4,1,2)(0,0,1)[12] Metrics:")
print(f"MSE: {mse_412_001_12}, RMSE: {rmse_412_001_12}, MAE: {mae_412_001_12}, MAPE: {mape_412_001_12}, AIC: {aic_412_001_12}, BIC: {bic_412_001_12}")
# Out:
# Ljung-Box test p-value: 0.8433423123453635
# Shapiro-Wilk test statistic: 0.8513856737080417
# Shapiro-Wilk test p-value: 1.7808702680714974e-15
# Residuals do not appear to be normally distributed (reject H0).
# ARIMA(4,1,2)(0,0,1)[12] Metrics:
# MSE: 3671.861507784435, RMSE: 60.5958868883395, MAE: 56.94822139771856, MAPE: 3126.9285056168806, AIC: 953.4454061488184, BIC: 982.262356715856

# %%
obj=test
# Check the type
if isinstance(obj, pd.DataFrame):
    print("It's a DataFrame")
    print("Data types of each column:", obj.dtypes)
elif isinstance(obj, pd.Series):
    print("It's a Series")
    print("Data type of the Series:", obj.dtype)
else:
    print("It's neither a DataFrame nor a Series")
# Out:
# It's a Series
# Data type of the Series: float64

# %%
obj=forecast
# Check the type
if isinstance(obj, pd.DataFrame):
    print("It's a DataFrame")
    print("Data types of each column:", obj.dtypes)
elif isinstance(obj, pd.Series):
    print("It's a Series")
    print("Data type of the Series:", obj.dtype)
else:
    print("It's neither a DataFrame nor a Series")
# Out:
# It's a Series
# Data type of the Series: float64
