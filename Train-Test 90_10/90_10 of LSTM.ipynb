# %% [markdown]
# ## Completed

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations


# LOADING THE DATASET
import gdown

# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()



# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx
# To: /content/downloaded_file.xlsx
# 16.9kB [00:00, 6.26MB/s]
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Collecting optuna
#   Downloading optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.41)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.2)
# Downloading optuna-4.3.0-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 5.9 MB/s eta 0:00:00
# Downloading alembic-1.16.1-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 11.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.1 colorlog-6.9.0 optuna-4.3.0

# %%
import os
import random
import numpy as np
import pandas as pd
import optuna
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import TimeSeriesSplit
import matplotlib.pyplot as plt

# ------------------ SET RANDOM SEED ------------------
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ------------------ LOAD YOUR DATA ------------------
# df = pd.read_csv('your_data.csv')  # Uncomment and load your actual data
# Ensure 'Inflation' column exists in df

# ------------------ TRAIN-TEST SPLIT ------------------
train_size = int(len(df) * 0.9)
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

y_train = train_data['Inflation'].values.reshape(-1, 1)
y_test = test_data['Inflation'].values.reshape(-1, 1)

# ------------------ NORMALIZE ------------------
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

# ------------------ SEQUENCE CREATION ------------------
def create_sequences(y_scaled, n_past, n_future):
    X, y_data = [], []
    for i in range(n_past, len(y_scaled) - n_future + 1):
        X.append(y_scaled[i - n_past:i, 0])
        y_data.append(y_scaled[i + n_future - 1:i + n_future, 0])
    return np.array(X), np.array(y_data)

# ------------------ OPTUNA OBJECTIVE FUNCTION ------------------
def objective(trial):
    n_past = trial.suggest_int("n_past", 1, 9)
    n_neurons = trial.suggest_int("n_neurons", 16, 128)
    n_layers = trial.suggest_int("n_layers", 1, 4)
    activation = trial.suggest_categorical("activation", ["relu", "tanh", "sigmoid"])
    dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5)
    batch_size = trial.suggest_categorical("batch_size", [1, 4, 8, 16, 32])
    optimizer = trial.suggest_categorical("optimizer", ["adam", "sgd", "rmsprop"])
    epochs = trial.suggest_int("epochs", 10, 100)

    X, y_seq = create_sequences(y_train_scaled, n_past, 1)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    mse_scores = []

    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train_fold, y_val = y_seq[train_idx], y_seq[val_idx]

        model = Sequential()
        model.add(LSTM(n_neurons, return_sequences=(n_layers > 1),
                       activation=activation, input_shape=(X_train.shape[1], 1)))
        model.add(Dropout(dropout_rate))

        for i in range(1, n_layers):
            return_seq = (i < n_layers - 1)
            model.add(LSTM(n_neurons, return_sequences=return_seq, activation=activation))
            model.add(Dropout(dropout_rate))

        model.add(Dense(1))
        model.compile(optimizer=optimizer, loss="mean_squared_error")

        model.fit(X_train, y_train_fold, epochs=epochs, batch_size=batch_size, verbose=0)
        y_pred = model.predict(X_val)
        mse = mean_squared_error(y_val, y_pred)
        mse_scores.append(mse)

    return np.mean(mse_scores)

# ------------------ RUN OPTUNA STUDY ------------------
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

print("Best Hyperparameters:", study.best_params)

# ------------------ TRAIN FINAL MODEL ------------------
best_params = study.best_params
n_past = best_params["n_past"]
n_neurons = best_params["n_neurons"]
n_layers = best_params["n_layers"]
activation = best_params["activation"]
dropout_rate = best_params["dropout_rate"]
batch_size = best_params["batch_size"]
optimizer = best_params["optimizer"]
epochs = best_params["epochs"]

X_train, y_train_seq = create_sequences(y_train_scaled, n_past, 1)
X_test, y_test_seq = create_sequences(y_test_scaled, n_past, 1)

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

model = Sequential()
model.add(LSTM(n_neurons, return_sequences=(n_layers > 1), input_shape=(X_train.shape[1], 1)))
model.add(Dropout(dropout_rate))
for _ in range(n_layers - 1):
    model.add(LSTM(n_neurons, return_sequences=False))
    model.add(Dropout(dropout_rate))
model.add(Dense(1))
model.compile(optimizer=optimizer, loss="mean_squared_error")
model.fit(X_train, y_train_seq, epochs=epochs, batch_size=batch_size, verbose=0)

# ------------------ EVALUATION ------------------
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_actual = scaler_y.inverse_transform(y_test_seq)

mse = mean_squared_error(y_test_actual, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, y_pred)
mape = np.mean(np.abs((y_test_actual - y_pred) / y_test_actual)) * 100
r2 = r2_score(y_test_actual, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"MAPE: {mape:.2f}%")
print(f"R-squared: {r2:.4f}")

# ------------------ PLOT ACTUAL VS PREDICTED ------------------
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label="Actual", color='blue')
plt.plot(y_pred, label="Fitted", color='red', linestyle='--')
plt.title('Actual vs Fitted Values')
plt.xlabel('Time')
plt.ylabel('Inflation')
plt.legend()
plt.show()
# Out:
# [I 2025-05-30 05:04:14,837] A new study created in memory with name: no-name-5536ce2c-a512-497a-951f-94461114c6f4
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 373ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7886ad7f0ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7886ad7f0ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step
# [I 2025-05-30 05:17:16,369] Trial 0 finished with value: 0.12219627748115644 and parameters: {'n_past': 8, 'n_neurons': 114, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.4043379461454206, 'batch_size': 1, 'optimizer': 'adam', 'epochs': 75}. Best is trial 0 with value: 0.12219627748115644.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# [I 2025-05-30 05:18:57,920] Trial 1 finished with value: 0.6379648612952893 and parameters: {'n_past': 3, 'n_neurons': 120, 'n_layers': 3, 'activation': 'sigmoid', 'dropout_rate': 0.20975846977815987, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 29}. Best is trial 0 with value: 0.12219627748115644.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 349ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step
# [I 2025-05-30 05:19:37,049] Trial 2 finished with value: 0.7388119977552237 and parameters: {'n_past': 2, 'n_neurons': 64, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.3385926321368362, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 14}. Best is trial 0 with value: 0.12219627748115644.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step
# [I 2025-05-30 05:21:00,492] Trial 3 finished with value: 0.05890290674615445 and parameters: {'n_past': 8, 'n_neurons': 90, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.380757546002061, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 90}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 764ms/step
# [I 2025-05-30 05:27:21,704] Trial 4 finished with value: 0.23658816843762712 and parameters: {'n_past': 9, 'n_neurons': 112, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.22514592183690066, 'batch_size': 4, 'optimizer': 'adam', 'epochs': 96}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 925ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 778ms/step
# [I 2025-05-30 05:28:25,970] Trial 5 finished with value: 1.2104365122243927 and parameters: {'n_past': 2, 'n_neurons': 25, 'n_layers': 4, 'activation': 'tanh', 'dropout_rate': 0.3061958922240565, 'batch_size': 32, 'optimizer': 'sgd', 'epochs': 64}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# [I 2025-05-30 05:28:59,632] Trial 6 finished with value: 0.164750184288836 and parameters: {'n_past': 2, 'n_neurons': 109, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.19122486851905773, 'batch_size': 32, 'optimizer': 'adam', 'epochs': 47}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 404ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# [I 2025-05-30 05:30:45,318] Trial 7 finished with value: 0.27809121997889313 and parameters: {'n_past': 1, 'n_neurons': 92, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.17157959627213443, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 61}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 302ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# [I 2025-05-30 05:31:27,585] Trial 8 finished with value: 0.599087728106908 and parameters: {'n_past': 7, 'n_neurons': 97, 'n_layers': 1, 'activation': 'sigmoid', 'dropout_rate': 0.1655501039876815, 'batch_size': 16, 'optimizer': 'sgd', 'epochs': 56}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# [I 2025-05-30 05:32:31,188] Trial 9 finished with value: 0.9425780302199186 and parameters: {'n_past': 9, 'n_neurons': 79, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.4735595764913334, 'batch_size': 32, 'optimizer': 'sgd', 'epochs': 47}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# [I 2025-05-30 05:47:20,393] Trial 10 finished with value: 0.3465634119038795 and parameters: {'n_past': 6, 'n_neurons': 51, 'n_layers': 4, 'activation': 'relu', 'dropout_rate': 0.4845407770201235, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 99}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 356ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step
# [I 2025-05-30 06:00:02,598] Trial 11 finished with value: 0.1329087186360437 and parameters: {'n_past': 7, 'n_neurons': 128, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.37186626298238185, 'batch_size': 1, 'optimizer': 'adam', 'epochs': 80}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 672ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 387ms/step
# [I 2025-05-30 06:10:18,636] Trial 12 finished with value: 0.21385053530392245 and parameters: {'n_past': 5, 'n_neurons': 87, 'n_layers': 2, 'activation': 'relu', 'dropout_rate': 0.40756863673395766, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 79}. Best is trial 3 with value: 0.05890290674615445.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# [I 2025-05-30 06:11:53,274] Trial 13 finished with value: 0.058095485346746266 and parameters: {'n_past': 8, 'n_neurons': 103, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3824843427808323, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 81}. Best is trial 13 with value: 0.058095485346746266.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# [I 2025-05-30 06:13:14,231] Trial 14 finished with value: 0.054449559843735854 and parameters: {'n_past': 5, 'n_neurons': 63, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.28212795355049397, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 88}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# [I 2025-05-30 06:14:22,390] Trial 15 finished with value: 0.07079651157125141 and parameters: {'n_past': 4, 'n_neurons': 55, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2655984995412934, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 85}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# [I 2025-05-30 06:15:27,853] Trial 16 finished with value: 0.11651243726654559 and parameters: {'n_past': 5, 'n_neurons': 32, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.2725798824291507, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 72}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# [I 2025-05-30 06:17:10,747] Trial 17 finished with value: 0.06996045957106253 and parameters: {'n_past': 6, 'n_neurons': 71, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.10394563615309552, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 90}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# [I 2025-05-30 06:18:12,979] Trial 18 finished with value: 0.0654520399396508 and parameters: {'n_past': 4, 'n_neurons': 39, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3219559043731748, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 70}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# [I 2025-05-30 06:18:44,672] Trial 19 finished with value: 0.44134888110112264 and parameters: {'n_past': 6, 'n_neurons': 47, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.4387395954462744, 'batch_size': 16, 'optimizer': 'sgd', 'epochs': 40}. Best is trial 14 with value: 0.054449559843735854.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# [I 2025-05-30 06:19:52,688] Trial 20 finished with value: 0.05082600207185661 and parameters: {'n_past': 4, 'n_neurons': 64, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2521541376834518, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 87}. Best is trial 20 with value: 0.05082600207185661.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# [I 2025-05-30 06:20:59,561] Trial 21 finished with value: 0.05077149064108362 and parameters: {'n_past': 4, 'n_neurons': 64, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.26401591858559514, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 88}. Best is trial 21 with value: 0.05077149064108362.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# [I 2025-05-30 06:22:11,723] Trial 22 finished with value: 0.04816796203942762 and parameters: {'n_past': 4, 'n_neurons': 67, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2584742017676923, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 22 with value: 0.04816796203942762.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# [I 2025-05-30 06:23:27,804] Trial 23 finished with value: 0.04752401343454512 and parameters: {'n_past': 4, 'n_neurons': 77, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2530561078311571, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# [I 2025-05-30 06:25:42,915] Trial 24 finished with value: 0.0716562266541749 and parameters: {'n_past': 3, 'n_neurons': 79, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.1272079651294825, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 310ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# [I 2025-05-30 06:27:04,851] Trial 25 finished with value: 0.05239930139385838 and parameters: {'n_past': 3, 'n_neurons': 76, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.236967925486451, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 95}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 380ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# [I 2025-05-30 06:28:48,013] Trial 26 finished with value: 0.10896677876335996 and parameters: {'n_past': 4, 'n_neurons': 43, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.28248333744514187, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 93}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# [I 2025-05-30 06:29:52,681] Trial 27 finished with value: 0.05438483649098609 and parameters: {'n_past': 5, 'n_neurons': 58, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3503024803897842, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# [I 2025-05-30 06:32:12,428] Trial 28 finished with value: 0.13597923145432128 and parameters: {'n_past': 3, 'n_neurons': 68, 'n_layers': 3, 'activation': 'relu', 'dropout_rate': 0.3101812309687283, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 84}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# [I 2025-05-30 06:33:39,027] Trial 29 finished with value: 0.2861935532100258 and parameters: {'n_past': 1, 'n_neurons': 84, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.20586331915157055, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 74}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# [I 2025-05-30 06:34:32,966] Trial 30 finished with value: 0.08718127739342188 and parameters: {'n_past': 4, 'n_neurons': 20, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.16996813894708193, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 68}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# [I 2025-05-30 06:35:42,921] Trial 31 finished with value: 0.04811112831134016 and parameters: {'n_past': 4, 'n_neurons': 61, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.24477554481612052, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 92}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# [I 2025-05-30 06:36:56,452] Trial 32 finished with value: 0.04941208509898801 and parameters: {'n_past': 3, 'n_neurons': 57, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2399360569314425, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 94}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# [I 2025-05-30 06:37:23,833] Trial 33 finished with value: 0.18168263092700543 and parameters: {'n_past': 3, 'n_neurons': 56, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.23296371940195135, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 15}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# [I 2025-05-30 06:38:32,554] Trial 34 finished with value: 0.0702081370136797 and parameters: {'n_past': 2, 'n_neurons': 34, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.20536960894209083, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 95}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 469ms/step
# [I 2025-05-30 06:40:17,159] Trial 35 finished with value: 0.3238999569589952 and parameters: {'n_past': 3, 'n_neurons': 73, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.2412702957351552, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 78}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# [I 2025-05-30 06:42:09,459] Trial 36 finished with value: 0.07824313295187776 and parameters: {'n_past': 2, 'n_neurons': 47, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.33667816054371, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 93}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step
# [I 2025-05-30 06:44:21,766] Trial 37 finished with value: 0.4507078510718013 and parameters: {'n_past': 5, 'n_neurons': 82, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.2949799567438769, 'batch_size': 8, 'optimizer': 'sgd', 'epochs': 100}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 495ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# [I 2025-05-30 06:45:10,703] Trial 38 finished with value: 0.40442844911993703 and parameters: {'n_past': 4, 'n_neurons': 69, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.21833635534782747, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 28}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# [I 2025-05-30 06:46:05,791] Trial 39 finished with value: 0.17965290290107905 and parameters: {'n_past': 2, 'n_neurons': 92, 'n_layers': 1, 'activation': 'sigmoid', 'dropout_rate': 0.17931420771242118, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 92}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 823ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 971ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 935ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 716ms/step
# [I 2025-05-30 06:53:41,587] Trial 40 finished with value: 0.5888416351238124 and parameters: {'n_past': 3, 'n_neurons': 60, 'n_layers': 4, 'activation': 'tanh', 'dropout_rate': 0.14457306814747362, 'batch_size': 1, 'optimizer': 'sgd', 'epochs': 83}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# [I 2025-05-30 06:54:45,969] Trial 41 finished with value: 0.051955977587204785 and parameters: {'n_past': 4, 'n_neurons': 67, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2591249773107298, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 89}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# [I 2025-05-30 06:55:55,844] Trial 42 finished with value: 0.05025626816741918 and parameters: {'n_past': 4, 'n_neurons': 50, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2902756151395452, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# [I 2025-05-30 06:57:31,053] Trial 43 finished with value: 0.05774369030058134 and parameters: {'n_past': 5, 'n_neurons': 53, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2979509896936888, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 97}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# [I 2025-05-30 06:58:24,990] Trial 44 finished with value: 0.07918779426843063 and parameters: {'n_past': 3, 'n_neurons': 49, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.19216566221640036, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 95}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 390ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# [I 2025-05-30 07:00:43,499] Trial 45 finished with value: 0.0735398143893485 and parameters: {'n_past': 6, 'n_neurons': 75, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.2460103676824563, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 91}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# [I 2025-05-30 07:01:55,088] Trial 46 finished with value: 0.06878536145619366 and parameters: {'n_past': 4, 'n_neurons': 38, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.31573951145920287, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 64}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step
# [I 2025-05-30 07:03:09,595] Trial 47 finished with value: 0.2102854265368399 and parameters: {'n_past': 5, 'n_neurons': 59, 'n_layers': 1, 'activation': 'sigmoid', 'dropout_rate': 0.28556555997196287, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 77}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step
# [I 2025-05-30 07:07:11,196] Trial 48 finished with value: 0.08924912155671458 and parameters: {'n_past': 3, 'n_neurons': 29, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.33338493987844975, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 23 with value: 0.04752401343454512.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 392ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 492ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# [I 2025-05-30 07:08:17,154] Trial 49 finished with value: 0.6452104984329367 and parameters: {'n_past': 1, 'n_neurons': 43, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.22586981636056921, 'batch_size': 8, 'optimizer': 'sgd', 'epochs': 84}. Best is trial 23 with value: 0.04752401343454512.
# Best Hyperparameters: {'n_past': 4, 'n_neurons': 77, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2530561078311571, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 100}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# RMSE: 3.1664
# MSE: 10.0260
# MAE: 1.9298
# MAPE: 74.84%
# R-squared: 0.9649

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
import optuna


import numpy as np
import pandas as pd
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# --- Load your dataset ---
# Make sure you already have 'df' loaded and 'Inflation' column exists

# Train-test split
train_size = int(len(df) * 0.9)
train_data = df.iloc[:train_size]
test_data = df.iloc[train_size:]

# Use the target variable as inflation data (y)
y_train = train_data['Inflation']  # Replace with your actual column name if different
y_test = test_data['Inflation']

# Normalize the target using StandardScaler
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# Prepare data for LSTM (create sequences)
def create_sequences(y_scaled, n_past, n_future):
    X, y_data = [], []
    for i in range(n_past, len(y_scaled) - n_future + 1):
        X.append(y_scaled[i - n_past:i, 0])
        y_data.append(y_scaled[i + n_future - 1:i + n_future, 0])
    return np.array(X), np.array(y_data)

# Objective function for Optuna
def objective(trial, y_train_scaled):
    n_past = trial.suggest_int("n_past", 1, 24)  # Time step size
    n_neurons = trial.suggest_int("n_neurons", 16, 128)
    n_layers = trial.suggest_int("n_layers", 1, 4)
    activation = trial.suggest_categorical("activation", ["relu", "tanh", "sigmoid"])
    dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5)
    batch_size = trial.suggest_categorical("batch_size", [1, 4, 8, 16, 32])
    optimizer = trial.suggest_categorical("optimizer", ["adam", "sgd", "rmsprop"])
    epochs = trial.suggest_int("epochs", 10, 100)

    # Create sequences
    X, y_seq = create_sequences(y_train_scaled, n_past, 1)

    # Reshape input to (samples, time_steps, features)
    X = X.reshape((X.shape[0], X.shape[1], 1))

    mse_scores = []

    # TimeSeriesSplit cross-validation
    tscv = TimeSeriesSplit(n_splits=5)
    for train_idx, val_idx in tscv.split(X):
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y_seq[train_idx], y_seq[val_idx]

        # Build model
        model = Sequential()


        # First LSTM layer
        model.add(LSTM(n_neurons, return_sequences=(n_layers > 1), activation=activation,
                        input_shape=(X_train.shape[1], X_train.shape[2])))
        model.add(Dropout(dropout_rate))


        # Additional LSTM layers
        for i in range(1, n_layers):
            return_seq = (i < n_layers - 1)  # True for intermediate layers, False for last
            model.add(LSTM(n_neurons, return_sequences=return_seq, activation=activation))
            model.add(Dropout(dropout_rate))

        # Output layer
        model.add(Dense(1))

        # Compile model
        model.compile(optimizer=optimizer, loss="mean_squared_error")

        # Train model
        model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

        # Predict and evaluate
        y_pred = model.predict(X_val)
        mse = mean_squared_error(y_val, y_pred)
        mse_scores.append(mse)

    return np.mean(mse_scores)

# Create and run Optuna study
study = optuna.create_study(direction="minimize")
study.optimize(lambda trial: objective(trial, y_train_scaled), n_trials=50)

# Best hyperparameters
print("Best Hyperparameters:", study.best_params)

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
#import optuna

# Best hyperparameters found
print("Best Hyperparameters:", study.best_params)

# Using the best hyperparameters to train the model
best_params = study.best_params
n_past = best_params["n_past"]
n_neurons = best_params["n_neurons"]
n_layers = best_params["n_layers"]
activation = best_params["activation"]
dropout_rate = best_params["dropout_rate"]
batch_size = best_params["batch_size"]
optimizer = best_params["optimizer"]
epochs = best_params["epochs"]




# Create sequences with the chosen time step size (window size)
X_train, y_train = create_sequences(y_train_scaled, n_past, 1)
X_test, y_test = create_sequences(y_test_scaled, n_past, 1)

# Build the LSTM model with the best parameters
model = Sequential()

# First LSTM layer
model.add(LSTM(n_neurons, return_sequences=(n_layers > 1), input_shape=(X_train.shape[1], 1)))
model.add(Dropout(dropout_rate))

# Additional LSTM layers
for _ in range(n_layers - 1):
    model.add(LSTM(n_neurons, return_sequences=False))
    model.add(Dropout(dropout_rate))

# Output layer
model.add(Dense(1))

# Compile the model
model.compile(optimizer=optimizer, loss="mean_squared_error")

# Train the model
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

# Predict on test set
y_pred_scaled = model.predict(X_test)

# Inverse transform to get the actual predicted values
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_actual = scaler_y.inverse_transform(y_test)

# Calculate performance metrics
mse = mean_squared_error(y_test_actual, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_actual, y_pred)
mape = np.mean(np.abs((y_test_actual - y_pred) / y_test_actual)) * 100
r2 = r2_score(y_test_actual, y_pred)

# Print the results
print(f"RMSE: {rmse}")
print(f"MSE: {mse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f"R-squared: {r2}")

# Plot actual vs fitted values
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label="Actual", color='blue')
plt.plot(y_pred, label="Fitted", color='red', linestyle='--')
plt.title('Actual vs Fitted Values')
plt.xlabel('Time')
plt.ylabel('Inflation')
plt.legend()
plt.show()
# Out:
# [I 2025-05-29 08:02:33,990] A new study created in memory with name: no-name-212a2d61-5d6c-4c67-83c3-5d3be31939ec
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ce9aebc0180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ce9aebc0180> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# [I 2025-05-29 08:03:27,194] Trial 0 finished with value: 0.07925279839689703 and parameters: {'n_past': 5, 'n_neurons': 33, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.26119656877123887, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 99}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 744ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 655ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# [I 2025-05-29 08:07:20,226] Trial 1 finished with value: 1.3360076121853495 and parameters: {'n_past': 21, 'n_neurons': 86, 'n_layers': 4, 'activation': 'relu', 'dropout_rate': 0.3334906996474586, 'batch_size': 16, 'optimizer': 'sgd', 'epochs': 83}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# [I 2025-05-29 08:07:41,966] Trial 2 finished with value: 0.669828411243917 and parameters: {'n_past': 6, 'n_neurons': 47, 'n_layers': 1, 'activation': 'sigmoid', 'dropout_rate': 0.25760756021239845, 'batch_size': 16, 'optimizer': 'adam', 'epochs': 14}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 912ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# [I 2025-05-29 08:10:36,043] Trial 3 finished with value: 0.9186171107645299 and parameters: {'n_past': 13, 'n_neurons': 40, 'n_layers': 4, 'activation': 'tanh', 'dropout_rate': 0.19482711162636585, 'batch_size': 8, 'optimizer': 'sgd', 'epochs': 67}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 729ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# [I 2025-05-29 08:29:45,652] Trial 4 finished with value: 0.29185924004965963 and parameters: {'n_past': 10, 'n_neurons': 109, 'n_layers': 4, 'activation': 'tanh', 'dropout_rate': 0.12261884117883173, 'batch_size': 1, 'optimizer': 'adam', 'epochs': 43}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 839ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step
# [I 2025-05-29 08:34:34,081] Trial 5 finished with value: 0.2591718663557131 and parameters: {'n_past': 14, 'n_neurons': 118, 'n_layers': 4, 'activation': 'tanh', 'dropout_rate': 0.3935708931472063, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 496ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# [I 2025-05-29 08:40:46,808] Trial 6 finished with value: 0.16787848568127123 and parameters: {'n_past': 7, 'n_neurons': 108, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.38099936659927514, 'batch_size': 4, 'optimizer': 'adam', 'epochs': 100}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 293ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# [I 2025-05-29 08:42:55,883] Trial 7 finished with value: 0.2626738583371398 and parameters: {'n_past': 19, 'n_neurons': 54, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.48842716528491736, 'batch_size': 4, 'optimizer': 'sgd', 'epochs': 65}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 383ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step
# [I 2025-05-29 08:44:18,498] Trial 8 finished with value: 0.30377182471150305 and parameters: {'n_past': 9, 'n_neurons': 59, 'n_layers': 2, 'activation': 'relu', 'dropout_rate': 0.12391932253553183, 'batch_size': 32, 'optimizer': 'adam', 'epochs': 96}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 868ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# [I 2025-05-29 08:45:33,102] Trial 9 finished with value: 28.786057924734315 and parameters: {'n_past': 12, 'n_neurons': 21, 'n_layers': 4, 'activation': 'relu', 'dropout_rate': 0.33246004279075536, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 35}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 458ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step
# [I 2025-05-29 08:46:29,640] Trial 10 finished with value: 0.9103009667040489 and parameters: {'n_past': 1, 'n_neurons': 21, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.22230752884323393, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 80}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 471ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 483ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 468ms/step
# [I 2025-05-29 08:49:52,530] Trial 11 finished with value: 0.24529004068633203 and parameters: {'n_past': 3, 'n_neurons': 87, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.4281003381549554, 'batch_size': 4, 'optimizer': 'adam', 'epochs': 82}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 689ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 456ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# [I 2025-05-29 08:55:12,944] Trial 12 finished with value: 0.14973024140609612 and parameters: {'n_past': 6, 'n_neurons': 94, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.28819372239631064, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 99}. Best is trial 0 with value: 0.07925279839689703.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step
# [I 2025-05-29 08:56:59,546] Trial 13 finished with value: 0.06689510175608124 and parameters: {'n_past': 4, 'n_neurons': 78, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.2821272833735065, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 87}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# [I 2025-05-29 08:57:50,060] Trial 14 finished with value: 0.11754025213135447 and parameters: {'n_past': 1, 'n_neurons': 69, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.19251921414620793, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 69}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 368ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 494ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 490ms/step
# [I 2025-05-29 08:59:33,260] Trial 15 finished with value: 0.2628508276066907 and parameters: {'n_past': 17, 'n_neurons': 34, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.2609806310367917, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 50}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# [I 2025-05-29 09:04:38,564] Trial 16 finished with value: 0.16557131360143681 and parameters: {'n_past': 4, 'n_neurons': 72, 'n_layers': 1, 'activation': 'sigmoid', 'dropout_rate': 0.3232503052640901, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 86}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 485ms/step
# [I 2025-05-29 09:07:05,151] Trial 17 finished with value: 0.09195485097249052 and parameters: {'n_past': 9, 'n_neurons': 62, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.1777250864673214, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 88}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# [I 2025-05-29 09:07:44,589] Trial 18 finished with value: 0.12058875655158852 and parameters: {'n_past': 4, 'n_neurons': 33, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.24107270842752868, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 74}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 333ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 345ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 477ms/step
# [I 2025-05-29 09:10:14,293] Trial 19 finished with value: 0.4309711254677363 and parameters: {'n_past': 24, 'n_neurons': 77, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.294810732580552, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 55}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# [I 2025-05-29 09:10:46,629] Trial 20 finished with value: 0.5728646894559913 and parameters: {'n_past': 16, 'n_neurons': 127, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.37707125454392776, 'batch_size': 32, 'optimizer': 'sgd', 'epochs': 27}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 352ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step
# [I 2025-05-29 09:12:48,507] Trial 21 finished with value: 0.06912024983238681 and parameters: {'n_past': 8, 'n_neurons': 60, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.16379456393164318, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 88}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 411ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step
# [I 2025-05-29 09:15:04,270] Trial 22 finished with value: 0.09204565180868805 and parameters: {'n_past': 7, 'n_neurons': 48, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.15242520220186234, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 90}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 592ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
# [I 2025-05-29 09:17:05,382] Trial 23 finished with value: 0.0971708253539216 and parameters: {'n_past': 4, 'n_neurons': 84, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.22490618184435904, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 75}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# [I 2025-05-29 09:19:48,531] Trial 24 finished with value: 0.09282141598748594 and parameters: {'n_past': 10, 'n_neurons': 97, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.16346824921012254, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 92}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 477ms/step
# [I 2025-05-29 09:24:23,284] Trial 25 finished with value: 0.2180160153223321 and parameters: {'n_past': 2, 'n_neurons': 16, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.10486287476966566, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 92}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# [I 2025-05-29 09:25:07,828] Trial 26 finished with value: 0.07026436486258231 and parameters: {'n_past': 6, 'n_neurons': 67, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.2730594800634363, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 76}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 491ms/step
# [I 2025-05-29 09:27:21,070] Trial 27 finished with value: 0.11455430882958673 and parameters: {'n_past': 8, 'n_neurons': 66, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.21207032078198845, 'batch_size': 8, 'optimizer': 'rmsprop', 'epochs': 61}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 357ms/step
# [I 2025-05-29 09:29:28,987] Trial 28 finished with value: 1.2568961112658008 and parameters: {'n_past': 12, 'n_neurons': 78, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.35018942695707983, 'batch_size': 8, 'optimizer': 'sgd', 'epochs': 73}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 309ms/step
# [I 2025-05-29 09:30:12,782] Trial 29 finished with value: 0.1391841156774521 and parameters: {'n_past': 6, 'n_neurons': 47, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.30132453188595154, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 78}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# [I 2025-05-29 09:30:49,600] Trial 30 finished with value: 0.08913960832157754 and parameters: {'n_past': 5, 'n_neurons': 57, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.28144800457839986, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 60}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# [I 2025-05-29 09:31:36,525] Trial 31 finished with value: 0.08752759752804566 and parameters: {'n_past': 3, 'n_neurons': 78, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.25996106207639014, 'batch_size': 32, 'optimizer': 'rmsprop', 'epochs': 84}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# [I 2025-05-29 09:32:37,031] Trial 32 finished with value: 0.07385458933570048 and parameters: {'n_past': 8, 'n_neurons': 38, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3154140352563251, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 92}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# [I 2025-05-29 09:33:47,900] Trial 33 finished with value: 0.13303234825323593 and parameters: {'n_past': 11, 'n_neurons': 63, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3560406201967664, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 93}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# [I 2025-05-29 09:34:44,319] Trial 34 finished with value: 0.06906659998728852 and parameters: {'n_past': 8, 'n_neurons': 39, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3155576665902195, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 86}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 489ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 409ms/step
# [I 2025-05-29 09:36:11,764] Trial 35 finished with value: 0.541216973452058 and parameters: {'n_past': 6, 'n_neurons': 53, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.4262967451241517, 'batch_size': 16, 'optimizer': 'sgd', 'epochs': 85}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 389ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# [I 2025-05-29 09:36:36,263] Trial 36 finished with value: 0.34902270040665895 and parameters: {'n_past': 14, 'n_neurons': 47, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.23509726834062308, 'batch_size': 16, 'optimizer': 'adam', 'epochs': 11}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 445ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step
# [I 2025-05-29 09:38:05,892] Trial 37 finished with value: 0.28254905767230526 and parameters: {'n_past': 8, 'n_neurons': 72, 'n_layers': 2, 'activation': 'relu', 'dropout_rate': 0.2814213726016452, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 78}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# [I 2025-05-29 09:48:49,690] Trial 38 finished with value: 0.3666341662759347 and parameters: {'n_past': 10, 'n_neurons': 41, 'n_layers': 3, 'activation': 'tanh', 'dropout_rate': 0.4135509684317085, 'batch_size': 1, 'optimizer': 'rmsprop', 'epochs': 82}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# [I 2025-05-29 09:49:33,585] Trial 39 finished with value: 0.3835555418932478 and parameters: {'n_past': 5, 'n_neurons': 27, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.4861526545247888, 'batch_size': 16, 'optimizer': 'sgd', 'epochs': 69}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 344ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 354ms/step
# [I 2025-05-29 09:50:25,932] Trial 40 finished with value: 0.6089821284002301 and parameters: {'n_past': 7, 'n_neurons': 93, 'n_layers': 2, 'activation': 'sigmoid', 'dropout_rate': 0.3432698313999231, 'batch_size': 8, 'optimizer': 'adam', 'epochs': 20}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# [I 2025-05-29 09:51:27,885] Trial 41 finished with value: 0.0783019393019557 and parameters: {'n_past': 8, 'n_neurons': 40, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3070278904598196, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# [I 2025-05-29 09:52:28,328] Trial 42 finished with value: 0.14932596643010715 and parameters: {'n_past': 9, 'n_neurons': 36, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.31997640551210244, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 89}. Best is trial 13 with value: 0.06689510175608124.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# [I 2025-05-29 09:53:25,874] Trial 43 finished with value: 0.05187418342848604 and parameters: {'n_past': 3, 'n_neurons': 54, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.36481697626010984, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step
# [I 2025-05-29 09:54:33,973] Trial 44 finished with value: 0.10056775411473509 and parameters: {'n_past': 2, 'n_neurons': 54, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.374433360405786, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# [I 2025-05-29 09:56:33,364] Trial 45 finished with value: 0.05214091694631112 and parameters: {'n_past': 3, 'n_neurons': 62, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.3978076806933422, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 100}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 376ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step
# [I 2025-05-29 09:59:12,187] Trial 46 finished with value: 0.18333981292512752 and parameters: {'n_past': 2, 'n_neurons': 59, 'n_layers': 2, 'activation': 'tanh', 'dropout_rate': 0.4637031682977243, 'batch_size': 4, 'optimizer': 'adam', 'epochs': 100}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# [I 2025-05-29 10:00:55,897] Trial 47 finished with value: 0.06309339791088146 and parameters: {'n_past': 3, 'n_neurons': 29, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.39175516053879017, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 96}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# [I 2025-05-29 10:02:41,951] Trial 48 finished with value: 0.08098158682042167 and parameters: {'n_past': 3, 'n_neurons': 24, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.40217760132831554, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 95}. Best is trial 43 with value: 0.05187418342848604.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# [I 2025-05-29 10:03:24,873] Trial 49 finished with value: 0.09156415342899199 and parameters: {'n_past': 1, 'n_neurons': 44, 'n_layers': 1, 'activation': 'relu', 'dropout_rate': 0.4477630984320566, 'batch_size': 4, 'optimizer': 'rmsprop', 'epochs': 40}. Best is trial 43 with value: 0.05187418342848604.
# Best Hyperparameters: {'n_past': 3, 'n_neurons': 54, 'n_layers': 1, 'activation': 'tanh', 'dropout_rate': 0.36481697626010984, 'batch_size': 16, 'optimizer': 'rmsprop', 'epochs': 96}
