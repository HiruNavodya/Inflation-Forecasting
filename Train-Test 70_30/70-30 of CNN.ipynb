# %% [markdown]
# ## 1

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown


# Convert to a direct download link (Excel format)
download_url = "https://docs.google.com/spreadsheets/d/1tjx2ifyUsAAB-yxxuvTIjXNmkomA9OzW/export?format=xlsx"

# Output filename
output_file = "downloaded_file.xlsx"

# Download the file
gdown.download(download_url, output=output_file, quiet=False)

# === Step 2: Read Excel File ===
data = pd.read_excel(output_file)

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 1  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 1), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 12.0MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 03:54:18,787] A new study created in memory with name: no-name-01dfc8ee-107a-444a-8e6f-81608d6d186c
# [I 2025-04-09 03:54:38,961] Trial 0 finished with value: 0.0004098399852712949 and parameters: {'filters': 108, 'kernel_size': 1, 'lr': 0.0020019169772427974, 'epochs': 49, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:54:49,590] Trial 1 finished with value: 0.0007068033252532283 and parameters: {'filters': 106, 'kernel_size': 1, 'lr': 0.006987253974561896, 'epochs': 29, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:54:57,255] Trial 2 finished with value: 0.002734333354358872 and parameters: {'filters': 33, 'kernel_size': 1, 'lr': 0.0008518951106620779, 'epochs': 17, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:03,644] Trial 3 finished with value: 0.0016072699460589017 and parameters: {'filters': 60, 'kernel_size': 1, 'lr': 0.0072336680943665115, 'epochs': 11, 'batch_size': 16}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:14,284] Trial 4 finished with value: 0.001544778506892423 and parameters: {'filters': 110, 'kernel_size': 1, 'lr': 0.0008730077352111922, 'epochs': 27, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:28,752] Trial 5 finished with value: 0.002337402004438142 and parameters: {'filters': 64, 'kernel_size': 1, 'lr': 0.00036669736233845907, 'epochs': 42, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:37,474] Trial 6 finished with value: 0.0018061593679400783 and parameters: {'filters': 79, 'kernel_size': 1, 'lr': 0.0006742248621051352, 'epochs': 22, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:45,805] Trial 7 finished with value: 0.0034791118620584407 and parameters: {'filters': 96, 'kernel_size': 1, 'lr': 0.005697568936740413, 'epochs': 12, 'batch_size': 32}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:55:56,138] Trial 8 finished with value: 0.0007132927858037874 and parameters: {'filters': 89, 'kernel_size': 1, 'lr': 0.008128771570546103, 'epochs': 33, 'batch_size': 32}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:56:04,510] Trial 9 finished with value: 0.005158438192059596 and parameters: {'filters': 76, 'kernel_size': 1, 'lr': 0.0008302450936187732, 'epochs': 24, 'batch_size': 32}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:56:17,858] Trial 10 finished with value: 0.00656959096280237 and parameters: {'filters': 118, 'kernel_size': 1, 'lr': 0.00010217842086141908, 'epochs': 50, 'batch_size': 16}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:56:30,597] Trial 11 finished with value: 0.0005225441224562625 and parameters: {'filters': 125, 'kernel_size': 1, 'lr': 0.0027767905397825484, 'epochs': 35, 'batch_size': 8}. Best is trial 0 with value: 0.0004098399852712949.
# [I 2025-04-09 03:56:44,164] Trial 12 finished with value: 0.0003926420079854627 and parameters: {'filters': 121, 'kernel_size': 1, 'lr': 0.0029106118895831745, 'epochs': 39, 'batch_size': 8}. Best is trial 12 with value: 0.0003926420079854627.
# [I 2025-04-09 03:57:01,785] Trial 13 finished with value: 0.000438911597787713 and parameters: {'filters': 127, 'kernel_size': 1, 'lr': 0.002163356307017256, 'epochs': 50, 'batch_size': 8}. Best is trial 12 with value: 0.0003926420079854627.
# [I 2025-04-09 03:57:17,700] Trial 14 finished with value: 0.0003886831837007776 and parameters: {'filters': 103, 'kernel_size': 1, 'lr': 0.002501541781525165, 'epochs': 43, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:57:27,874] Trial 15 finished with value: 0.000637379843586435 and parameters: {'filters': 100, 'kernel_size': 1, 'lr': 0.0031967842982059255, 'epochs': 40, 'batch_size': 16}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:57:42,586] Trial 16 finished with value: 0.0006417183709951738 and parameters: {'filters': 116, 'kernel_size': 1, 'lr': 0.0016200038991503953, 'epochs': 41, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:57:57,394] Trial 17 finished with value: 0.0004873760723664115 and parameters: {'filters': 93, 'kernel_size': 1, 'lr': 0.004332157745553158, 'epochs': 45, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:58:08,018] Trial 18 finished with value: 0.003197475258881847 and parameters: {'filters': 128, 'kernel_size': 1, 'lr': 0.0004326800325550732, 'epochs': 36, 'batch_size': 16}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:58:20,244] Trial 19 finished with value: 0.0015348435651200514 and parameters: {'filters': 115, 'kernel_size': 1, 'lr': 0.0014647021761858374, 'epochs': 45, 'batch_size': 32}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:58:33,684] Trial 20 finished with value: 0.0006072656299996501 and parameters: {'filters': 39, 'kernel_size': 1, 'lr': 0.004178876504761916, 'epochs': 38, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:58:48,362] Trial 21 finished with value: 0.000640451418197093 and parameters: {'filters': 104, 'kernel_size': 1, 'lr': 0.001469298178389948, 'epochs': 46, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:59:03,824] Trial 22 finished with value: 0.0004398861055960879 and parameters: {'filters': 110, 'kernel_size': 1, 'lr': 0.002246362687684654, 'epochs': 47, 'batch_size': 8}. Best is trial 14 with value: 0.0003886831837007776.
# [I 2025-04-09 03:59:24,353] Trial 23 finished with value: 0.0003881491526650886 and parameters: {'filters': 84, 'kernel_size': 1, 'lr': 0.003948313304360598, 'epochs': 43, 'batch_size': 8}. Best is trial 23 with value: 0.0003881491526650886.
# [I 2025-04-09 03:59:39,521] Trial 24 finished with value: 0.000541499777076145 and parameters: {'filters': 84, 'kernel_size': 1, 'lr': 0.004100951552461839, 'epochs': 41, 'batch_size': 8}. Best is trial 23 with value: 0.0003881491526650886.
# [I 2025-04-09 03:59:52,062] Trial 25 finished with value: 0.000513635081006214 and parameters: {'filters': 70, 'kernel_size': 1, 'lr': 0.0032114090148431017, 'epochs': 32, 'batch_size': 8}. Best is trial 23 with value: 0.0003881491526650886.
# [I 2025-04-09 04:00:06,334] Trial 26 finished with value: 0.0005485625200284024 and parameters: {'filters': 52, 'kernel_size': 1, 'lr': 0.005132484581515534, 'epochs': 38, 'batch_size': 8}. Best is trial 23 with value: 0.0003881491526650886.
# [I 2025-04-09 04:00:21,994] Trial 27 finished with value: 0.0003823130294525375 and parameters: {'filters': 85, 'kernel_size': 1, 'lr': 0.008990902860453625, 'epochs': 43, 'batch_size': 8}. Best is trial 27 with value: 0.0003823130294525375.
# [I 2025-04-09 04:00:33,620] Trial 28 finished with value: 0.00034487267839722335 and parameters: {'filters': 86, 'kernel_size': 1, 'lr': 0.009541690979341124, 'epochs': 43, 'batch_size': 16}. Best is trial 28 with value: 0.00034487267839722335.
# [I 2025-04-09 04:00:46,877] Trial 29 finished with value: 0.0003668872232083231 and parameters: {'filters': 87, 'kernel_size': 1, 'lr': 0.009846092797043389, 'epochs': 48, 'batch_size': 16}. Best is trial 28 with value: 0.00034487267839722335.
# Best trial: {'filters': 86, 'kernel_size': 1, 'lr': 0.009541690979341124, 'epochs': 43, 'batch_size': 16}
# Epoch 1/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0181
# Epoch 2/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029
# Epoch 3/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016
# Epoch 4/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5246e-04
# Epoch 5/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2584e-04
# Epoch 6/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5971e-04
# Epoch 7/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8543e-04
# Epoch 8/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7402e-04
# Epoch 9/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3284e-04
# Epoch 10/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6055e-04
# Epoch 11/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6491e-04
# Epoch 12/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1498e-04
# Epoch 13/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8174e-04
# Epoch 14/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3670e-04
# Epoch 15/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1540e-04
# Epoch 16/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6448e-04
# Epoch 17/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0196e-04
# Epoch 18/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4355e-04
# Epoch 19/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0280e-04
# Epoch 20/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9603e-04
# Epoch 21/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7061e-04
# Epoch 22/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5272e-04
# Epoch 23/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3020e-04
# Epoch 24/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4941e-04
# Epoch 25/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8869e-04
# Epoch 26/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5941e-04
# Epoch 27/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0649e-04
# Epoch 28/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8256e-04
# Epoch 29/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7207e-04
# Epoch 30/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7121e-04
# Epoch 31/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4413e-04
# Epoch 32/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7383e-04
# Epoch 33/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3894e-04
# Epoch 34/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0924e-04
# Epoch 35/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7586e-04
# Epoch 36/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8678e-04
# Epoch 37/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1558e-04
# Epoch 38/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7371e-04
# Epoch 39/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2322e-04
# Epoch 40/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2091e-04
# Epoch 41/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2335e-04
# Epoch 42/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9059e-04
# Epoch 43/43
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3405e-04
# WARNING:tensorflow:5 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f3095e03d80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f3095e03d80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#  Test MSE  : 14.6749
#  Test RMSE : 3.8308
#  Test MAE  : 2.0654
#  Test MAPE : 36.77%
#  Test R²   : 0.9545

# %% [markdown]
# ## 2

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 12.0MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 7.9 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 10.0 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.15.2 colorlog-6.9.0 optuna-4.2.1

# %%
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 2  # Monthly data (1 year of past data to predict next month)

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

# %%
split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 2),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)
# Out:
# [I 2025-04-09 03:39:51,668] A new study created in memory with name: no-name-b1a8a468-10ed-4343-89e3-66112cce1f8d
# [I 2025-04-09 03:39:59,095] Trial 0 finished with value: 0.006622866300555567 and parameters: {'filters': 38, 'kernel_size': 1, 'lr': 0.0008386044947364455, 'epochs': 18, 'batch_size': 32}. Best is trial 0 with value: 0.006622866300555567.
# [I 2025-04-09 03:40:05,508] Trial 1 finished with value: 0.011137032716457421 and parameters: {'filters': 67, 'kernel_size': 2, 'lr': 0.000221751176132951, 'epochs': 14, 'batch_size': 32}. Best is trial 0 with value: 0.006622866300555567.
# [I 2025-04-09 03:40:12,296] Trial 2 finished with value: 0.013166751149886599 and parameters: {'filters': 62, 'kernel_size': 1, 'lr': 0.00013105019817336228, 'epochs': 21, 'batch_size': 16}. Best is trial 0 with value: 0.006622866300555567.
# [I 2025-04-09 03:40:19,937] Trial 3 finished with value: 0.0081047058920376 and parameters: {'filters': 41, 'kernel_size': 2, 'lr': 0.00018530809740918184, 'epochs': 11, 'batch_size': 8}. Best is trial 0 with value: 0.006622866300555567.
# [I 2025-04-09 03:40:31,385] Trial 4 finished with value: 0.0012453327265878518 and parameters: {'filters': 59, 'kernel_size': 2, 'lr': 0.004522963919921702, 'epochs': 45, 'batch_size': 32}. Best is trial 4 with value: 0.0012453327265878518.
# [I 2025-04-09 03:40:43,992] Trial 5 finished with value: 0.0005767125937078769 and parameters: {'filters': 34, 'kernel_size': 1, 'lr': 0.007494798151255776, 'epochs': 48, 'batch_size': 16}. Best is trial 5 with value: 0.0005767125937078769.
# [I 2025-04-09 03:40:51,247] Trial 6 finished with value: 0.0040903227248539524 and parameters: {'filters': 72, 'kernel_size': 1, 'lr': 0.0005673222938537172, 'epochs': 14, 'batch_size': 8}. Best is trial 5 with value: 0.0005767125937078769.
# [I 2025-04-09 03:41:11,295] Trial 7 finished with value: 0.0014499543661562104 and parameters: {'filters': 76, 'kernel_size': 1, 'lr': 0.0004912696849718266, 'epochs': 48, 'batch_size': 16}. Best is trial 5 with value: 0.0005767125937078769.
# [I 2025-04-09 03:41:21,154] Trial 8 finished with value: 0.004449177145337065 and parameters: {'filters': 104, 'kernel_size': 2, 'lr': 0.00030304182214610216, 'epochs': 36, 'batch_size': 32}. Best is trial 5 with value: 0.0005767125937078769.
# [I 2025-04-09 03:41:42,303] Trial 9 finished with value: 0.0004231218481436372 and parameters: {'filters': 122, 'kernel_size': 2, 'lr': 0.007979850844909238, 'epochs': 41, 'batch_size': 16}. Best is trial 9 with value: 0.0004231218481436372.
# [I 2025-04-09 03:41:52,638] Trial 10 finished with value: 0.0008492484145487348 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.0022827339790759257, 'epochs': 34, 'batch_size': 16}. Best is trial 9 with value: 0.0004231218481436372.
# [I 2025-04-09 03:42:04,525] Trial 11 finished with value: 0.00041489397214415175 and parameters: {'filters': 98, 'kernel_size': 1, 'lr': 0.005103003328647025, 'epochs': 42, 'batch_size': 16}. Best is trial 11 with value: 0.00041489397214415175.
# [I 2025-04-09 03:42:17,992] Trial 12 finished with value: 0.0005817262620742744 and parameters: {'filters': 102, 'kernel_size': 2, 'lr': 0.0024111378291904544, 'epochs': 41, 'batch_size': 16}. Best is trial 11 with value: 0.00041489397214415175.
# [I 2025-04-09 03:42:29,408] Trial 13 finished with value: 0.0003534331384192531 and parameters: {'filters': 125, 'kernel_size': 1, 'lr': 0.009069384769247664, 'epochs': 27, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:42:40,618] Trial 14 finished with value: 0.0011602241623525817 and parameters: {'filters': 101, 'kernel_size': 1, 'lr': 0.002810191790421517, 'epochs': 27, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:42:53,740] Trial 15 finished with value: 0.0006317046548550328 and parameters: {'filters': 90, 'kernel_size': 1, 'lr': 0.0043203801450756845, 'epochs': 27, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:43:07,968] Trial 16 finished with value: 0.0008399966997482503 and parameters: {'filters': 117, 'kernel_size': 1, 'lr': 0.0013222269564125866, 'epochs': 31, 'batch_size': 8}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:43:16,576] Trial 17 finished with value: 0.0008248892069483796 and parameters: {'filters': 88, 'kernel_size': 1, 'lr': 0.0087422810630203, 'epochs': 23, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:43:30,446] Trial 18 finished with value: 0.0005983295171366384 and parameters: {'filters': 113, 'kernel_size': 1, 'lr': 0.004929438653977881, 'epochs': 38, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:43:43,275] Trial 19 finished with value: 0.0008100257449162503 and parameters: {'filters': 108, 'kernel_size': 1, 'lr': 0.0013548297119244717, 'epochs': 28, 'batch_size': 8}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:43:57,303] Trial 20 finished with value: 0.00036115815843610716 and parameters: {'filters': 88, 'kernel_size': 1, 'lr': 0.009511674160273716, 'epochs': 42, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:44:23,547] Trial 21 finished with value: 0.0004485781828407198 and parameters: {'filters': 90, 'kernel_size': 1, 'lr': 0.006042985144106214, 'epochs': 43, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:44:32,885] Trial 22 finished with value: 0.0003630483552115038 and parameters: {'filters': 82, 'kernel_size': 1, 'lr': 0.009163621645004425, 'epochs': 32, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:44:50,011] Trial 23 finished with value: 0.0004212768593182166 and parameters: {'filters': 54, 'kernel_size': 1, 'lr': 0.009909037954659054, 'epochs': 33, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:45:05,301] Trial 24 finished with value: 0.0009990292455768213 and parameters: {'filters': 82, 'kernel_size': 1, 'lr': 0.0030459882639980373, 'epochs': 24, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:45:20,933] Trial 25 finished with value: 0.00047946929407771677 and parameters: {'filters': 81, 'kernel_size': 1, 'lr': 0.009836168976851505, 'epochs': 31, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:45:44,294] Trial 26 finished with value: 0.0006327049874622995 and parameters: {'filters': 46, 'kernel_size': 1, 'lr': 0.003587163441065896, 'epochs': 50, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:45:57,531] Trial 27 finished with value: 0.0005608699769557764 and parameters: {'filters': 95, 'kernel_size': 1, 'lr': 0.006423891064111327, 'epochs': 37, 'batch_size': 16}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:46:04,913] Trial 28 finished with value: 0.0019684865643891194 and parameters: {'filters': 111, 'kernel_size': 1, 'lr': 0.0016764535185539331, 'epochs': 19, 'batch_size': 32}. Best is trial 13 with value: 0.0003534331384192531.
# [I 2025-04-09 03:46:17,837] Trial 29 finished with value: 0.0009097527654375881 and parameters: {'filters': 128, 'kernel_size': 1, 'lr': 0.0009244009198996932, 'epochs': 38, 'batch_size': 8}. Best is trial 13 with value: 0.0003534331384192531.
# Best trial: {'filters': 125, 'kernel_size': 1, 'lr': 0.009069384769247664, 'epochs': 27, 'batch_size': 16}

# %%
# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)
# Out:
# Epoch 1/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0144
# Epoch 2/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023
# Epoch 3/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 4/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4500e-04
# Epoch 5/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3078e-04
# Epoch 6/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6664e-04
# Epoch 7/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9339e-04
# Epoch 8/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5169e-04
# Epoch 9/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5319e-04
# Epoch 10/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1946e-04
# Epoch 11/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8129e-04
# Epoch 12/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7829e-04
# Epoch 13/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3850e-04
# Epoch 14/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4765e-04
# Epoch 15/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8002e-04
# Epoch 16/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5283e-04
# Epoch 17/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8400e-04
# Epoch 18/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6574e-04
# Epoch 19/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7245e-04
# Epoch 20/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5718e-04
# Epoch 21/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5718e-04
# Epoch 22/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3304e-04
# Epoch 23/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0327e-04
# Epoch 24/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4583e-04
# Epoch 25/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6751e-04
# Epoch 26/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2030e-04
# Epoch 27/27
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2656e-04

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"Test MSE: {mse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test R2: {r2:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Test MSE: 0.0034
# Test MAE: 0.0356
# Test R2: 0.9417

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#  Test MSE  : 0.0034
#  Test RMSE : 0.0586
#  Test MAE  : 0.0356
#  Test MAPE : inf%
#  Test R²   : 0.9417

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()

# %% [markdown]
# ## 3

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 3  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 3), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 19.7MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 03:46:35,415] A new study created in memory with name: no-name-94fb88e2-711a-4c27-a84f-dffde654ec86
# [I 2025-04-09 03:47:00,628] Trial 0 finished with value: 0.0006860939999266217 and parameters: {'filters': 86, 'kernel_size': 3, 'lr': 0.0014740541521681438, 'epochs': 41, 'batch_size': 16}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:47:15,821] Trial 1 finished with value: 0.0019114622458194692 and parameters: {'filters': 67, 'kernel_size': 3, 'lr': 0.001582041791012459, 'epochs': 15, 'batch_size': 32}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:47:48,821] Trial 2 finished with value: 0.0014346722261204075 and parameters: {'filters': 82, 'kernel_size': 2, 'lr': 0.0004858349094566965, 'epochs': 50, 'batch_size': 8}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:48:17,348] Trial 3 finished with value: 0.0019685370304311314 and parameters: {'filters': 122, 'kernel_size': 3, 'lr': 0.00018459146029540426, 'epochs': 43, 'batch_size': 8}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:48:29,480] Trial 4 finished with value: 0.0012783936496513586 and parameters: {'filters': 99, 'kernel_size': 1, 'lr': 0.0009908482210079185, 'epochs': 37, 'batch_size': 16}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:48:39,477] Trial 5 finished with value: 0.007282151918237408 and parameters: {'filters': 53, 'kernel_size': 3, 'lr': 0.0002297983508040299, 'epochs': 28, 'batch_size': 32}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:48:47,426] Trial 6 finished with value: 0.0015999453122882794 and parameters: {'filters': 34, 'kernel_size': 3, 'lr': 0.00952841980601327, 'epochs': 30, 'batch_size': 32}. Best is trial 0 with value: 0.0006860939999266217.
# [I 2025-04-09 03:49:04,506] Trial 7 finished with value: 0.0004964182395876074 and parameters: {'filters': 71, 'kernel_size': 2, 'lr': 0.004487482145867656, 'epochs': 49, 'batch_size': 8}. Best is trial 7 with value: 0.0004964182395876074.
# [I 2025-04-09 03:49:10,332] Trial 8 finished with value: 0.0014297112938947976 and parameters: {'filters': 41, 'kernel_size': 3, 'lr': 0.004588415932391265, 'epochs': 13, 'batch_size': 16}. Best is trial 7 with value: 0.0004964182395876074.
# [I 2025-04-09 03:49:25,575] Trial 9 finished with value: 0.002256901585496962 and parameters: {'filters': 39, 'kernel_size': 2, 'lr': 0.0008217564367002587, 'epochs': 23, 'batch_size': 32}. Best is trial 7 with value: 0.0004964182395876074.
# [I 2025-04-09 03:49:57,324] Trial 10 finished with value: 0.00041481082735117525 and parameters: {'filters': 107, 'kernel_size': 1, 'lr': 0.003635633877390448, 'epochs': 49, 'batch_size': 8}. Best is trial 10 with value: 0.00041481082735117525.
# [I 2025-04-09 03:50:21,487] Trial 11 finished with value: 0.0004314316514258583 and parameters: {'filters': 118, 'kernel_size': 1, 'lr': 0.003113507591999454, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.00041481082735117525.
# [I 2025-04-09 03:50:39,125] Trial 12 finished with value: 0.0004521917338327815 and parameters: {'filters': 127, 'kernel_size': 1, 'lr': 0.0034908202075022558, 'epochs': 44, 'batch_size': 8}. Best is trial 10 with value: 0.00041481082735117525.
# [I 2025-04-09 03:50:53,377] Trial 13 finished with value: 0.00039046773842225474 and parameters: {'filters': 110, 'kernel_size': 1, 'lr': 0.00918294839879821, 'epochs': 36, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:51:07,147] Trial 14 finished with value: 0.00040625301577771705 and parameters: {'filters': 105, 'kernel_size': 1, 'lr': 0.008732235396292927, 'epochs': 36, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:51:20,642] Trial 15 finished with value: 0.0004275776930929472 and parameters: {'filters': 100, 'kernel_size': 1, 'lr': 0.009127182092870813, 'epochs': 36, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:51:30,330] Trial 16 finished with value: 0.00039306363517728943 and parameters: {'filters': 110, 'kernel_size': 2, 'lr': 0.007249764673968896, 'epochs': 24, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:51:40,049] Trial 17 finished with value: 0.0009395216523747271 and parameters: {'filters': 91, 'kernel_size': 2, 'lr': 0.002446236231048548, 'epochs': 21, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:51:49,986] Trial 18 finished with value: 0.0006562895432580262 and parameters: {'filters': 113, 'kernel_size': 2, 'lr': 0.005903808382885869, 'epochs': 25, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:52:00,121] Trial 19 finished with value: 0.0022136971820145845 and parameters: {'filters': 93, 'kernel_size': 2, 'lr': 0.00037308106669428745, 'epochs': 31, 'batch_size': 16}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:52:08,565] Trial 20 finished with value: 0.0007020311507706841 and parameters: {'filters': 113, 'kernel_size': 1, 'lr': 0.0021798511239285697, 'epochs': 18, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:52:21,966] Trial 21 finished with value: 0.0006814130756538361 and parameters: {'filters': 102, 'kernel_size': 1, 'lr': 0.007035478497245474, 'epochs': 36, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:52:33,923] Trial 22 finished with value: 0.00339496818681558 and parameters: {'filters': 110, 'kernel_size': 1, 'lr': 0.0001081251962907549, 'epochs': 33, 'batch_size': 8}. Best is trial 13 with value: 0.00039046773842225474.
# [I 2025-04-09 03:52:43,731] Trial 23 finished with value: 0.00037348469292434555 and parameters: {'filters': 127, 'kernel_size': 2, 'lr': 0.006400808577726271, 'epochs': 27, 'batch_size': 8}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:52:57,368] Trial 24 finished with value: 0.00052505077716584 and parameters: {'filters': 124, 'kernel_size': 2, 'lr': 0.006438258445048911, 'epochs': 27, 'batch_size': 8}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:53:06,118] Trial 25 finished with value: 0.0006569182975605751 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.005324870490637401, 'epochs': 18, 'batch_size': 8}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:53:15,580] Trial 26 finished with value: 0.0005762867028048883 and parameters: {'filters': 117, 'kernel_size': 2, 'lr': 0.0021246785813873502, 'epochs': 21, 'batch_size': 8}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:53:28,295] Trial 27 finished with value: 0.0005659566377289593 and parameters: {'filters': 76, 'kernel_size': 2, 'lr': 0.006998839548600997, 'epochs': 33, 'batch_size': 8}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:53:36,660] Trial 28 finished with value: 0.0008299720745223264 and parameters: {'filters': 120, 'kernel_size': 2, 'lr': 0.009648593685687124, 'epochs': 26, 'batch_size': 32}. Best is trial 23 with value: 0.00037348469292434555.
# [I 2025-04-09 03:53:48,108] Trial 29 finished with value: 0.0010348339565098286 and parameters: {'filters': 89, 'kernel_size': 3, 'lr': 0.0014522726165583587, 'epochs': 39, 'batch_size': 16}. Best is trial 23 with value: 0.00037348469292434555.
# Best trial: {'filters': 127, 'kernel_size': 2, 'lr': 0.006400808577726271, 'epochs': 27, 'batch_size': 8}
# Epoch 1/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0072
# Epoch 2/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5429e-04
# Epoch 3/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3726e-04
# Epoch 4/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4643e-04
# Epoch 5/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0792e-04
# Epoch 6/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8873e-04
# Epoch 7/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3572e-04
# Epoch 8/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8696e-04
# Epoch 9/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9476e-04
# Epoch 10/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9159e-04
# Epoch 11/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1479e-04
# Epoch 12/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9413e-04
# Epoch 13/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9525e-04
# Epoch 14/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5472e-04
# Epoch 15/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6823e-04
# Epoch 16/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3639e-04
# Epoch 17/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3033e-04
# Epoch 18/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2348e-04
# Epoch 19/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2132e-04
# Epoch 20/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6374e-04
# Epoch 21/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3353e-04
# Epoch 22/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2439e-04
# Epoch 23/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1510e-04
# Epoch 24/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3346e-04
# Epoch 25/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3573e-04
# Epoch 26/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4455e-04
# Epoch 27/27
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8607e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  Test MSE  : 10.3694
#  Test RMSE : 3.2202
#  Test MAE  : 1.7774
#  Test MAPE : 37.91%
#  Test R²   : 0.9682

# %% [markdown]
# ## 4

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 4  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 4), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 29.5MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:01:20,081] A new study created in memory with name: no-name-c101a15e-ddee-4c02-a981-c00df039583e
# [I 2025-04-09 04:01:39,982] Trial 0 finished with value: 0.0027503566234372556 and parameters: {'filters': 106, 'kernel_size': 1, 'lr': 0.00010307665034763662, 'epochs': 50, 'batch_size': 8}. Best is trial 0 with value: 0.0027503566234372556.
# [I 2025-04-09 04:01:55,823] Trial 1 finished with value: 0.0005097553075756878 and parameters: {'filters': 52, 'kernel_size': 1, 'lr': 0.005029800336722828, 'epochs': 49, 'batch_size': 8}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:08,886] Trial 2 finished with value: 0.0016397608948561053 and parameters: {'filters': 50, 'kernel_size': 2, 'lr': 0.0008422829702685428, 'epochs': 49, 'batch_size': 16}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:19,772] Trial 3 finished with value: 0.0019523101897599797 and parameters: {'filters': 99, 'kernel_size': 2, 'lr': 0.0002867071346678467, 'epochs': 40, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:31,968] Trial 4 finished with value: 0.0007715497292034949 and parameters: {'filters': 53, 'kernel_size': 4, 'lr': 0.009837519741461855, 'epochs': 49, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:41,046] Trial 5 finished with value: 0.001204165038264667 and parameters: {'filters': 116, 'kernel_size': 4, 'lr': 0.0016681827115232778, 'epochs': 31, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:47,791] Trial 6 finished with value: 0.00746954131561021 and parameters: {'filters': 90, 'kernel_size': 4, 'lr': 0.00025010336443364033, 'epochs': 19, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:02:57,100] Trial 7 finished with value: 0.00238909098940591 and parameters: {'filters': 93, 'kernel_size': 2, 'lr': 0.00035855306627082044, 'epochs': 34, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:03:04,340] Trial 8 finished with value: 0.001069895214944457 and parameters: {'filters': 81, 'kernel_size': 1, 'lr': 0.008339306242961857, 'epochs': 16, 'batch_size': 16}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:03:16,650] Trial 9 finished with value: 0.009890318227310976 and parameters: {'filters': 98, 'kernel_size': 2, 'lr': 0.00013115323984634324, 'epochs': 50, 'batch_size': 32}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:03:29,164] Trial 10 finished with value: 0.0009144999494310468 and parameters: {'filters': 37, 'kernel_size': 3, 'lr': 0.003073228694363635, 'epochs': 24, 'batch_size': 8}. Best is trial 1 with value: 0.0005097553075756878.
# [I 2025-04-09 04:03:44,364] Trial 11 finished with value: 0.00034099907012811553 and parameters: {'filters': 61, 'kernel_size': 3, 'lr': 0.009286775059094572, 'epochs': 41, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:03:59,093] Trial 12 finished with value: 0.0005066759282878289 and parameters: {'filters': 64, 'kernel_size': 3, 'lr': 0.004006924647536371, 'epochs': 41, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:04:13,912] Trial 13 finished with value: 0.00046448786937010783 and parameters: {'filters': 70, 'kernel_size': 3, 'lr': 0.0030726482961666184, 'epochs': 40, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:04:29,647] Trial 14 finished with value: 0.0009075686781822393 and parameters: {'filters': 70, 'kernel_size': 3, 'lr': 0.0018238414174275724, 'epochs': 38, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:04:36,136] Trial 15 finished with value: 0.0012635055172722787 and parameters: {'filters': 79, 'kernel_size': 3, 'lr': 0.00536065161372131, 'epochs': 10, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:04:50,809] Trial 16 finished with value: 0.0007632456157201281 and parameters: {'filters': 66, 'kernel_size': 3, 'lr': 0.0021255323020362826, 'epochs': 41, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:05:06,473] Trial 17 finished with value: 0.0010688191590209801 and parameters: {'filters': 35, 'kernel_size': 4, 'lr': 0.001155384708873299, 'epochs': 44, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:05:14,524] Trial 18 finished with value: 0.0011503283894853666 and parameters: {'filters': 76, 'kernel_size': 3, 'lr': 0.006408603830751442, 'epochs': 27, 'batch_size': 16}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:05:27,333] Trial 19 finished with value: 0.0005668813246302307 and parameters: {'filters': 127, 'kernel_size': 2, 'lr': 0.003285235403626984, 'epochs': 35, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:05:43,404] Trial 20 finished with value: 0.0013285070211471368 and parameters: {'filters': 59, 'kernel_size': 4, 'lr': 0.0006726469113651163, 'epochs': 44, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:05:57,477] Trial 21 finished with value: 0.0005492395527350405 and parameters: {'filters': 62, 'kernel_size': 3, 'lr': 0.004539925697422087, 'epochs': 43, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:06:10,524] Trial 22 finished with value: 0.0005665796876807386 and parameters: {'filters': 44, 'kernel_size': 3, 'lr': 0.0037709494498983057, 'epochs': 36, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:06:22,272] Trial 23 finished with value: 0.0007784732685346777 and parameters: {'filters': 71, 'kernel_size': 3, 'lr': 0.0026584253072070596, 'epochs': 31, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:06:37,061] Trial 24 finished with value: 0.00036597515281755477 and parameters: {'filters': 85, 'kernel_size': 3, 'lr': 0.007414888788004573, 'epochs': 45, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:06:49,394] Trial 25 finished with value: 0.0009374954582502445 and parameters: {'filters': 85, 'kernel_size': 2, 'lr': 0.007728476129234295, 'epochs': 45, 'batch_size': 16}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:07:04,125] Trial 26 finished with value: 0.0008791143773123622 and parameters: {'filters': 74, 'kernel_size': 3, 'lr': 0.0065195554257400055, 'epochs': 46, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:07:17,606] Trial 27 finished with value: 0.0003640537130801628 and parameters: {'filters': 84, 'kernel_size': 4, 'lr': 0.008932498383406116, 'epochs': 40, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:07:30,706] Trial 28 finished with value: 0.0005303182842908427 and parameters: {'filters': 107, 'kernel_size': 4, 'lr': 0.009195084196998961, 'epochs': 37, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# [I 2025-04-09 04:07:46,600] Trial 29 finished with value: 0.0003817120013991371 and parameters: {'filters': 84, 'kernel_size': 4, 'lr': 0.006748844615505488, 'epochs': 47, 'batch_size': 8}. Best is trial 11 with value: 0.00034099907012811553.
# Best trial: {'filters': 61, 'kernel_size': 3, 'lr': 0.009286775059094572, 'epochs': 41, 'batch_size': 8}
# Epoch 1/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0074
# Epoch 2/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 3/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7581e-04
# Epoch 4/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0838e-04
# Epoch 5/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6002e-04
# Epoch 6/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2035e-04
# Epoch 7/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3479e-04
# Epoch 8/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8500e-04
# Epoch 9/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8758e-04
# Epoch 10/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7613e-04
# Epoch 11/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2774e-04
# Epoch 12/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9798e-04
# Epoch 13/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1613e-04
# Epoch 14/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2015e-04
# Epoch 15/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6800e-04
# Epoch 16/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9573e-04
# Epoch 17/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0343e-04
# Epoch 18/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5669e-04
# Epoch 19/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7400e-04
# Epoch 20/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6867e-04
# Epoch 21/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2583e-04
# Epoch 22/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1508e-04
# Epoch 23/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1417e-04
# Epoch 24/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7928e-04
# Epoch 25/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0066e-04
# Epoch 26/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 27/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3981e-04
# Epoch 28/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2113e-04
# Epoch 29/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8336e-04
# Epoch 30/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6920e-04
# Epoch 31/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# Epoch 32/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2680e-04
# Epoch 33/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7020e-04
# Epoch 34/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6887e-04
# Epoch 35/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7103e-04
# Epoch 36/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8913e-04
# Epoch 37/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3228e-04
# Epoch 38/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2335e-04
# Epoch 39/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4420e-04
# Epoch 40/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1322e-04
# Epoch 41/41
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1254e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#  Test MSE  : 9.5917
#  Test RMSE : 3.0971
#  Test MAE  : 1.7915
#  Test MAPE : 43.10%
#  Test R²   : 0.9706

# %% [markdown]
# ## 5

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 5  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 5), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 7.58MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:08:16,951] A new study created in memory with name: no-name-fe1a40c4-3b93-40da-8060-f09203d2289c
# [I 2025-04-09 04:08:31,813] Trial 0 finished with value: 0.0011824931910571952 and parameters: {'filters': 106, 'kernel_size': 5, 'lr': 0.0018575026853849452, 'epochs': 23, 'batch_size': 8}. Best is trial 0 with value: 0.0011824931910571952.
# [I 2025-04-09 04:08:46,400] Trial 1 finished with value: 0.0010323773603886366 and parameters: {'filters': 86, 'kernel_size': 3, 'lr': 0.009626470273604287, 'epochs': 36, 'batch_size': 32}. Best is trial 1 with value: 0.0010323773603886366.
# [I 2025-04-09 04:08:57,471] Trial 2 finished with value: 0.0026707584814478955 and parameters: {'filters': 84, 'kernel_size': 2, 'lr': 0.0003297990081131054, 'epochs': 32, 'batch_size': 16}. Best is trial 1 with value: 0.0010323773603886366.
# [I 2025-04-09 04:09:14,416] Trial 3 finished with value: 0.0008107227428505818 and parameters: {'filters': 34, 'kernel_size': 3, 'lr': 0.003560847906233012, 'epochs': 49, 'batch_size': 8}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:09:23,637] Trial 4 finished with value: 0.0021301526188229523 and parameters: {'filters': 83, 'kernel_size': 3, 'lr': 0.00014560864408374592, 'epochs': 24, 'batch_size': 8}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:09:29,576] Trial 5 finished with value: 0.017844440454306703 and parameters: {'filters': 109, 'kernel_size': 4, 'lr': 0.0003749747486823509, 'epochs': 10, 'batch_size': 32}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:09:34,615] Trial 6 finished with value: 0.004436270256216328 and parameters: {'filters': 74, 'kernel_size': 3, 'lr': 0.000552058094822142, 'epochs': 10, 'batch_size': 32}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:09:41,565] Trial 7 finished with value: 0.00776540096073101 and parameters: {'filters': 114, 'kernel_size': 4, 'lr': 0.0001864191442267688, 'epochs': 16, 'batch_size': 32}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:09:54,022] Trial 8 finished with value: 0.0015414306932749848 and parameters: {'filters': 112, 'kernel_size': 5, 'lr': 0.0008612902985727653, 'epochs': 50, 'batch_size': 32}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:10:03,656] Trial 9 finished with value: 0.00400207187825193 and parameters: {'filters': 91, 'kernel_size': 3, 'lr': 0.0003415234369733192, 'epochs': 31, 'batch_size': 32}. Best is trial 3 with value: 0.0008107227428505818.
# [I 2025-04-09 04:10:18,801] Trial 10 finished with value: 0.0003713475986539076 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.004704134789530023, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:10:34,344] Trial 11 finished with value: 0.0004610246008572479 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.003769313311195042, 'epochs': 49, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:10:48,062] Trial 12 finished with value: 0.0005073333353114625 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.005304316672942735, 'epochs': 41, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:11:02,698] Trial 13 finished with value: 0.0006533388368552551 and parameters: {'filters': 51, 'kernel_size': 1, 'lr': 0.0023984849357850118, 'epochs': 43, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:11:14,448] Trial 14 finished with value: 0.0007984193313556412 and parameters: {'filters': 53, 'kernel_size': 1, 'lr': 0.009189267424031939, 'epochs': 45, 'batch_size': 16}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:11:27,274] Trial 15 finished with value: 0.000768584276859959 and parameters: {'filters': 48, 'kernel_size': 2, 'lr': 0.0016049678920812304, 'epochs': 38, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:11:42,245] Trial 16 finished with value: 0.0005519543095336606 and parameters: {'filters': 68, 'kernel_size': 2, 'lr': 0.004596984549763093, 'epochs': 46, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:11:53,047] Trial 17 finished with value: 0.0014468030713032931 and parameters: {'filters': 60, 'kernel_size': 1, 'lr': 0.0011245154690922455, 'epochs': 38, 'batch_size': 16}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:08,664] Trial 18 finished with value: 0.0006664674632096043 and parameters: {'filters': 40, 'kernel_size': 2, 'lr': 0.0029347141791391048, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:18,679] Trial 19 finished with value: 0.00043552146235015243 and parameters: {'filters': 45, 'kernel_size': 1, 'lr': 0.005364427591455692, 'epochs': 26, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:27,646] Trial 20 finished with value: 0.00041331715571383637 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.007371976907370219, 'epochs': 24, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:38,159] Trial 21 finished with value: 0.000404078343611521 and parameters: {'filters': 124, 'kernel_size': 2, 'lr': 0.006343164775805734, 'epochs': 26, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:47,316] Trial 22 finished with value: 0.0008987293889125189 and parameters: {'filters': 123, 'kernel_size': 2, 'lr': 0.007221676037387921, 'epochs': 22, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:12:55,421] Trial 23 finished with value: 0.0008210702217184007 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.006116721689776576, 'epochs': 19, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:13:05,046] Trial 24 finished with value: 0.0006777907547075301 and parameters: {'filters': 98, 'kernel_size': 2, 'lr': 0.007593477791722604, 'epochs': 28, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:13:21,218] Trial 25 finished with value: 0.0010700495574080076 and parameters: {'filters': 122, 'kernel_size': 2, 'lr': 0.001775407489374784, 'epochs': 32, 'batch_size': 16}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:13:28,578] Trial 26 finished with value: 0.0012735959511095036 and parameters: {'filters': 100, 'kernel_size': 1, 'lr': 0.0028600156732044046, 'epochs': 16, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:13:40,072] Trial 27 finished with value: 0.0005678525631083176 and parameters: {'filters': 120, 'kernel_size': 2, 'lr': 0.004096397175002976, 'epochs': 28, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:13:48,781] Trial 28 finished with value: 0.0009155656637934347 and parameters: {'filters': 66, 'kernel_size': 1, 'lr': 0.009547458988557054, 'epochs': 19, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# [I 2025-04-09 04:14:00,931] Trial 29 finished with value: 0.0009254600736312568 and parameters: {'filters': 104, 'kernel_size': 4, 'lr': 0.0021798613392465427, 'epochs': 34, 'batch_size': 8}. Best is trial 10 with value: 0.0003713475986539076.
# Best trial: {'filters': 32, 'kernel_size': 1, 'lr': 0.004704134789530023, 'epochs': 50, 'batch_size': 8}
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0108
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9441e-04
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2787e-04
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0212e-04
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4262e-04
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9922e-04
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8431e-04
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6350e-04
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0391e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9229e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2765e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6003e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5496e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9657e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5404e-04
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2280e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5962e-04
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3039e-04
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7241e-04
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5981e-04
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9311e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6309e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2273e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6135e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7606e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9709e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6550e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6800e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4164e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3205e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2342e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2539e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3279e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0317e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9192e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2741e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3216e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6069e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0066e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4531e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1572e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0527e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8706e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7941e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  Test MSE  : 10.3363
#  Test RMSE : 3.2150
#  Test MAE  : 1.8772
#  Test MAPE : 42.19%
#  Test R²   : 0.9683

# %% [markdown]
# ## 6

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 6  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 6), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 5.76MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:14:35,607] A new study created in memory with name: no-name-4aead441-79da-4423-bef2-1cebf468fb99
# [I 2025-04-09 04:14:46,239] Trial 0 finished with value: 0.0020825787408587835 and parameters: {'filters': 63, 'kernel_size': 1, 'lr': 0.000792357538691801, 'epochs': 14, 'batch_size': 8}. Best is trial 0 with value: 0.0020825787408587835.
# [I 2025-04-09 04:14:51,811] Trial 1 finished with value: 0.0013339845075582464 and parameters: {'filters': 112, 'kernel_size': 2, 'lr': 0.005142854929063625, 'epochs': 11, 'batch_size': 16}. Best is trial 1 with value: 0.0013339845075582464.
# [I 2025-04-09 04:15:06,024] Trial 2 finished with value: 0.002869748044759035 and parameters: {'filters': 34, 'kernel_size': 2, 'lr': 0.00014250216156332687, 'epochs': 39, 'batch_size': 8}. Best is trial 1 with value: 0.0013339845075582464.
# [I 2025-04-09 04:15:21,070] Trial 3 finished with value: 0.0006693023266658807 and parameters: {'filters': 106, 'kernel_size': 1, 'lr': 0.001114129511578932, 'epochs': 43, 'batch_size': 8}. Best is trial 3 with value: 0.0006693023266658807.
# [I 2025-04-09 04:15:35,243] Trial 4 finished with value: 0.0004657800988449405 and parameters: {'filters': 92, 'kernel_size': 3, 'lr': 0.004641102357478622, 'epochs': 38, 'batch_size': 8}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:15:49,888] Trial 5 finished with value: 0.0015592266184588273 and parameters: {'filters': 55, 'kernel_size': 6, 'lr': 0.00012841876506533039, 'epochs': 43, 'batch_size': 8}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:15:55,887] Trial 6 finished with value: 0.016924538377982874 and parameters: {'filters': 51, 'kernel_size': 3, 'lr': 0.00017017127194555879, 'epochs': 18, 'batch_size': 32}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:16:05,774] Trial 7 finished with value: 0.0009597347137363007 and parameters: {'filters': 91, 'kernel_size': 6, 'lr': 0.0031593454850761824, 'epochs': 32, 'batch_size': 16}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:16:17,051] Trial 8 finished with value: 0.0020817703722665706 and parameters: {'filters': 111, 'kernel_size': 4, 'lr': 0.000245989683749615, 'epochs': 44, 'batch_size': 32}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:16:26,731] Trial 9 finished with value: 0.0019787533092312515 and parameters: {'filters': 71, 'kernel_size': 4, 'lr': 0.00040543422597275823, 'epochs': 35, 'batch_size': 32}. Best is trial 4 with value: 0.0004657800988449405.
# [I 2025-04-09 04:16:36,674] Trial 10 finished with value: 0.0004127205756958574 and parameters: {'filters': 90, 'kernel_size': 5, 'lr': 0.008430042751347452, 'epochs': 27, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:16:45,847] Trial 11 finished with value: 0.0009876071708276868 and parameters: {'filters': 88, 'kernel_size': 5, 'lr': 0.0087465389966142, 'epochs': 24, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:16:56,073] Trial 12 finished with value: 0.0006831270584370941 and parameters: {'filters': 127, 'kernel_size': 5, 'lr': 0.0024500895584869827, 'epochs': 25, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:17:11,868] Trial 13 finished with value: 0.0008859001973178238 and parameters: {'filters': 81, 'kernel_size': 3, 'lr': 0.008618844987852377, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:17:22,774] Trial 14 finished with value: 0.001408631990974148 and parameters: {'filters': 97, 'kernel_size': 5, 'lr': 0.0021900158080078373, 'epochs': 27, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:17:30,560] Trial 15 finished with value: 0.0009315797360613942 and parameters: {'filters': 76, 'kernel_size': 4, 'lr': 0.004369761764570349, 'epochs': 20, 'batch_size': 16}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:17:42,608] Trial 16 finished with value: 0.0007579674759957319 and parameters: {'filters': 102, 'kernel_size': 3, 'lr': 0.0016083714222955173, 'epochs': 33, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:17:56,740] Trial 17 finished with value: 0.0005393948037332544 and parameters: {'filters': 127, 'kernel_size': 2, 'lr': 0.005409908450494741, 'epochs': 38, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:18:05,837] Trial 18 finished with value: 0.001027192804031074 and parameters: {'filters': 86, 'kernel_size': 5, 'lr': 0.009382795648519236, 'epochs': 29, 'batch_size': 32}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:18:12,853] Trial 19 finished with value: 0.0017142457460674148 and parameters: {'filters': 117, 'kernel_size': 6, 'lr': 0.0008851530385863886, 'epochs': 22, 'batch_size': 16}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:18:29,997] Trial 20 finished with value: 0.00043241906193240237 and parameters: {'filters': 97, 'kernel_size': 4, 'lr': 0.004244932501110971, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:18:46,968] Trial 21 finished with value: 0.00043188390069796395 and parameters: {'filters': 96, 'kernel_size': 4, 'lr': 0.0039009442554114745, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:19:12,528] Trial 22 finished with value: 0.0007309521994708726 and parameters: {'filters': 99, 'kernel_size': 4, 'lr': 0.0031171802998662115, 'epochs': 50, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:19:30,538] Trial 23 finished with value: 0.0005616192453696082 and parameters: {'filters': 71, 'kernel_size': 5, 'lr': 0.006195866536048758, 'epochs': 47, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:19:47,630] Trial 24 finished with value: 0.0008200963008372734 and parameters: {'filters': 81, 'kernel_size': 4, 'lr': 0.0016392143961362654, 'epochs': 46, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:20:02,754] Trial 25 finished with value: 0.0006392751723372688 and parameters: {'filters': 95, 'kernel_size': 5, 'lr': 0.0034843074589146097, 'epochs': 41, 'batch_size': 8}. Best is trial 10 with value: 0.0004127205756958574.
# [I 2025-04-09 04:20:20,567] Trial 26 finished with value: 0.00033242054147801053 and parameters: {'filters': 117, 'kernel_size': 4, 'lr': 0.006754127915059373, 'epochs': 47, 'batch_size': 8}. Best is trial 26 with value: 0.00033242054147801053.
# [I 2025-04-09 04:20:33,899] Trial 27 finished with value: 0.0005302864398496846 and parameters: {'filters': 119, 'kernel_size': 6, 'lr': 0.007797925163134386, 'epochs': 35, 'batch_size': 8}. Best is trial 26 with value: 0.00033242054147801053.
# [I 2025-04-09 04:20:46,971] Trial 28 finished with value: 0.0006589029702202728 and parameters: {'filters': 119, 'kernel_size': 5, 'lr': 0.00639954666805699, 'epochs': 47, 'batch_size': 16}. Best is trial 26 with value: 0.00033242054147801053.
# [I 2025-04-09 04:20:52,972] Trial 29 finished with value: 0.0020703217402721443 and parameters: {'filters': 106, 'kernel_size': 4, 'lr': 0.0005431545354641515, 'epochs': 16, 'batch_size': 32}. Best is trial 26 with value: 0.00033242054147801053.
# Best trial: {'filters': 117, 'kernel_size': 4, 'lr': 0.006754127915059373, 'epochs': 47, 'batch_size': 8}
# Epoch 1/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0111
# Epoch 2/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 3/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 4/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 5/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 6/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6385e-04
# Epoch 7/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1993e-04
# Epoch 8/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0730e-04
# Epoch 9/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2299e-04
# Epoch 10/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0402e-04
# Epoch 11/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4771e-04
# Epoch 12/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1143e-04
# Epoch 13/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5585e-04
# Epoch 14/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9819e-04
# Epoch 15/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1357e-04
# Epoch 16/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6420e-04
# Epoch 17/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0272e-04
# Epoch 18/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0247e-04
# Epoch 19/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0797e-04
# Epoch 20/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8276e-04
# Epoch 21/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2513e-04
# Epoch 22/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2284e-04
# Epoch 23/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1790e-04
# Epoch 24/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2009e-04
# Epoch 25/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0789e-04
# Epoch 26/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5483e-04
# Epoch 27/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4930e-04
# Epoch 28/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5307e-04
# Epoch 29/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5040e-04
# Epoch 30/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4719e-04
# Epoch 31/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1026e-04
# Epoch 32/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4661e-04
# Epoch 33/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6590e-04
# Epoch 34/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8550e-04
# Epoch 35/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5242e-04
# Epoch 36/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8587e-04
# Epoch 37/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7422e-04
# Epoch 38/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5318e-04
# Epoch 39/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3821e-04
# Epoch 40/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7859e-04
# Epoch 41/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8375e-04
# Epoch 42/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2471e-04
# Epoch 43/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6732e-04
# Epoch 44/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7102e-04
# Epoch 45/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8808e-04
# Epoch 46/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5092e-04
# Epoch 47/47
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0940e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#  Test MSE  : 15.2842
#  Test RMSE : 3.9095
#  Test MAE  : 2.8400
#  Test MAPE : 53.29%
#  Test R²   : 0.9531

# %% [markdown]
# ## 7

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 7  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 7), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 15.3MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:21:28,057] A new study created in memory with name: no-name-847ec421-d945-4981-ab7a-98ee1bed39be
# [I 2025-04-09 04:21:42,395] Trial 0 finished with value: 0.014569105172995478 and parameters: {'filters': 76, 'kernel_size': 6, 'lr': 0.00010180773450342611, 'epochs': 44, 'batch_size': 32}. Best is trial 0 with value: 0.014569105172995478.
# [I 2025-04-09 04:21:49,802] Trial 1 finished with value: 0.0018778341182041913 and parameters: {'filters': 120, 'kernel_size': 6, 'lr': 0.003382083582726223, 'epochs': 19, 'batch_size': 32}. Best is trial 1 with value: 0.0018778341182041913.
# [I 2025-04-09 04:21:55,793] Trial 2 finished with value: 0.004293728309373061 and parameters: {'filters': 109, 'kernel_size': 5, 'lr': 0.00021927428149449553, 'epochs': 15, 'batch_size': 16}. Best is trial 1 with value: 0.0018778341182041913.
# [I 2025-04-09 04:22:03,252] Trial 3 finished with value: 0.0011484268761705607 and parameters: {'filters': 49, 'kernel_size': 3, 'lr': 0.008179912443479742, 'epochs': 12, 'batch_size': 8}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:22:14,785] Trial 4 finished with value: 0.0013066809139369677 and parameters: {'filters': 88, 'kernel_size': 7, 'lr': 0.0010168183090596015, 'epochs': 45, 'batch_size': 32}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:22:24,787] Trial 5 finished with value: 0.002463440061546862 and parameters: {'filters': 118, 'kernel_size': 4, 'lr': 0.00023662843749618827, 'epochs': 36, 'batch_size': 32}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:22:37,878] Trial 6 finished with value: 0.0018284687733588119 and parameters: {'filters': 99, 'kernel_size': 6, 'lr': 0.00018704933011140818, 'epochs': 37, 'batch_size': 8}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:22:47,952] Trial 7 finished with value: 0.0029446270782500505 and parameters: {'filters': 52, 'kernel_size': 5, 'lr': 0.000151964947949926, 'epochs': 23, 'batch_size': 8}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:22:57,128] Trial 8 finished with value: 0.0013567842252086848 and parameters: {'filters': 106, 'kernel_size': 6, 'lr': 0.0015076068507213385, 'epochs': 36, 'batch_size': 32}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:23:07,002] Trial 9 finished with value: 0.0022272824232156077 and parameters: {'filters': 107, 'kernel_size': 4, 'lr': 0.00021930099356819865, 'epochs': 31, 'batch_size': 16}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:23:13,782] Trial 10 finished with value: 0.0013549188054942836 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.008248397671823731, 'epochs': 11, 'batch_size': 8}. Best is trial 3 with value: 0.0011484268761705607.
# [I 2025-04-09 04:23:29,590] Trial 11 finished with value: 0.0009170937410090119 and parameters: {'filters': 80, 'kernel_size': 2, 'lr': 0.0007186450732991166, 'epochs': 50, 'batch_size': 8}. Best is trial 11 with value: 0.0009170937410090119.
# [I 2025-04-09 04:23:39,838] Trial 12 finished with value: 0.0016825397421295445 and parameters: {'filters': 64, 'kernel_size': 2, 'lr': 0.0005012370167165295, 'epochs': 26, 'batch_size': 8}. Best is trial 11 with value: 0.0009170937410090119.
# [I 2025-04-09 04:23:54,906] Trial 13 finished with value: 0.0006588073107801998 and parameters: {'filters': 45, 'kernel_size': 2, 'lr': 0.002575962978044197, 'epochs': 47, 'batch_size': 8}. Best is trial 13 with value: 0.0006588073107801998.
# [I 2025-04-09 04:24:11,012] Trial 14 finished with value: 0.0007003917562542483 and parameters: {'filters': 34, 'kernel_size': 1, 'lr': 0.0021608252906970466, 'epochs': 49, 'batch_size': 8}. Best is trial 13 with value: 0.0006588073107801998.
# [I 2025-04-09 04:24:28,459] Trial 15 finished with value: 0.0006441665852131943 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.0027979349046360824, 'epochs': 50, 'batch_size': 8}. Best is trial 15 with value: 0.0006441665852131943.
# [I 2025-04-09 04:24:42,452] Trial 16 finished with value: 0.0009703297934417302 and parameters: {'filters': 47, 'kernel_size': 2, 'lr': 0.004109330946613437, 'epochs': 42, 'batch_size': 8}. Best is trial 15 with value: 0.0006441665852131943.
# [I 2025-04-09 04:24:53,878] Trial 17 finished with value: 0.0008053698111325502 and parameters: {'filters': 63, 'kernel_size': 3, 'lr': 0.0041731288533367215, 'epochs': 41, 'batch_size': 16}. Best is trial 15 with value: 0.0006441665852131943.
# [I 2025-04-09 04:25:09,388] Trial 18 finished with value: 0.0005959141029355427 and parameters: {'filters': 41, 'kernel_size': 1, 'lr': 0.0020132292017071974, 'epochs': 47, 'batch_size': 8}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:25:21,034] Trial 19 finished with value: 0.0012412630991699796 and parameters: {'filters': 63, 'kernel_size': 1, 'lr': 0.0012459601054728717, 'epochs': 31, 'batch_size': 8}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:25:32,137] Trial 20 finished with value: 0.002342353322698424 and parameters: {'filters': 35, 'kernel_size': 3, 'lr': 0.0004648448723546318, 'epochs': 39, 'batch_size': 16}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:25:47,836] Trial 21 finished with value: 0.0006059719210801026 and parameters: {'filters': 44, 'kernel_size': 1, 'lr': 0.002334357259765131, 'epochs': 47, 'batch_size': 8}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:26:05,126] Trial 22 finished with value: 0.0005984734064744165 and parameters: {'filters': 41, 'kernel_size': 1, 'lr': 0.0017827077620651307, 'epochs': 50, 'batch_size': 8}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:26:27,856] Trial 23 finished with value: 0.0008760366666441163 and parameters: {'filters': 56, 'kernel_size': 1, 'lr': 0.0017108794324361837, 'epochs': 45, 'batch_size': 8}. Best is trial 18 with value: 0.0005959141029355427.
# [I 2025-04-09 04:26:46,352] Trial 24 finished with value: 0.0005566390367069592 and parameters: {'filters': 42, 'kernel_size': 2, 'lr': 0.005575393634106044, 'epochs': 47, 'batch_size': 8}. Best is trial 24 with value: 0.0005566390367069592.
# [I 2025-04-09 04:27:01,853] Trial 25 finished with value: 0.000583106157137081 and parameters: {'filters': 71, 'kernel_size': 2, 'lr': 0.0059185694591922635, 'epochs': 41, 'batch_size': 8}. Best is trial 24 with value: 0.0005566390367069592.
# [I 2025-04-09 04:27:18,721] Trial 26 finished with value: 0.00042620254680514336 and parameters: {'filters': 72, 'kernel_size': 3, 'lr': 0.005001623974996108, 'epochs': 42, 'batch_size': 8}. Best is trial 26 with value: 0.00042620254680514336.
# [I 2025-04-09 04:27:32,067] Trial 27 finished with value: 0.0005401239128938565 and parameters: {'filters': 75, 'kernel_size': 3, 'lr': 0.005962077756852061, 'epochs': 34, 'batch_size': 8}. Best is trial 26 with value: 0.00042620254680514336.
# [I 2025-04-09 04:27:42,666] Trial 28 finished with value: 0.000743342645970794 and parameters: {'filters': 88, 'kernel_size': 4, 'lr': 0.009996644822630614, 'epochs': 33, 'batch_size': 16}. Best is trial 26 with value: 0.00042620254680514336.
# [I 2025-04-09 04:27:53,662] Trial 29 finished with value: 0.0006845591609211018 and parameters: {'filters': 78, 'kernel_size': 3, 'lr': 0.005128818323592536, 'epochs': 27, 'batch_size': 8}. Best is trial 26 with value: 0.00042620254680514336.
# Best trial: {'filters': 72, 'kernel_size': 3, 'lr': 0.005001623974996108, 'epochs': 42, 'batch_size': 8}
# Epoch 1/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0130
# Epoch 2/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026
# Epoch 3/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 4/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014
# Epoch 5/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7830e-04
# Epoch 6/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5486e-04
# Epoch 7/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1279e-04
# Epoch 8/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6413e-04
# Epoch 9/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9465e-04
# Epoch 10/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5595e-04
# Epoch 11/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1469e-04
# Epoch 12/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5094e-04
# Epoch 13/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1249e-04
# Epoch 14/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6993e-04
# Epoch 15/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8753e-04
# Epoch 16/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3343e-04
# Epoch 17/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9087e-04
# Epoch 18/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1296e-04
# Epoch 19/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5191e-04
# Epoch 20/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5544e-04
# Epoch 21/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3759e-04
# Epoch 22/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9737e-04
# Epoch 23/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0204e-04
# Epoch 24/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2801e-04
# Epoch 25/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2497e-04
# Epoch 26/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6270e-04
# Epoch 27/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8807e-04
# Epoch 28/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8366e-04
# Epoch 29/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1210e-04
# Epoch 30/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7138e-04
# Epoch 31/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9396e-04
# Epoch 32/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1668e-04
# Epoch 33/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5034e-04
# Epoch 34/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3882e-04
# Epoch 35/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5075e-04
# Epoch 36/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4218e-04
# Epoch 37/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6620e-04
# Epoch 38/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7096e-04
# Epoch 39/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3407e-04
# Epoch 40/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3398e-04
# Epoch 41/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8358e-04
# Epoch 42/42
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0472e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  Test MSE  : 11.5713
#  Test RMSE : 3.4017
#  Test MAE  : 2.0768
#  Test MAPE : 57.09%
#  Test R²   : 0.9649

# %% [markdown]
# ## 8

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 8  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 8), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 17.7MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:28:26,214] A new study created in memory with name: no-name-a992986a-59e5-4277-97ad-c58f3e30ec60
# [I 2025-04-09 04:28:36,390] Trial 0 finished with value: 0.013235207938123494 and parameters: {'filters': 78, 'kernel_size': 2, 'lr': 0.00015642115822840186, 'epochs': 12, 'batch_size': 32}. Best is trial 0 with value: 0.013235207938123494.
# [I 2025-04-09 04:28:49,074] Trial 1 finished with value: 0.0006426592153729871 and parameters: {'filters': 43, 'kernel_size': 2, 'lr': 0.00490808832728279, 'epochs': 39, 'batch_size': 8}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:28:54,957] Trial 2 finished with value: 0.003683441085740924 and parameters: {'filters': 105, 'kernel_size': 2, 'lr': 0.00018118501948049206, 'epochs': 14, 'batch_size': 16}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:29:03,689] Trial 3 finished with value: 0.002807583582277099 and parameters: {'filters': 78, 'kernel_size': 1, 'lr': 0.00036780925860146465, 'epochs': 28, 'batch_size': 32}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:29:14,889] Trial 4 finished with value: 0.0013947804012180616 and parameters: {'filters': 40, 'kernel_size': 8, 'lr': 0.007098495257546998, 'epochs': 43, 'batch_size': 32}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:29:21,384] Trial 5 finished with value: 0.003979948892568548 and parameters: {'filters': 40, 'kernel_size': 4, 'lr': 0.00021228382893259142, 'epochs': 18, 'batch_size': 16}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:29:27,225] Trial 6 finished with value: 0.0023749435786157846 and parameters: {'filters': 128, 'kernel_size': 2, 'lr': 0.0007012928880354105, 'epochs': 11, 'batch_size': 32}. Best is trial 1 with value: 0.0006426592153729871.
# [I 2025-04-09 04:29:36,202] Trial 7 finished with value: 0.0005197541953142112 and parameters: {'filters': 115, 'kernel_size': 7, 'lr': 0.007518169476604381, 'epochs': 23, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:29:48,064] Trial 8 finished with value: 0.0010557260926968108 and parameters: {'filters': 75, 'kernel_size': 7, 'lr': 0.0011136748218305767, 'epochs': 43, 'batch_size': 16}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:02,696] Trial 9 finished with value: 0.0008944833146718641 and parameters: {'filters': 35, 'kernel_size': 6, 'lr': 0.0014223856009399113, 'epochs': 46, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:12,196] Trial 10 finished with value: 0.0008681446585493783 and parameters: {'filters': 112, 'kernel_size': 5, 'lr': 0.0030430952470279758, 'epochs': 25, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:24,473] Trial 11 finished with value: 0.001088585927694415 and parameters: {'filters': 96, 'kernel_size': 4, 'lr': 0.00888035521003567, 'epochs': 35, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:35,583] Trial 12 finished with value: 0.0008944118938719233 and parameters: {'filters': 61, 'kernel_size': 8, 'lr': 0.003655490589290698, 'epochs': 34, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:44,520] Trial 13 finished with value: 0.0010734440196150292 and parameters: {'filters': 53, 'kernel_size': 6, 'lr': 0.003669377689758389, 'epochs': 22, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:30:57,108] Trial 14 finished with value: 0.0007510401483159512 and parameters: {'filters': 126, 'kernel_size': 3, 'lr': 0.005348231920703138, 'epochs': 36, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:31:07,920] Trial 15 finished with value: 0.0011595203541219234 and parameters: {'filters': 96, 'kernel_size': 5, 'lr': 0.0018094773849788718, 'epochs': 31, 'batch_size': 8}. Best is trial 7 with value: 0.0005197541953142112.
# [I 2025-04-09 04:31:23,377] Trial 16 finished with value: 0.0004587528868190323 and parameters: {'filters': 58, 'kernel_size': 1, 'lr': 0.009891801078174422, 'epochs': 50, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:31:32,631] Trial 17 finished with value: 0.0012751957983709872 and parameters: {'filters': 63, 'kernel_size': 7, 'lr': 0.00979261746384634, 'epochs': 20, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:31:48,465] Trial 18 finished with value: 0.0005489376392991593 and parameters: {'filters': 90, 'kernel_size': 1, 'lr': 0.0023013859193984037, 'epochs': 50, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:31:57,960] Trial 19 finished with value: 0.0022499751454840102 and parameters: {'filters': 65, 'kernel_size': 6, 'lr': 0.0005744707480317484, 'epochs': 28, 'batch_size': 16}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:32:06,733] Trial 20 finished with value: 0.0008892490877769887 and parameters: {'filters': 115, 'kernel_size': 3, 'lr': 0.005769177243027315, 'epochs': 17, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:32:23,002] Trial 21 finished with value: 0.0007119482033886015 and parameters: {'filters': 89, 'kernel_size': 1, 'lr': 0.0017838186654428117, 'epochs': 50, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:32:38,847] Trial 22 finished with value: 0.000512605057641243 and parameters: {'filters': 95, 'kernel_size': 1, 'lr': 0.002435136730656876, 'epochs': 49, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:32:53,069] Trial 23 finished with value: 0.0005688615444038684 and parameters: {'filters': 107, 'kernel_size': 3, 'lr': 0.0028044152134998053, 'epochs': 46, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:33:06,091] Trial 24 finished with value: 0.0005849518444544325 and parameters: {'filters': 118, 'kernel_size': 1, 'lr': 0.007285235814124181, 'epochs': 41, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:33:20,325] Trial 25 finished with value: 0.0005173514558312794 and parameters: {'filters': 87, 'kernel_size': 7, 'lr': 0.004296541716314608, 'epochs': 47, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:33:36,062] Trial 26 finished with value: 0.0006970023920681948 and parameters: {'filters': 70, 'kernel_size': 4, 'lr': 0.004218430531104101, 'epochs': 47, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:33:51,016] Trial 27 finished with value: 0.0007995861621263126 and parameters: {'filters': 85, 'kernel_size': 3, 'lr': 0.002406955888761249, 'epochs': 48, 'batch_size': 8}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:34:02,159] Trial 28 finished with value: 0.0019405545317567885 and parameters: {'filters': 56, 'kernel_size': 2, 'lr': 0.0008836812871766289, 'epochs': 44, 'batch_size': 32}. Best is trial 16 with value: 0.0004587528868190323.
# [I 2025-04-09 04:34:23,902] Trial 29 finished with value: 0.0005736672998561213 and parameters: {'filters': 82, 'kernel_size': 2, 'lr': 0.005713706486394599, 'epochs': 40, 'batch_size': 16}. Best is trial 16 with value: 0.0004587528868190323.
# Best trial: {'filters': 58, 'kernel_size': 1, 'lr': 0.009891801078174422, 'epochs': 50, 'batch_size': 8}
# Epoch 1/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0089
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9009e-04
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3201e-04
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1038e-04
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6120e-04
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1683e-04
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1438e-04
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9257e-04
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0728e-04
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8799e-04
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0462e-04
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9240e-04
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6875e-04
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9111e-04
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0810e-04
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7836e-04
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1503e-04
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3905e-04
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5616e-04
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1347e-04
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0997e-04
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9383e-04
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4191e-04
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9005e-04
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3089e-04
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9158e-04
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4428e-04
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8857e-04
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0282e-04
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7902e-04
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6044e-04
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4431e-04
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9473e-04
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2570e-04
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7146e-04
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0858e-04
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1803e-04
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3796e-04
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5918e-04
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9088e-04
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8555e-04
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7155e-04
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6452e-04
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4324e-04
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0665e-04
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8039e-04
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5772e-04
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4161e-04
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3982e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#  Test MSE  : 34.9338
#  Test RMSE : 5.9105
#  Test MAE  : 3.4661
#  Test MAPE : 75.32%
#  Test R²   : 0.8940

# %% [markdown]
# ## 9

# %%
# Standard libraries
import sys  # System-specific parameters and functions
import os   # Miscellaneous operating system interfaces
import warnings  # Warning control
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations

# LOADING THE DATASET
import gdown

# Google Sheets URL (Updated)
google_sheets_url = "https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx"

# Download the file
output_file = 'InflationYOY..xlsx'
gdown.download(google_sheets_url, output=output_file, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
data = pd.read_excel(output_file)

# Display the first few rows of the dataframe
print(data.head())

# Create a copy of the data
df = data.copy()

# Display column names
df.columns
df
df.columns
# Create a new 'Date' column by combining 'Year', 'Month', and 'Day'
df['Date'] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# Set 'Date' as the index
df.set_index('Date', inplace=True)
# Drop the 'Year', 'Month', and 'Day' columns
df.drop(columns=['Year', 'Month', 'Day'], inplace=True)

# Display the first few rows to verify changes
print(df.head())

# Check the updated index
print(df.index)
df
! pip install optuna
# !pip install optuna
# !pip install scikit-learn
# !pip install tensorflow


import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Rename for ease if necessary
target_column ="Inflation" # e.g., "Inflation"

# Normalize the data
scaler = MinMaxScaler()
df[target_column] = scaler.fit_transform(df[[target_column]])

# Convert to supervised learning format
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Define window size
window_size = 9  # Monthly data (1 year of past data to predict next month)  #################################################################

# Prepare input/output
X, y = create_sequences(df[target_column].values, window_size)

split_index = int(len(X) * 0.7)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Reshape for CNN [samples, time steps, features]
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]

import optuna
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten
from tensorflow.keras.optimizers import Adam

def create_model(trial, input_shape):
    model = Sequential()
    model.add(Conv1D(filters=trial.suggest_int('filters', 32, 128),
                     kernel_size=trial.suggest_int('kernel_size', 1, 9), #################################################################
                     activation='relu',
                     input_shape=input_shape))
    model.add(Flatten())
    model.add(Dense(1))
    model.compile(optimizer=Adam(learning_rate=trial.suggest_loguniform('lr', 1e-4, 1e-2)),
                  loss='mse')
    return model

def objective(trial):
    tscv = TimeSeriesSplit(n_splits=3)
    val_losses = []

    for train_idx, val_idx in tscv.split(X_train):
        X_t, X_v = X_train[train_idx], X_train[val_idx]
        y_t, y_v = y_train[train_idx], y_train[val_idx]

        model = create_model(trial, input_shape=X_train.shape[1:])
        model.fit(X_t, y_t, epochs=trial.suggest_int('epochs', 10, 50), verbose=0, batch_size=trial.suggest_categorical('batch_size', [8, 16, 32]))

        val_loss = model.evaluate(X_v, y_v, verbose=0)
        val_losses.append(val_loss)

    return np.mean(val_losses)

# Run Optuna study
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print('Best trial:', study.best_trial.params)

# Train final model
best_params = study.best_trial.params
model = Sequential()
model.add(Conv1D(filters=best_params['filters'],
                 kernel_size=best_params['kernel_size'],
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Flatten())
model.add(Dense(1))
model.compile(optimizer=Adam(learning_rate=best_params['lr']),
              loss='mse')

model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], verbose=1)

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Predict and inverse transform
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100
r2 = r2_score(y_test_inv, y_pred_inv)

# Print results
print(f" Test MSE  : {mse:.4f}")
print(f" Test RMSE : {rmse:.4f}")
print(f" Test MAE  : {mae:.4f}")
print(f" Test MAPE : {mape:.2f}%")
print(f" Test R²   : {r2:.4f}")

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('CNN Forecast vs Actual')
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://docs.google.com/spreadsheets/d/11kMXVOIzTz0EGXQDYJtX945igTfAjqwg/export?format=xlsx
# To: /content/InflationYOY..xlsx
# 16.9kB [00:00, 8.27MB/s]
#    Year  Month  Day  Inflation
# 0  2000      1   31   0.329139
# 1  2000      2   28   1.940367
# 2  2000      3   31   4.469678
# 3  2000      4   30   3.672022
# 4  2000      5   31   2.382412
#             Inflation
# Date
# 2000-01-31   0.329139
# 2000-02-28   1.940367
# 2000-03-31   4.469678
# 2000-04-30   3.672022
# 2000-05-31   2.382412
# DatetimeIndex(['2000-01-31', '2000-02-28', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31',
#                ...
#                '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30',
#                '2024-10-31', '2024-11-30', '2024-12-31', '2025-01-31',
#                '2025-02-28', '2025-03-31'],
#               dtype='datetime64[ns]', name='Date', length=303, freq=None)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.40)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# [I 2025-04-09 04:34:50,230] A new study created in memory with name: no-name-ecb2e793-6409-44cc-afb4-eaddc3080a97
# [I 2025-04-09 04:35:20,632] Trial 0 finished with value: 0.0005550783729025474 and parameters: {'filters': 114, 'kernel_size': 4, 'lr': 0.001641925827033156, 'epochs': 46, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:35:28,038] Trial 1 finished with value: 0.001186139522663628 and parameters: {'filters': 55, 'kernel_size': 8, 'lr': 0.00466975371774007, 'epochs': 13, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:35:40,752] Trial 2 finished with value: 0.0021392403286881745 and parameters: {'filters': 112, 'kernel_size': 6, 'lr': 0.00036176332078448526, 'epochs': 47, 'batch_size': 32}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:35:58,557] Trial 3 finished with value: 0.0011861661138633888 and parameters: {'filters': 66, 'kernel_size': 6, 'lr': 0.0008428974658080716, 'epochs': 43, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:09,098] Trial 4 finished with value: 0.0008283412898890674 and parameters: {'filters': 75, 'kernel_size': 4, 'lr': 0.00583402811524488, 'epochs': 21, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:19,650] Trial 5 finished with value: 0.001769030272650222 and parameters: {'filters': 63, 'kernel_size': 3, 'lr': 0.001002791663546336, 'epochs': 35, 'batch_size': 16}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:27,932] Trial 6 finished with value: 0.0021706712432205677 and parameters: {'filters': 61, 'kernel_size': 4, 'lr': 0.001364153863338436, 'epochs': 14, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:36,567] Trial 7 finished with value: 0.0017831832228694111 and parameters: {'filters': 92, 'kernel_size': 1, 'lr': 0.0009102519678189353, 'epochs': 15, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:48,426] Trial 8 finished with value: 0.002961858486135801 and parameters: {'filters': 32, 'kernel_size': 1, 'lr': 0.0002104016799293673, 'epochs': 39, 'batch_size': 16}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:36:54,826] Trial 9 finished with value: 0.002285893618439635 and parameters: {'filters': 82, 'kernel_size': 4, 'lr': 0.008486604355887108, 'epochs': 16, 'batch_size': 32}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:37:04,876] Trial 10 finished with value: 0.001137840454854692 and parameters: {'filters': 125, 'kernel_size': 9, 'lr': 0.0026945032512233655, 'epochs': 29, 'batch_size': 16}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:37:15,459] Trial 11 finished with value: 0.0009456220529197404 and parameters: {'filters': 99, 'kernel_size': 3, 'lr': 0.0029965000731284066, 'epochs': 25, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:37:25,369] Trial 12 finished with value: 0.0010936695713705074 and parameters: {'filters': 128, 'kernel_size': 6, 'lr': 0.007398003045193229, 'epochs': 23, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:37:37,818] Trial 13 finished with value: 0.0009293612577797224 and parameters: {'filters': 106, 'kernel_size': 3, 'lr': 0.0026925730061632784, 'epochs': 34, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:37:53,647] Trial 14 finished with value: 0.0012484703911468387 and parameters: {'filters': 82, 'kernel_size': 5, 'lr': 0.0004516602674914169, 'epochs': 50, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:01,273] Trial 15 finished with value: 0.0020744818029925227 and parameters: {'filters': 48, 'kernel_size': 2, 'lr': 0.0017375106782736508, 'epochs': 21, 'batch_size': 32}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:11,060] Trial 16 finished with value: 0.0030635446698094406 and parameters: {'filters': 74, 'kernel_size': 5, 'lr': 0.00012035016785629939, 'epochs': 28, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:19,928] Trial 17 finished with value: 0.0009063507313840091 and parameters: {'filters': 114, 'kernel_size': 7, 'lr': 0.005114554891018744, 'epochs': 20, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:30,916] Trial 18 finished with value: 0.0013435438255934666 and parameters: {'filters': 90, 'kernel_size': 4, 'lr': 0.004587370515414753, 'epochs': 42, 'batch_size': 32}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:36,823] Trial 19 finished with value: 0.002272804578145345 and parameters: {'filters': 75, 'kernel_size': 2, 'lr': 0.0005258454211126978, 'epochs': 10, 'batch_size': 16}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:48,735] Trial 20 finished with value: 0.0010308703931514174 and parameters: {'filters': 43, 'kernel_size': 5, 'lr': 0.0018723593170427042, 'epochs': 33, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:38:57,060] Trial 21 finished with value: 0.0011598679217665147 and parameters: {'filters': 114, 'kernel_size': 7, 'lr': 0.005229241690490433, 'epochs': 19, 'batch_size': 8}. Best is trial 0 with value: 0.0005550783729025474.
# [I 2025-04-09 04:39:07,626] Trial 22 finished with value: 0.0003902788060562064 and parameters: {'filters': 103, 'kernel_size': 7, 'lr': 0.009119251197717925, 'epochs': 26, 'batch_size': 8}. Best is trial 22 with value: 0.0003902788060562064.
# [I 2025-04-09 04:39:18,854] Trial 23 finished with value: 0.0008359770727111027 and parameters: {'filters': 100, 'kernel_size': 8, 'lr': 0.009649522168519286, 'epochs': 29, 'batch_size': 8}. Best is trial 22 with value: 0.0003902788060562064.
# [I 2025-04-09 04:39:29,171] Trial 24 finished with value: 0.0010948868778844674 and parameters: {'filters': 119, 'kernel_size': 5, 'lr': 0.0033372919788436906, 'epochs': 26, 'batch_size': 8}. Best is trial 22 with value: 0.0003902788060562064.
# [I 2025-04-09 04:39:41,511] Trial 25 finished with value: 0.0005703710970313599 and parameters: {'filters': 90, 'kernel_size': 7, 'lr': 0.006087633502173218, 'epochs': 36, 'batch_size': 8}. Best is trial 22 with value: 0.0003902788060562064.
# [I 2025-04-09 04:39:54,347] Trial 26 finished with value: 0.00036062116851098835 and parameters: {'filters': 93, 'kernel_size': 7, 'lr': 0.009656460911117493, 'epochs': 38, 'batch_size': 8}. Best is trial 26 with value: 0.00036062116851098835.
# [I 2025-04-09 04:40:09,480] Trial 27 finished with value: 0.00045535242922293645 and parameters: {'filters': 102, 'kernel_size': 9, 'lr': 0.009718133069214652, 'epochs': 45, 'batch_size': 8}. Best is trial 26 with value: 0.00036062116851098835.
# [I 2025-04-09 04:40:20,352] Trial 28 finished with value: 0.0007649769055812309 and parameters: {'filters': 100, 'kernel_size': 9, 'lr': 0.009197696069048515, 'epochs': 40, 'batch_size': 32}. Best is trial 26 with value: 0.00036062116851098835.
# [I 2025-04-09 04:40:32,492] Trial 29 finished with value: 0.0010305517838181306 and parameters: {'filters': 107, 'kernel_size': 8, 'lr': 0.0039191722034393845, 'epochs': 44, 'batch_size': 16}. Best is trial 26 with value: 0.00036062116851098835.
# Best trial: {'filters': 93, 'kernel_size': 7, 'lr': 0.009656460911117493, 'epochs': 38, 'batch_size': 8}
# Epoch 1/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0076
# Epoch 2/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 3/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017
# Epoch 4/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010
# Epoch 5/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6373e-04
# Epoch 6/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5630e-04
# Epoch 7/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2349e-04
# Epoch 8/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8313e-04
# Epoch 9/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3856e-04
# Epoch 10/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2023e-04
# Epoch 11/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9783e-04
# Epoch 12/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2126e-04
# Epoch 13/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2490e-04
# Epoch 14/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3457e-04
# Epoch 15/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0956e-04
# Epoch 16/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6390e-04
# Epoch 17/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9793e-04
# Epoch 18/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8278e-04
# Epoch 19/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2926e-04
# Epoch 20/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0188e-04
# Epoch 21/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7555e-04
# Epoch 22/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4507e-04
# Epoch 23/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8997e-04
# Epoch 24/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4730e-04
# Epoch 25/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6666e-04
# Epoch 26/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1143e-04
# Epoch 27/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5377e-04
# Epoch 28/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4596e-04
# Epoch 29/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7296e-04
# Epoch 30/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5311e-04
# Epoch 31/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1041e-04
# Epoch 32/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6923e-04
# Epoch 33/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5819e-04
# Epoch 34/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9414e-04
# Epoch 35/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3301e-04
# Epoch 36/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7855e-04
# Epoch 37/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2789e-04
# Epoch 38/38
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0460e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  Test MSE  : 12.2481
#  Test RMSE : 3.4997
#  Test MAE  : 2.3938
#  Test MAPE : 53.43%
#  Test R²   : 0.9628

# %% [markdown]
# ## 10
